# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable
from collections.abc import Iterable  # Import Iterable from collections.abc

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re
import difflib
from PyPDF2 import PdfReader 
from nltk.tokenize import word_tokenize
from nltk.corpus import words as nltk_words

# %%
relative_path_html = "HTML/Output_html_Chapter1/kaggle/working/out/output/"
relative_path_pdf = "HTML/Output_html_Chapter1/kaggle/working/out/pages/"
# Get the absolute path by joining the current directory with the relative path
absolute_path_html = os.path.join(os.getcwd(), relative_path_html)
absolute_path_pdf = os.path.join(os.getcwd(), relative_path_pdf)

# %%
output_list = []
vocab = []

# %%
output_list
# Out:
# []

# %%
vocab
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
def filter_english_characters(word_list):
    filtered = []

    for word in word_list:
        # Check if the word contains only English letters
        #if re.match("^[a-zA-Z]+$", word):
        if re.match("[a-zA-Z]+", word):
            filtered.append(word)

    return filtered

# %%
for file in os.listdir(absolute_path_pdf):
    # Check whether the file is in text format
    if file.endswith(".pdf"):
        file_path = os.path.join(absolute_path_pdf, file)  # Construct the full file path
        with open(file_path, 'rb') as fp:
            reader = PdfReader(fp)  
            page = reader.pages[0] 
            # Extract text from the page 
            text = page.extract_text()
            tokens = word_tokenize(text)
            clean_text = [word.lower() for word in tokens if word.isalpha()]
            filtered = filter_english_characters(clean_text)
            vocab.extend(filtered)

# %%
full_vocab = list(set(vocab))
full_vocab
# Out:
# ['temporary',
#  'sourace',
#  'tmc',
#  'uàzàuà',
#  'council',
#  'gddp',
#  'statutory',
#  'towns',
#  'yet',
#  'hassan',
#  'note',
#  'gross',
#  'avàæ',
#  'card',
#  'aiàiázàvj',
#  'zàqët',
#  'nacs',
#  'cc',
#  'kannada',
#  'inhabited',
#  'govt',
#  'tp',
#  'gà',
#  'monitoring',
#  'yadgiri',
#  'gáaiàäzàægàä',
#  'davanagere',
#  'apl',
#  'above',
#  'station',
#  'permanent',
#  'cylindercpàëaiàä',
#  'female',
#  'village',
#  'value',
#  'anthyodayaration',
#  'as',
#  'mysuru',
#  'includes',
#  'rs',
#  'uttara',
#  'water',
#  'notified',
#  'at',
#  'kolar',
#  'shivamogga',
#  'state',
#  'bodies',
#  'ballari',
#  'muncipal',
#  'property',
#  'civil',
#  'r',
#  'census',
#  'working',
#  'tumakuru',
#  'without',
#  'shops',
#  'corporation',
#  'current',
#  'film',
#  'rural',
#  'revenue',
#  'va',
#  'bengaluru',
#  'gvàûgà',
#  'administration',
#  'nada',
#  'directorate',
#  'fire',
#  'nddp',
#  'railway',
#  'stations',
#  'from',
#  'dharawad',
#  'chikkamagaluru',
#  'capita',
#  'lakhs',
#  'municipal',
#  'with',
#  'primary',
#  'urban',
#  'villages',
#  'mläö',
#  'per',
#  'police',
#  'emergency',
#  'of',
#  'mandya',
#  'not',
#  'percapita',
#  'food',
#  'ministry',
#  'bifurcated',
#  'gadag',
#  'vàäªàäpàægàä',
#  'chitradurga',
#  'broadcasting',
#  'india',
#  'koppal',
#  'theatres',
#  'source',
#  'on',
#  'notyet',
#  'panchayaths',
#  'area',
#  'tally',
#  'záªàtuégé',
#  'kodagu',
#  'districts',
#  'chikkaballapura',
#  'district',
#  'pàææªàä',
#  'panchayat',
#  'calls',
#  'photo',
#  'chamarajanagar',
#  'dakshina',
#  'poverty',
#  'bagalkot',
#  'general',
#  'traffic',
#  'net',
#  'belagavi',
#  'haveri',
#  'bpl',
#  'taluks',
#  'péæqàuàä',
#  'city',
#  'offices',
#  'págáuàèºà',
#  'total',
#  'supplies',
#  'constant',
#  'in',
#  'villagesas',
#  'gádåmläö',
#  'ration',
#  'villagestotal',
#  'cinema',
#  'districtsmläö',
#  'karnataka',
#  'prices',
#  'is',
#  'kalaburagi',
#  'divison',
#  'ramanagara',
#  'information',
#  'holders',
#  'kalburagi',
#  'hoblies',
#  'circles',
#  'women',
#  'uáæªàä',
#  'rdpr',
#  'cylinderbpl',
#  'vijayapura',
#  'tppàææªàä',
#  'department',
#  'districtrailway',
#  'nos',
#  'prisons',
#  'priority',
#  'districtsapl',
#  'accountant',
#  'và',
#  'avàæzàäuàð',
#  'gádå',
#  'zságàªáqà',
#  'aãnzágàgàä',
#  'districtdomestic',
#  'local',
#  'product',
#  'aãnzágàgà',
#  'brigade',
#  'frombengaluru',
#  'prisoners',
#  'and',
#  'cmc',
#  'egàäªà',
#  'uáæ',
#  'raichur',
#  'domestic',
#  'the',
#  'income',
#  'akshaya',
#  'bidar',
#  'town',
#  'below',
#  'grama',
#  'udupi']

# %%
# iterate through all file 
for file in os.listdir(absolute_path_html): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = os.path.join(absolute_path_html, file)
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)

# %%
output_list
# Out:
# [[['1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA'],
#   ['Sl.No',
#    'District',
#    'At Current Prices 2013-14',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices',
#    'At Constant 2011-12 Prices',
#    'Per capita NDDP In Rs.',
#    'Per capita NDDP In Rs.'],
#   ['Sl.No',
#    'District',
#    'Gross District Domestic Product GDDP Rs. inLakhs',
#    'Net District Domestic Product NDDP Rs. inLakhs',
#    'Gross District Domestic Product GDDP Rs. inLakhs',
#    'Net District Domestic Product NDDP Rs. inLakhs',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices'],
#   ['1', '2', '52', '53', '54', '55', '56', '57']],
#  [['General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.'],
#   ['',
#    'ffl',
#    'Nada Offices',
#    'Circles',
#    'Hoblies',
#    'Grama Panchayaths',
#    'No.of Taluks'],
#   ['1', '2', '3', '4', '5', '6', '7']],
#  [['1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census'],
#   ['Sl.No',
#    'Districts',
#    '2011g twCities Towns Urban',
#    '201 Villages',
#    '201 Villages',
#    'TOTAL Villages'],
#   ['Sl.No',
#    'Districts',
#    '2011g twCities Towns Urban',
#    'Inhabited',
#    'Efi Un-inhabited',
#    'TOTAL Villages'],
#   ['1', '2', '8', '9', '10', '11']],
#  [['1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos'],
#   ['',
#    'ffl',
#    'FireBrigade Stations',
#    'WorkingFireBrigadeWaterTankers',
#    'Emergencyfirecall received',
#    'Valueofthes property protected'],
#   ['1', '2', '24', '25', '26', '27']],
#  [['1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl'],
#   ['Sl.No.',
#    'Districts',
#    'WithCylinder',
#    'WithCylinder',
#    'WithCylinder',
#    'Without Cylinder',
#    'Without Cylinder',
#    'Without Cylinder'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'tRural',
#    'Total',
#    'Urban',
#    'tRural',
#    'Total'],
#   ['1', '2', '40', '41', '42', '43', '44', '45']],
#  [['1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos'],
#   ['',
#    'ffl',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies'],
#   ['', 'ffl', 'CC', 'CMC', 'TMC', 'TP', 'NACs', 'TOTAL'],
#   ['1', '2', '12', '13', '14', '15', '16', '17']],
#  [['1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'ema PoliceStations',
#    'ema PoliceStations',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'ema PoliceStations',
#    'ema PoliceStations',
#    'Prisons',
#    'Prisons',
#    'Prisoner',
#    'Prisoner',
#    'Prisoner'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'ema PoliceStations',
#    'ema PoliceStations',
#    'Prisons',
#    'Prisons',
#    'Male',
#    'Male',
#    'Female'],
#   ['1',
#    '2',
#    '2',
#    '2',
#    '2',
#    '18',
#    '18',
#    '19',
#    '19',
#    '20',
#    '20',
#    '21',
#    '21',
#    '22',
#    '22',
#    '23']],
#  [['1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders'],
#   ['Sl.No',
#    'Districts',
#    'Urban',
#    'Rural',
#    'Total',
#    'Urban',
#    'tRural',
#    'Total'],
#   ['1', '2', '46', '47', '48', '49', '50', '51']],
#  [['1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos'],
#   ['',
#    '.ffl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl'],
#   ['',
#    '.ffl',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder'],
#   ['', '.ffl', 'Urban', 'tRural', 'Total', 'gUrban', 'Rural', 'Total'],
#   ['1', '2', '34', '35', '36', '37', '38', '39']],
#  [['1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'BPL Card Holders Jfl',
#    'BPL Card Holders Jfl',
#    'BPL Card Holders Jfl'],
#   ['Sl.No.',
#    'Districts',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'CAv Anthyodaya',
#    'CAv Anthyodaya',
#    'CAv Anthyodaya'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'tRural',
#    'Total',
#    'Urban',
#    'tRural',
#    'Total'],
#   ['1', '2', '28', '29', '30', '31', '32', '33']]]

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def remove_after_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].end()
        input_string = input_string[:second_occurrence_index]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def process_one_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_one_data(output_list)
output_list
# Out:
# [[['1.10 ffl District Income Of Karnataka',
#    '1.10 ffl District Income Of Karnataka',
#    '1.10 ffl District Income Of Karnataka',
#    '1.10 ffl District Income Of Karnataka',
#    '1.10 ffl District Income Of Karnataka',
#    '1.10 ffl District Income Of Karnataka',
#    '1.10 ffl District Income Of Karnataka',
#    '1.10 ffl District Income Of Karnataka'],
#   ['Sl.No',
#    'District',
#    'At Current Prices 2013-14',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices',
#    'At Constant 2011-12 Prices',
#    'Per capita Nddp In Rs.',
#    'Per capita Nddp In Rs.'],
#   ['Sl.No',
#    'District',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices'],
#   ['1', '2', '52', '53', '54', '55', '56', '57']],
#  [['31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.'],
#   ['',
#    'ffl',
#    'Nada Offices',
#    'Circles',
#    'Hoblies',
#    'Grama Panchayaths',
#    'No.of Taluks'],
#   ['1', '2', '3', '4', '5', '6', '7']],
#  [['1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census'],
#   ['Sl.No',
#    'Districts',
#    '2011g tw Cities Towns Urban',
#    '201 Villages',
#    '201 Villages',
#    'Total Villages'],
#   ['Sl.No',
#    'Districts',
#    '2011g tw Cities Towns Urban',
#    'Inhabited',
#    'Efi Un-inhabited',
#    'Total Villages'],
#   ['1', '2', '8', '9', '10', '11']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['',
#    'ffl',
#    'Fire Brigade Stations',
#    'Working Fire Brigade Water Tankers',
#    'Emergencyfirecall received',
#    'Valueofthes property protected'],
#   ['1', '2', '24', '25', '26', '27']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'Apl Card Holders Jfl',
#    'Apl Card Holders Jfl',
#    'Apl Card Holders Jfl',
#    'Apl Card Holders Jfl',
#    'Apl Card Holders Jfl',
#    'Apl Card Holders Jfl'],
#   ['Sl.No.',
#    'Districts',
#    'With Cylinder',
#    'With Cylinder',
#    'With Cylinder',
#    'Without Cylinder',
#    'Without Cylinder',
#    'Without Cylinder'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    't Rural',
#    'Total',
#    'Urban',
#    't Rural',
#    'Total'],
#   ['1', '2', '40', '41', '42', '43', '44', '45']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['',
#    'ffl',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies'],
#   ['', 'ffl', 'Cc', 'Cmc', 'Tmc', 'Tp', 'NACs', 'Total'],
#   ['1', '2', '12', '13', '14', '15', '16', '17']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'ema Police Stations',
#    'ema Police Stations',
#    '31.03.2016',
#    '31.03.2016',
#    '31.03.2016',
#    '31.03.2016',
#    '31.03.2016'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'ema Police Stations',
#    'ema Police Stations',
#    'Prisons',
#    'Prisons',
#    'Prisoner',
#    'Prisoner',
#    'Prisoner'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'ema Police Stations',
#    'ema Police Stations',
#    'Prisons',
#    'Prisons',
#    'Male',
#    'Male',
#    'Female'],
#   ['1',
#    '2',
#    '2',
#    '2',
#    '2',
#    '18',
#    '18',
#    '19',
#    '19',
#    '20',
#    '20',
#    '21',
#    '21',
#    '22',
#    '22',
#    '23']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders'],
#   ['Sl.No',
#    'Districts',
#    'Urban',
#    'Rural',
#    'Total',
#    'Urban',
#    't Rural',
#    'Total'],
#   ['1', '2', '46', '47', '48', '49', '50', '51']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['',
#    '.ffl',
#    'BPLCard Holders Jfl',
#    'BPLCard Holders Jfl',
#    'BPLCard Holders Jfl',
#    'BPLCard Holders Jfl',
#    'BPLCard Holders Jfl',
#    'BPLCard Holders Jfl'],
#   ['',
#    '.ffl',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder'],
#   ['', '.ffl', 'Urban', 't Rural', 'Total', 'g Urban', 'Rural', 'Total'],
#   ['1', '2', '34', '35', '36', '37', '38', '39']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'Cau Ration shops',
#    'Cau Ration shops',
#    'Cau Ration shops',
#    'Bpl Card Holders Jfl',
#    'Bpl Card Holders Jfl',
#    'Bpl Card Holders Jfl'],
#   ['Sl.No.',
#    'Districts',
#    'Cau Ration shops',
#    'Cau Ration shops',
#    'Cau Ration shops',
#    'CAv Anthyodaya',
#    'CAv Anthyodaya',
#    'CAv Anthyodaya'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    't Rural',
#    'Total',
#    'Urban',
#    't Rural',
#    'Total'],
#   ['1', '2', '28', '29', '30', '31', '32', '33']]]

# %%
def extract_unmatched_words(out_list, full_vocab):
    unmatched_words = set()

    # Helper function to flatten nested lists
    def flatten(items):
        for x in items:
            if isinstance(x, Iterable) and not isinstance(x, (str, bytes)):
                yield from flatten(x)
            else:
                yield x

    # Flatten the out_list and tokenize words
    words = ' '.join(flatten(out_list)).split()

    # Filter English words
    english_words = [word.lower() for word in words if re.match("[a-zA-Z]+", word)]

    # Find unmatched words
    for word in english_words:
        if word not in full_vocab:
            unmatched_words.add(word)

    return unmatched_words

# Extract unmatched words
unmatched_words = extract_unmatched_words(output_list, full_vocab)
print("Unmatched English words:", unmatched_words)
# Out:
# Unmatched English words: {'g', 'efi', 'sl.no.', 'anthyodaya', 'cylinder', 'received', 'cal', 'cities', 'tankers', 'protected', 'ema', 'sl.no', 'jfl', 'akshayawithcylinder', 'cav', 'tw', 'urba', 'prisoner', 'cau', 'emergencyfirecall', 'un-inhabited', 't', 'ffl', 'male', 'bplcard', 'no.of', 'valueofthes', 'cin', 'rs.', 'nos.'}

# %%
closest_matches = {}

# Find closest match for each unmatched word
for word in unmatched_words:
    closest_match = difflib.get_close_matches(word, full_vocab, n=1)
    if closest_match:
        closest_matches[word] = closest_match[0]

# Join matched words with spaces
for key in closest_matches:
    closest_matches[key] = ' '.join(closest_matches[key].split())

print("Closest matches:", closest_matches)
# Out:
# Closest matches: {'g': 'gà', 'anthyodaya': 'anthyodayaration', 'cylinder': 'cylinderbpl', 'cal': 'local', 'cities': 'circles', 'tankers': 'taluks', 'protected': 'product', 'ema': 'female', 'tw': 'town', 'urba': 'urban', 'prisoner': 'prisoners', 'emergencyfirecall': 'emergency', 'un-inhabited': 'inhabited', 't': 'tp', 'male': 'female', 'bplcard': 'card', 'valueofthes': 'value', 'cin': 'in', 'rs.': 'rs', 'nos.': 'nos'}

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['g', 'efi', 'ema', 'jfl', 'cav', 'cau', 't', 'ffl']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')
    
    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = { 'cal': 'local', 'ema': 'female', 'tw': 'town', 'urba': 'urban', 'prisoner': 'prisoners', 'emergencyfirecall': 'emergency firecall', 'male': 'female', 'bplcard': 'bpl card', 'valueofthes': 'value of the'}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)

# %%
process_data(output_list)
output_list
# Out:
# [[['1.10  District Income Of Karnataka',
#    '1.10  District Income Of Karnataka',
#    '1.10  District Income Of Karnataka',
#    '1.10  District Income Of Karnataka',
#    '1.10  District Income Of Karnataka',
#    '1.10  District Income Of Karnataka',
#    '1.10  District Income Of Karnataka',
#    '1.10  District Income Of Karnataka'],
#   ['Sl.No',
#    'District',
#    'At Current Prices 2013-14',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices',
#    'At Constant 2011-12 Prices',
#    'Per capita Nddp In Rs.',
#    'Per capita Nddp In Rs.'],
#   ['Sl.No',
#    'District',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices'],
#   ['1', '2', '52', '53', '54', '55', '56', '57']],
#  [['31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.',
#    '31.03.2016.'],
#   ['',
#    '',
#    'Nada Offices',
#    'Circles',
#    'Hoblies',
#    'Grama Panchayaths',
#    'No.of Taluks'],
#   ['1', '2', '3', '4', '5', '6', '7']],
#  [['1.2  No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2  No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2  No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2  No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2  No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2  No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census'],
#   ['Sl.No',
#    'Districts',
#    '2011g town Cities Towns Urban',
#    '201 Villages',
#    '201 Villages',
#    'Total Villages'],
#   ['Sl.No',
#    'Districts',
#    '2011g town Cities Towns Urban',
#    'Inhabited',
#    'Un-inhabited',
#    'Total Villages'],
#   ['1', '2', '8', '9', '10', '11']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['',
#    '',
#    'Fire Brigade Stations',
#    'Working Fire Brigade Water Tankers',
#    'Emergencyfirecall received',
#    'Valueofthes property protected'],
#   ['1', '2', '24', '25', '26', '27']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders'],
#   ['Sl.No.',
#    'Districts',
#    'With Cylinder',
#    'With Cylinder',
#    'With Cylinder',
#    'Without Cylinder',
#    'Without Cylinder',
#    'Without Cylinder'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'Rural',
#    'Total',
#    'Urban',
#    'Rural',
#    'Total'],
#   ['1', '2', '40', '41', '42', '43', '44', '45']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['',
#    '',
#    'Urba local Bodies',
#    'Urba local Bodies',
#    'Urba local Bodies',
#    'Urba local Bodies',
#    'Urba local Bodies',
#    'Urba local Bodies'],
#   ['', '', 'Cc', 'Cmc', 'Tmc', 'Tp', 'NACs', 'Total'],
#   ['1', '2', '12', '13', '14', '15', '16', '17']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Police Stations',
#    'Police Stations',
#    '31.03.2016',
#    '31.03.2016',
#    '31.03.2016',
#    '31.03.2016',
#    '31.03.2016'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'Police Stations',
#    'Police Stations',
#    'Prisons',
#    'Prisons',
#    'Prisoner',
#    'Prisoner',
#    'Prisoner'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'Police Stations',
#    'Police Stations',
#    'Prisons',
#    'Prisons',
#    'Male',
#    'Male',
#    'Female'],
#   ['1',
#    '2',
#    '2',
#    '2',
#    '2',
#    '18',
#    '18',
#    '19',
#    '19',
#    '20',
#    '20',
#    '21',
#    '21',
#    '22',
#    '22',
#    '23']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders'],
#   ['Sl.No', 'Districts', 'Urban', 'Rural', 'Total', 'Urban', 'Rural', 'Total'],
#   ['1', '2', '46', '47', '48', '49', '50', '51']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['',
#    '.ffl',
#    'BPLCard Holders',
#    'BPLCard Holders',
#    'BPLCard Holders',
#    'BPLCard Holders',
#    'BPLCard Holders',
#    'BPLCard Holders'],
#   ['',
#    '.ffl',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder'],
#   ['', '.ffl', 'Urban', 'Rural', 'Total', 'Urban', 'Rural', 'Total'],
#   ['1', '2', '34', '35', '36', '37', '38', '39']],
#  [['31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos',
#    '31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'Ration shops',
#    'Ration shops',
#    'Ration shops',
#    'Bpl Card Holders',
#    'Bpl Card Holders',
#    'Bpl Card Holders'],
#   ['Sl.No.',
#    'Districts',
#    'Ration shops',
#    'Ration shops',
#    'Ration shops',
#    'Anthyodaya',
#    'Anthyodaya',
#    'Anthyodaya'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'Rural',
#    'Total',
#    'Urban',
#    'Rural',
#    'Total'],
#   ['1', '2', '28', '29', '30', '31', '32', '33']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'Si.n',
#    'Si.n',
#    '1'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Urban',
#    '55'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Rural',
#    '56'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Total',
#    '57'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    '% to State total',
#    '58'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Urban',
#    '59'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Rural',
#    '60'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Total',
#    '61'],
#   ['1.9',
#    'Non-Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    '% % to State total',
#    '62']],
#  [['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'Villages',
#    'Un-Inhabited Inhabited',
#    '7'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'Villages',
#    'Un-Inhabited Inhabited',
#    '8'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    '',
#    'Total Villages',
#    '9']],
#  [['1.5', 'No. of Fire Stations on 31-3-2020', '', '1'],
#   ['1.5', 'No. of Fire Stations on 31-3-2020', '', '2'],
#   ['1.5', 'No. of Fire Stations on 31-3-2020', 'Fire Brigade Stations', '20'],
#   ['1.5',
#    'No. of Fire Stations on 31-3-2020',
#    'Working Fire Brigade Water Tankers',
#    '21'],
#   ['1.5',
#    'No. of Fire Stations on 31-3-2020',
#    'Emergency fire calls received',
#    '22'],
#   ['1.5',
#    'No. of Fire Stations on 31-3-2020',
#    'Value of the property protected during 2019-20 Rs.in Lakhs',
#    '23']],
#  [['1.10', 'District Income and Per Capita Income', 'SI.No', 'SI.No', '1'],
#   ['1.10',
#    'District Income and Per Capita Income',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.10',
#    'District Income and Per Capita Income',
#    '2017 At Current Prices 2017-18',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    '63'],
#   ['1.10',
#    'District Income and Per Capita Income',
#    '2017 At Current Prices 2017-18',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    '64'],
#   ['1.10',
#    'District Income and Per Capita Income',
#    'At Constant Prices 2017-18',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    '65'],
#   ['1.10',
#    'District Income and Per Capita Income',
#    'At Constant Prices 2017-18',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    '66'],
#   ['1.10',
#    'District Income and Per Capita Income',
#    'Per capita Income In Rs.',
#    'At Current Prices 2017-18',
#    '67'],
#   ['1.10',
#    'District Income and Per Capita Income',
#    'Per capita Income In Rs.',
#    'At constant Prices 2017-18',
#    '68'],
#   ['1.10', 'District Income and Per Capita Income', 'Rank', 'Rank', '69']],
#  [['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Urban',
#    '39'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Rural',
#    '40'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Total',
#    '41'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    '% to State total',
#    '42'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Urban',
#    '43'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Rural',
#    '44'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Total',
#    '45'],
#   ['1.7',
#    'Anthyodaya Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    '% to State total',
#    '46']],
#  [['1.3', 'Urban Local Bodies', '', '', '1'],
#   ['1.3', 'Urban Local Bodies', '', '', '2'],
#   ['1.3', 'Urban Local Bodies', 'Urban Local Bodies', 'Cc', '10'],
#   ['1.3', 'Urban Local Bodies', 'Urban Local Bodies', 'Cmc', '11'],
#   ['1.3', 'Urban Local Bodies', 'Urban Local Bodies', 'Tmc', '12'],
#   ['1.3', 'Urban Local Bodies', 'Urban Local Bodies', 'Tp', '13'],
#   ['1.3', 'Urban Local Bodies', 'Urban Local Bodies', 'NACs', '14'],
#   ['1.3', 'Urban Local Bodies', 'Urban Local Bodies', 'Total', '15']],
#  [['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Urban',
#    '47'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Rural',
#    '48'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    'Total',
#    '49'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'with cylinder',
#    '% to State total',
#    '50'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Urban',
#    '51'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Rural',
#    '52'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    'Total',
#    '53'],
#   ['1.8',
#    'Priority Card Holders with and without gas cylinder on 31-3-2020 Cumulative',
#    'without cylinder',
#    '% to State total',
#    '54'],
#   ['', '', '', '% to State total', '54']],
#  [['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Priority',
#    'Urban',
#    '30'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Priority',
#    'Rural',
#    '31'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Priority',
#    'Total',
#    '32'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Non Priority',
#    'Urban',
#    '33'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Non Priority',
#    'Rural',
#    '34'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Non Priority',
#    'Total',
#    '35'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Total Card Hold',
#    'Urban',
#    '36'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Total Card Hold',
#    'Rural',
#    '37'],
#   ['1.6',
#    'Priority Non Priority and Total Ration Card Holders on 31-3-2017 Cumulative',
#    'Total Card Hold',
#    'Total',
#    '38'],
#   ['', '', '', 'Total', '38']],
#  [['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Si. No',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Ration shops',
#    'Ration shops',
#    'Urban',
#    '24'],
#   ['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Ration shops',
#    'Ration shops',
#    'Rural',
#    '25'],
#   ['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Ration shops',
#    'Ration shops',
#    'Total',
#    '26'],
#   ['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Ration card holders',
#    'Anthyodaya',
#    'Urban',
#    '27'],
#   ['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Ration card holders',
#    'Anthyodaya',
#    'Rural',
#    '28'],
#   ['1.6',
#    'Ration Shops and Ration Card Holders on 31-3-2017 Cumulative',
#    'Ration card holders',
#    'Anthyodaya',
#    'Total',
#    '29'],
#   ['', '', '', '', 'Total', '29']],
#  [['1.4',
#    'Police Stations Prisons and Prisoners on 31-3-2020 in numbers Prisons and Prisoners',
#    'sl',
#    'sl',
#    'sl',
#    '1'],
#   ['1.4',
#    'Police Stations Prisons and Prisoners on 31-3-2020 in numbers Prisons and Prisoners',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['1.4',
#    'Police Stations Prisons and Prisoners on 31-3-2020 in numbers Prisons and Prisoners',
#    'Police Stations',
#    'Police Stations',
#    'Police Stations',
#    '16'],
#   ['1.4',
#    'Police Stations Prisons and Prisoners on 31-3-2020 in numbers Prisons and Prisoners',
#    'Prisons and Prisoners',
#    'Prisons',
#    'Prisons',
#    '17'],
#   ['1.4',
#    'Police Stations Prisons and Prisoners on 31-3-2020 in numbers Prisons and Prisoners',
#    'Prisons and Prisoners',
#    'Prisoners',
#    'Male',
#    '18'],
#   ['1.4',
#    'Police Stations Prisons and Prisoners on 31-3-2020 in numbers Prisons and Prisoners',
#    'Prisons and Prisoners',
#    'Prisoners',
#    'Female',
#    '19']],
#  [['1.1',
#    'Taluks Hoblies Grama Panchayath Village Accountant Circles on 31-3-2020',
#    '',
#    '1'],
#   ['1.1',
#    'Taluks Hoblies Grama Panchayath Village Accountant Circles on 31-3-2020',
#    '',
#    '2'],
#   ['1.1',
#    'Taluks Hoblies Grama Panchayath Village Accountant Circles on 31-3-2020',
#    'Taluks',
#    '3'],
#   ['1.1',
#    'Taluks Hoblies Grama Panchayath Village Accountant Circles on 31-3-2020',
#    'Hoblies',
#    '4'],
#   ['1.1',
#    'Taluks Hoblies Grama Panchayath Village Accountant Circles on 31-3-2020',
#    'Grama Panchayaths',
#    '5'],
#   ['1.1',
#    'Taluks Hoblies Grama Panchayath Village Accountant Circles on 31-3-2020',
#    'Circles',
#    '6']],
#  [['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'Villages',
#    'Un-Inhabited Inhabited',
#    '7'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    'Villages',
#    'Un-Inhabited Inhabited',
#    '8'],
#   ['1.2',
#    'Inhabited Un-inhabited and Total Villages per Census',
#    '',
#    'Total Villages',
#    '9']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 1
chapter_name = "General Information"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id = remove_extra_spaces(inner_list[0][0])
        table_name = remove_extra_spaces(inner_list[0][1])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list)-1:
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Output_html_Chapter1/Chapter1_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Dictionary/Chapter1_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)

# %%
#Not used
def remove_before_second_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) >= 2:
        second_occurrence_index = matches[1].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()
