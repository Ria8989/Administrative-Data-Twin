# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
relative_path_html = "HTML/Output_html_Chapter1/kaggle/working/out/output/"
relative_path_pdf = "HTML/Output_html_Chapter1/kaggle/working/out/pages/"
# Get the absolute path by joining the current directory with the relative path
absolute_path_html = os.path.join(os.getcwd(), relative_path_html)
absolute_path_pdf = os.path.join(os.getcwd(), relative_path_pdf)
absolute_path_result = os.path.join(os.getcwd(), "Dictionary/")

# %%
os.chdir(absolute_path_html)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4135/4028394611.py in <module>
# ----> 1 os.chdir(absolute_path_html)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/riya/Downloads/ADT/2015-16/HTML/Output_html_Chapter1/kaggle/working/out/output/HTML/Output_html_Chapter1/kaggle/working/out/output/'

# %%
absolute_path_html
# Out:
# '/home/riya/Downloads/ADT/2015-16/HTML/Output_html_Chapter1/kaggle/working/out/output/HTML/Output_html_Chapter1/kaggle/working/out/output/'

# %%
os.listdir(absolute_path_html)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4135/2949927607.py in <module>
# ----> 1 os.listdir(absolute_path_html)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/riya/Downloads/ADT/2015-16/HTML/Output_html_Chapter1/kaggle/working/out/output/HTML/Output_html_Chapter1/kaggle/working/out/output/'

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(os.getcwd()): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = os.path.join(os.getcwd(), file)
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)

# %%
output_list
# Out:
# [[['1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA',
#    '1.10 ffl DISTRICT INCOME OF KARNATAKA'],
#   ['Sl.No',
#    'District',
#    'At Current Prices 2013-14',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices',
#    'At Constant 2011-12 Prices',
#    'Per capita NDDP In Rs.',
#    'Per capita NDDP In Rs.'],
#   ['Sl.No',
#    'District',
#    'Gross District Domestic Product GDDP Rs. inLakhs',
#    'Net District Domestic Product NDDP Rs. inLakhs',
#    'Gross District Domestic Product GDDP Rs. inLakhs',
#    'Net District Domestic Product NDDP Rs. inLakhs',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices'],
#   ['1', '2', '52', '53', '54', '55', '56', '57']],
#  [['General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.',
#    'General Information1.1 Nada Offices Village Accountant Circles Hoblies Grama Panchayaths Taluks on 31.03.2016.'],
#   ['',
#    'ffl',
#    'Nada Offices',
#    'Circles',
#    'Hoblies',
#    'Grama Panchayaths',
#    'No.of Taluks'],
#   ['1', '2', '3', '4', '5', '6', '7']],
#  [['1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 Efi No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census'],
#   ['Sl.No',
#    'Districts',
#    '2011g twCities Towns Urban',
#    '201 Villages',
#    '201 Villages',
#    'TOTAL Villages'],
#   ['Sl.No',
#    'Districts',
#    '2011g twCities Towns Urban',
#    'Inhabited',
#    'Efi Un-inhabited',
#    'TOTAL Villages'],
#   ['1', '2', '8', '9', '10', '11']],
#  [['1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos',
#    '1.5 No.of Fire Stations on 31.3.2016 In Nos'],
#   ['',
#    'ffl',
#    'FireBrigade Stations',
#    'WorkingFireBrigadeWaterTankers',
#    'Emergencyfirecall received',
#    'Valueofthes property protected'],
#   ['1', '2', '24', '25', '26', '27']],
#  [['1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos',
#    '1.8 .Jfl No.of A.P.L. Non-Priority Card Holders on 31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl',
#    'APL Card Holders Jfl'],
#   ['Sl.No.',
#    'Districts',
#    'WithCylinder',
#    'WithCylinder',
#    'WithCylinder',
#    'Without Cylinder',
#    'Without Cylinder',
#    'Without Cylinder'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'tRural',
#    'Total',
#    'Urban',
#    'tRural',
#    'Total'],
#   ['1', '2', '40', '41', '42', '43', '44', '45']],
#  [['1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos',
#    '1.3 Urban Local Bodies on 31.3.2016 In Nos'],
#   ['',
#    'ffl',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies',
#    'Urba cal Bodies'],
#   ['', 'ffl', 'CC', 'CMC', 'TMC', 'TP', 'NACs', 'TOTAL'],
#   ['1', '2', '12', '13', '14', '15', '16', '17']],
#  [['1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos',
#    '1.4 US Cinema Theatres Police Station Prisons and Prisoners on 31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'Cin Theatres',
#    'ema PoliceStations',
#    'ema PoliceStations',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016',
#    'Prisons Prisoners 31.03.2016'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'ema PoliceStations',
#    'ema PoliceStations',
#    'Prisons',
#    'Prisons',
#    'Prisoner',
#    'Prisoner',
#    'Prisoner'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'ema PoliceStations',
#    'ema PoliceStations',
#    'Prisons',
#    'Prisons',
#    'Male',
#    'Male',
#    'Female'],
#   ['1',
#    '2',
#    '2',
#    '2',
#    '2',
#    '18',
#    '18',
#    '19',
#    '19',
#    '20',
#    '20',
#    '21',
#    '21',
#    '22',
#    '22',
#    '23']],
#  [['1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31.3.2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders'],
#   ['Sl.No',
#    'Districts',
#    'Urban',
#    'Rural',
#    'Total',
#    'Urban',
#    'tRural',
#    'Total'],
#   ['1', '2', '46', '47', '48', '49', '50', '51']],
#  [['1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos',
#    '1.7 .Jfl BPL Priority Card Holders on 31.3.2016 In Nos'],
#   ['',
#    '.ffl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl',
#    'BPLCardHolders Jfl'],
#   ['',
#    '.ffl',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshayawithcylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder'],
#   ['', '.ffl', 'Urban', 'tRural', 'Total', 'gUrban', 'Rural', 'Total'],
#   ['1', '2', '34', '35', '36', '37', '38', '39']],
#  [['1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos',
#    '1.6 CAU .Jfl RATION SHOPS AND B.P.L. RATION CARD HOLDERS on 31.3.2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'BPL Card Holders Jfl',
#    'BPL Card Holders Jfl',
#    'BPL Card Holders Jfl'],
#   ['Sl.No.',
#    'Districts',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'CAU Ration shops',
#    'CAv Anthyodaya',
#    'CAv Anthyodaya',
#    'CAv Anthyodaya'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'tRural',
#    'Total',
#    'Urban',
#    'tRural',
#    'Total'],
#   ['1', '2', '28', '29', '30', '31', '32', '33']]]

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['ema', '201', '.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2016', '31.3.201', '31.3.2016', '31.3.2016.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')
    
    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = { "1.10f" : "1.10", "capitaNDDP" : "capita NDDP", "Information1.1" : "Information 1.1", "ACircles" : "VA Circles", "twCities" : "Cities", "Emerg" : "Emergency", "callsreceived" : "calls received", "Valueofthes" : "Value of the", "thepropertyprotected" : "the property protected", "1.8 .Jfl" : "1.8", "tRural" : "Rural", "1.7 .Jfl" : "1.7", "BPLCard" : "BPL Card", "withcylinder" : "with cylinder", "gUrban" : "Urban", "Urb" : "Urban", "cal" : "Local", "on" : "on 31-03-2016", "Cin" : "Cinema", "Prisons Prisoners" : "Prisons and Prisoners 31-03-2016", "BPLCardHolders" : "BPL Card Holders", "Akshayawithcylinder" : "Akshaya with cylinder", "gUrban" : "Urban", "US Cinema" : "Cinema", "Urba" : "Urban" }

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(output_list)
output_list
# Out:
# [[['1.10 District Income Of Karnataka',
#    '1.10 District Income Of Karnataka',
#    '1.10 District Income Of Karnataka',
#    '1.10 District Income Of Karnataka',
#    '1.10 District Income Of Karnataka',
#    '1.10 District Income Of Karnataka',
#    '1.10 District Income Of Karnataka',
#    '1.10 District Income Of Karnataka'],
#   ['Sl.No',
#    'District',
#    'At Current Prices 2013-14',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices',
#    'At Constant 2011-12 Prices',
#    'Per capita Nddp In Rs.',
#    'Per capita Nddp In Rs.'],
#   ['Sl.No',
#    'District',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    'At Current Prices 2013-14',
#    'At Constant 2011-12 Prices'],
#   ['1', '2', '52', '53', '54', '55', '56', '57']],
#  [['', '', '', '', '', '', ''],
#   ['',
#    '',
#    'Nada Offices',
#    'Circles',
#    'Hoblies',
#    'Grama Panchayaths',
#    'No.of Taluks'],
#   ['1', '2', '3', '4', '5', '6', '7']],
#  [['1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    '1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census'],
#   ['Sl.No',
#    'Districts',
#    'Cities Towns Urban',
#    'Villages',
#    'Villages',
#    'Total Villages'],
#   ['Sl.No',
#    'Districts',
#    'Cities Towns Urban',
#    'Inhabited',
#    'Un-inhabited',
#    'Total Villages'],
#   ['1', '2', '8', '9', '10', '11']],
#  [['1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    '1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    '1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    '1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    '1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    '1.5 No.of Fire Stations on 31-03-2016 In Nos'],
#   ['',
#    '',
#    'Fire Brigade Stations',
#    'Working Fire Brigade Water Tankers',
#    'Emergencyfirecall received',
#    'Value of the property protected'],
#   ['1', '2', '24', '25', '26', '27']],
#  [['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    '1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    '1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    '1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    '1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    '1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    '1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    '1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders',
#    'Apl Card Holders'],
#   ['Sl.No.',
#    'Districts',
#    'With Cylinder',
#    'With Cylinder',
#    'With Cylinder',
#    'Without Cylinder',
#    'Without Cylinder',
#    'Without Cylinder'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'Rural',
#    'Total',
#    'Urban',
#    'Rural',
#    'Total'],
#   ['1', '2', '40', '41', '42', '43', '44', '45']],
#  [['1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    '1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    '1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    '1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    '1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    '1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    '1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    '1.3 Urban Local Bodies on 31-03-2016 In Nos'],
#   ['',
#    '',
#    'Urban Local Bodies',
#    'Urban Local Bodies',
#    'Urban Local Bodies',
#    'Urban Local Bodies',
#    'Urban Local Bodies',
#    'Urban Local Bodies'],
#   ['', '', 'Cc', 'Cmc', 'Tmc', 'Tp', 'NACs', 'Total'],
#   ['1', '2', '12', '13', '14', '15', '16', '17']],
#  [['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    '1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Cinema Theatres',
#    'Cinema Theatres',
#    'Cinema Theatres',
#    'Cinema Theatres',
#    'Police Stations',
#    'Police Stations',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisons and Prisoners 31-03-2016'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'Police Stations',
#    'Police Stations',
#    'Prisons',
#    'Prisons',
#    'Prisoner',
#    'Prisoner',
#    'Prisoner'],
#   ['Sl.No',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Districts',
#    'Permanent',
#    'Permanent',
#    'Temporary',
#    'Temporary',
#    'Police Stations',
#    'Police Stations',
#    'Prisons',
#    'Prisons',
#    'Male',
#    'Male',
#    'Female'],
#   ['1',
#    '2',
#    '2',
#    '2',
#    '2',
#    '18',
#    '18',
#    '19',
#    '19',
#    '20',
#    '20',
#    '21',
#    '21',
#    '22',
#    '22',
#    '23']],
#  [['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    '1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos'],
#   ['Sl.No',
#    'Districts',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Total Ration Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders',
#    'Photo Card Holders'],
#   ['Sl.No', 'Districts', 'Urban', 'Rural', 'Total', 'Urban', 'Rural', 'Total'],
#   ['1', '2', '46', '47', '48', '49', '50', '51']],
#  [['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    '1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    '1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    '1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    '1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    '1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    '1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    '1.7 Bpl Priority Card Holders on 31-03-2016 In Nos'],
#   ['',
#    '',
#    'Bpl Card Holders',
#    'Bpl Card Holders',
#    'Bpl Card Holders',
#    'Bpl Card Holders',
#    'Bpl Card Holders',
#    'Bpl Card Holders'],
#   ['',
#    '',
#    'Akshaya with cylinder',
#    'Akshaya with cylinder',
#    'Akshaya with cylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder',
#    'Akshaya without cylinder'],
#   ['', '', 'Urban', 'Rural', 'Total', 'Urban', 'Rural', 'Total'],
#   ['1', '2', '34', '35', '36', '37', '38', '39']],
#  [['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    '1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    '1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    '1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    '1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    '1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    '1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    '1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos'],
#   ['Sl.No.',
#    'Districts',
#    'Ration shops',
#    'Ration shops',
#    'Ration shops',
#    'Bpl Card Holders',
#    'Bpl Card Holders',
#    'Bpl Card Holders'],
#   ['Sl.No.',
#    'Districts',
#    'Ration shops',
#    'Ration shops',
#    'Ration shops',
#    'Anthyodaya',
#    'Anthyodaya',
#    'Anthyodaya'],
#   ['Sl.No.',
#    'Districts',
#    'Urban',
#    'Rural',
#    'Total',
#    'Urban',
#    'Rural',
#    'Total'],
#   ['1', '2', '28', '29', '30', '31', '32', '33']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['1.10 District Income Of Karnataka', 'Sl.No', 'Sl.No', '1'],
#   ['1.10 District Income Of Karnataka', 'District', 'District', '2'],
#   ['1.10 District Income Of Karnataka',
#    'At Current Prices 2013-14',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    '52'],
#   ['1.10 District Income Of Karnataka',
#    'At Current Prices 2013-14',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    '53'],
#   ['1.10 District Income Of Karnataka',
#    'At Constant 2011-12 Prices',
#    'Gross District Domestic Product Gddp Rs. in Lakhs',
#    '54'],
#   ['1.10 District Income Of Karnataka',
#    'At Constant 2011-12 Prices',
#    'Net District Domestic Product Nddp Rs. in Lakhs',
#    '55'],
#   ['1.10 District Income Of Karnataka',
#    'Per capita Nddp In Rs.',
#    'At Current Prices 2013-14',
#    '56'],
#   ['1.10 District Income Of Karnataka',
#    'Per capita Nddp In Rs.',
#    'At Constant 2011-12 Prices',
#    '57']],
#  [['', '', '1'],
#   ['', '', '2'],
#   ['', 'Nada Offices', '3'],
#   ['', 'Circles', '4'],
#   ['', 'Hoblies', '5'],
#   ['', 'Grama Panchayaths', '6'],
#   ['', 'No.of Taluks', '7']],
#  [['1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    'Cities Towns Urban',
#    'Cities Towns Urban',
#    '8'],
#   ['1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    'Villages',
#    'Inhabited',
#    '9'],
#   ['1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    'Villages',
#    'Un-inhabited',
#    '10'],
#   ['1.2 No.of Taluks Inhabited Un-inhabited and Total Villages Nos. per 2011 Census',
#    'Total Villages',
#    'Total Villages',
#    '11']],
#  [['1.5 No.of Fire Stations on 31-03-2016 In Nos', '', '1'],
#   ['1.5 No.of Fire Stations on 31-03-2016 In Nos', '', '2'],
#   ['1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    'Fire Brigade Stations',
#    '24'],
#   ['1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    'Working Fire Brigade Water Tankers',
#    '25'],
#   ['1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    'Emergencyfirecall received',
#    '26'],
#   ['1.5 No.of Fire Stations on 31-03-2016 In Nos',
#    'Value of the property protected',
#    '27']],
#  [['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Apl Card Holders',
#    'With Cylinder',
#    'Urban',
#    '40'],
#   ['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Apl Card Holders',
#    'With Cylinder',
#    'Rural',
#    '41'],
#   ['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Apl Card Holders',
#    'With Cylinder',
#    'Total',
#    '42'],
#   ['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Apl Card Holders',
#    'Without Cylinder',
#    'Urban',
#    '43'],
#   ['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Apl Card Holders',
#    'Without Cylinder',
#    'Rural',
#    '44'],
#   ['1.8 No.of A.p.l. Non-Priority Card Holders on 31-03-2016 In Nos',
#    'Apl Card Holders',
#    'Without Cylinder',
#    'Total',
#    '45']],
#  [['1.3 Urban Local Bodies on 31-03-2016 In Nos', '', '', '1'],
#   ['1.3 Urban Local Bodies on 31-03-2016 In Nos', '', '', '2'],
#   ['1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    'Urban Local Bodies',
#    'Cc',
#    '12'],
#   ['1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    'Urban Local Bodies',
#    'Cmc',
#    '13'],
#   ['1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    'Urban Local Bodies',
#    'Tmc',
#    '14'],
#   ['1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    'Urban Local Bodies',
#    'Tp',
#    '15'],
#   ['1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    'Urban Local Bodies',
#    'NACs',
#    '16'],
#   ['1.3 Urban Local Bodies on 31-03-2016 In Nos',
#    'Urban Local Bodies',
#    'Total',
#    '17']],
#  [['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Cinema Theatres',
#    'Permanent',
#    'Permanent',
#    '18'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Cinema Theatres',
#    'Permanent',
#    'Permanent',
#    '18'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Cinema Theatres',
#    'Temporary',
#    'Temporary',
#    '19'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Cinema Theatres',
#    'Temporary',
#    'Temporary',
#    '19'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Police Stations',
#    'Police Stations',
#    'Police Stations',
#    '20'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Police Stations',
#    'Police Stations',
#    'Police Stations',
#    '20'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisons',
#    'Prisons',
#    '21'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisons',
#    'Prisons',
#    '21'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisoner',
#    'Male',
#    '22'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisoner',
#    'Male',
#    '22'],
#   ['1.4 Cinema Theatres Police Station Prisons and Prisoners on 31-03-2016 In Nos',
#    'Prisons and Prisoners 31-03-2016',
#    'Prisoner',
#    'Female',
#    '23']],
#  [['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Total Ration Card Holders',
#    'Urban',
#    '46'],
#   ['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Total Ration Card Holders',
#    'Rural',
#    '47'],
#   ['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Total Ration Card Holders',
#    'Total',
#    '48'],
#   ['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Photo Card Holders',
#    'Urban',
#    '49'],
#   ['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Photo Card Holders',
#    'Rural',
#    '50'],
#   ['1.9 Total Ration Card Holders Photo Card Holders on 31-03-2016 In Nos',
#    'Photo Card Holders',
#    'Total',
#    '51']],
#  [['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos', '', '', '', '1'],
#   ['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos', '', '', '', '2'],
#   ['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Akshaya with cylinder',
#    'Urban',
#    '34'],
#   ['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Akshaya with cylinder',
#    'Rural',
#    '35'],
#   ['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Akshaya with cylinder',
#    'Total',
#    '36'],
#   ['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Akshaya without cylinder',
#    'Urban',
#    '37'],
#   ['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Akshaya without cylinder',
#    'Rural',
#    '38'],
#   ['1.7 Bpl Priority Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Akshaya without cylinder',
#    'Total',
#    '39']],
#  [['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Ration shops',
#    'Ration shops',
#    'Urban',
#    '28'],
#   ['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Ration shops',
#    'Ration shops',
#    'Rural',
#    '29'],
#   ['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Ration shops',
#    'Ration shops',
#    'Total',
#    '30'],
#   ['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Anthyodaya',
#    'Urban',
#    '31'],
#   ['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Anthyodaya',
#    'Rural',
#    '32'],
#   ['1.6 Ration Shops And B.p.l. Ration Card Holders on 31-03-2016 In Nos',
#    'Bpl Card Holders',
#    'Anthyodaya',
#    'Total',
#    '33']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 1
chapter_name = "General Information"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id, table_name = find_table_details(inner_list[0][0])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list):
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT/2015-16/HTML/Output_html_Chapter1/Chapter1_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT/2015-16/Dictionary/Chapter1_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)
