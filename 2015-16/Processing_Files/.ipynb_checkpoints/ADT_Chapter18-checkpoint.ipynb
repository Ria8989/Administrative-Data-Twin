# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
relative_path_html = "../HTML/Output_html_Chapter18/kaggle/working/out/output/"
relative_path_pdf = "../HTML/Output_html_Chapter18/kaggle/working/out/pages/"
relative_dictionary_path = "../Dictionary/Chapter18_Attributes.csv"
relative_result_path = "../HTML/Output_html_Chapter18/Chapter18_Attributes.csv"
# Get the absolute path by joining the current directory with the relative path
absolute_path_html = os.path.join(os.getcwd(), relative_path_html)
absolute_path_pdf = os.path.join(os.getcwd(), relative_path_pdf)
absolute_dictionary_path = os.path.join(os.getcwd(), relative_dictionary_path)
absolute_result_path = os.path.join(os.getcwd(), relative_result_path)

# %%
absolute_path_html
# Out:
# '/home/riya/Downloads/ADT/2015-16/Processing_Files/../HTML/Output_html_Chapter18/kaggle/working/out/output/'

# %%
os.listdir(absolute_path_html)
# Out:
# ['output_page_18.html',
#  'output_page_15.html',
#  'output_page_10.html',
#  'output_page_16.html',
#  'output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_11.html',
#  'output_page_8.html',
#  'output_page_21.html',
#  'output_page_19.html',
#  'output_page_3.html',
#  'output_page_13.html',
#  'output_page_20.html',
#  'output_page_4.html',
#  'output_page_22.html',
#  'output_page_23.html',
#  'output_page_14.html',
#  'output_page_9.html',
#  'output_page_12.html',
#  'output_page_17.html',
#  'output_page_7.html',
#  'output_page_6.html',
#  'output_page_24.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(absolute_path_html): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = os.path.join(absolute_path_html, file)
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)

# %%
output_list
# Out:
# [[['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'rge Agrl. Land Holder More than10 Ha. ST',
#    'rge Agrl. Land Holder More than10 Ha. ST',
#    'rge Agrl. Land Holder More than10 Ha. ST',
#    'rge Agrl. Land Holder More than10 Ha. ST',
#    'rge Agrl. Land Holder More than10 Ha. ST',
#    'rge Agrl. Land Holder More than10 Ha. ST',
#    'rge Agrl. Land Holder More than10 Ha. ST',
#    'rge Agrl. Land Holder More than10 Ha. ST'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1128', '1129', '1130', '1131', '1132', '1133', '1134', '1135']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1104', '1105', '1106', '1107', '1108', '1109', '1110', '1111']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['',
#    'ffl',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST',
#    'AUS qem Medium Agril. Land Holder 2-4Ha. ST'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1064', '1065', '1066', '1067', '1068', '1069', '1070', '1071']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    'ffl',
#    'edium Agril. Land Holder 4-10 Ha. Total',
#    'edium Agril. Land Holder 4-10 Ha. Total',
#    'edium Agril. Land Holder 4-10 Ha. Total',
#    'edium Agril. Land Holder 4-10 Ha. Total',
#    'edium Agril. Land Holder 4-10 Ha. Total',
#    'edium Agril. Land Holder 4-10 Ha. Total',
#    'edium Agril. Land Holder 4-10 Ha. Total',
#    'edium Agril. Land Holder 4-10 Ha. Total'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1112', '1113', '1114', '1115', '1116', '1117', '1118', '1119']],
#  [['18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.3 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census'],
#   ['',
#    'ffl',
#    'Marginal Agril. Land Holder Below1Ha. SC',
#    'Marginal Agril. Land Holder Below1Ha. SC',
#    'Marginal Agril. Land Holder Below1Ha. SC',
#    'Marginal Agril. Land Holder Below1Ha. SC',
#    'Marginal Agril. Land Holder Below1Ha. SC',
#    'Marginal Agril. Land Holder Below1Ha. SC',
#    'Marginal Agril. Land Holder Below1Ha. SC',
#    'Marginal Agril. Land Holder Below1Ha. SC'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['', 'ffl', '', '', '', '', '', '', '', ''],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '992', '993', '994', '995', '996', '997', '998', '999']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1000', '1001', '1002', '1003', '1004', '1005', '1006', '1007']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census'],
#   ['',
#    'ffl',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'gAW Institutions',
#    'Total'],
#   ['1', '2', '1024', '1025', '1026', '1027', '1028', '1029', '1030', '1031']],
#  [['18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3P AGRICULTURAL LAND HOLDINGS AND AREA 2010-11'],
#   ['Sl.No',
#    'District',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS egm Medium Agril. Land Holder 2-4 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1072', '1073', '1074', '1075', '1076', '1077', '1078', '1079']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census'],
#   ['',
#    'ffl',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total'],
#   ['', 'ffl', 'mber', 'mber', 'mber', 'mber', 'Area', 'Area', 'Area', 'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1048', '1049', '1050', '1051', '1052', '1053', '1054', '1055']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    ''],
#   ['Sl.No',
#    'District',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    ''],
#   ['Sl.No',
#    'District',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1152',
#    '1153',
#    '1154',
#    '1155',
#    '1156',
#    '1157',
#    '1158',
#    '1159',
#    '1159']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['',
#    'ffl',
#    'arge Agrl. Land Holder More than10 Ha. Others',
#    'arge Agrl. Land Holder More than10 Ha. Others',
#    'arge Agrl. Land Holder More than10 Ha. Others',
#    'arge Agrl. Land Holder More than10 Ha. Others',
#    'arge Agrl. Land Holder More than10 Ha. Others',
#    'arge Agrl. Land Holder More than10 Ha. Others',
#    'arge Agrl. Land Holder More than10 Ha. Others',
#    'arge Agrl. Land Holder More than10 Ha. Others'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1136', '1137', '1138', '1139', '1140', '1141', '1142', '1143']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census'],
#   ['',
#    'ffl',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1008', '1009', '1010', '1011', '1012', '1013', '1014', '1015']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'edium Agril. Land Holder 4-10 Ha. SC',
#    'edium Agril. Land Holder 4-10 Ha. SC',
#    'edium Agril. Land Holder 4-10 Ha. SC',
#    'edium Agril. Land Holder 4-10 Ha. SC',
#    'edium Agril. Land Holder 4-10 Ha. SC',
#    'edium Agril. Land Holder 4-10 Ha. SC',
#    'edium Agril. Land Holder 4-10 Ha. SC',
#    'edium Agril. Land Holder 4-10 Ha. SC'],
#   ['Sl.No',
#    'District',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1088', '1089', '1090', '1091', '1092', '1093', '1094', '1095']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['',
#    'ffl',
#    'Large Agrl. Land Holder More than10 Ha. Total',
#    'Large Agrl. Land Holder More than10 Ha. Total',
#    'Large Agrl. Land Holder More than10 Ha. Total',
#    'Large Agrl. Land Holder More than10 Ha. Total',
#    'Large Agrl. Land Holder More than10 Ha. Total',
#    'Large Agrl. Land Holder More than10 Ha. Total',
#    'Large Agrl. Land Holder More than10 Ha. Total',
#    'Large Agrl. Land Holder More than10 Ha. Total'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1144', '1145', '1146', '1147', '1148', '1149', '1150', '1151']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total'],
#   ['Sl.No',
#    'District',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '1016',
#    '1017',
#    '1018',
#    '1019',
#    '1020',
#    '1021',
#    '1022',
#    '1023',
#    '']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'AUT Agrl. Land Holder ST',
#    'AUT Agrl. Land Holder ST',
#    'AUT Agrl. Land Holder ST',
#    'AUT Agrl. Land Holder ST',
#    'AUT Agrl. Land Holder ST',
#    'AUT Agrl. Land Holder ST',
#    'AUT Agrl. Land Holder ST',
#    'AUT Agrl. Land Holder ST'],
#   ['Sl.No',
#    'District',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1160', '1161', '1162', '1163', '1164', '1165', '1166', '1167']],
#  [['AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
#    'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census'],
#   ['Sl.No.',
#    'Districts',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others'],
#   ['Sl.No.',
#    'Districts',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1168', '1169', '1170', '1171', '1172', '1173', '1174', '1175']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    'ffl',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST',
#    'AUM qed ium Agril. Land Holder 4-10 Ha. ST'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1096', '1097', '1098', '1099', '1100', '1101', '1102', '1103']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC',
#    'wSe Medium Agril. Land Holder 2-4Ha. SC'],
#   ['Sl.No',
#    'District',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1056', '1057', '1058', '1059', '1060', '1061', '1062', '1063']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11'],
#   ['',
#    'ffl',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1080', '1081', '1082', '1083', '1084', '1085', '1086', '1087']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    ''],
#   ['Sl.No',
#    'District',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    'Large Agrl. Land Holder More than10 Ha. SC',
#    ''],
#   ['Sl.No',
#    'District',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1120',
#    '1121',
#    '1122',
#    '1123',
#    '1124',
#    '1125',
#    '1126',
#    '1127',
#    '1127']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    ''],
#   ['Sl.No',
#    'District',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    'gSm allAgril. Land Holder 2 Ha. Others',
#    ''],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1040',
#    '1041',
#    '1042',
#    '1043',
#    '1044',
#    '1045',
#    '1046',
#    '1047',
#    '1047']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11Census'],
#   ['Sl. No.',
#    'Districts',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST'],
#   ['Sl. No.',
#    'Districts',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl. No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1032', '1033', '1034', '1035', '1036', '1037', '1038', '1039']],
#  [['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    ''],
#   ['',
#    'ffl',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    ''],
#   ['',
#    'ffl',
#    'mber',
#    'mber',
#    'mber',
#    'mber',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1176',
#    '1177',
#    '1178',
#    '1179',
#    '1180',
#    '1181',
#    '1182',
#    '1183',
#    '1183']]]

# %%
list_to_remove = [[['AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   'AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census'],
  ['Sl.No.',
   'Districts',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others'],
  ['Sl.No.',
   'Districts',
   'umber',
   'umber',
   'umber',
   'umber',
   'Area',
   'Area',
   'Area',
   'Area'],
  ['Sl.No.',
   'Districts',
   'Male',
   'Female',
   'Institutions',
   'Total',
   'Male',
   'Female',
   'Institutions',
   'Total'],
  ['1', '2', '1168', '1169', '1170', '1171', '1172', '1173', '1174', '1175']]]

# %%
for item in list_to_remove:
    output_list.remove(item)

# %%
list_to_add = [[['18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census',
   '18.3 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Agri.Census'],
  ['Sl.No.',
   'Districts',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others',
   'Total Agrl. Land Holder Others'],
  ['Sl.No.',
   'Districts',
   'umber',
   'umber',
   'umber',
   'umber',
   'Area',
   'Area',
   'Area',
   'Area'],
  ['Sl.No.',
   'Districts',
   'Male',
   'Female',
   'Institutions',
   'Total',
   'Male',
   'Female',
   'Institutions',
   'Total'],
  ['1', '2', '1168', '1169', '1170', '1171', '1172', '1173', '1174', '1175']]]

output_list.extend(list_to_add)

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['31.03.2015', 'UAS', 'llsAi', 'ASN', 'mez', '3 jAz 6', 'AASU', 'tAvP', 'uka', 'QjAi', 'flAi', '30.9.2015', 'iaxled', '2005Dy', 'zPr', 'AUq', 'MAz', 'sfi', 'Raing', 'ema', '.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2005 jAz 2015', '2006 jAz 2016', '2011 twAi rAi AaP fiU %', '2011 twAi wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2016', '31.3.201', '31.3.2016', '31.3.2016.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'tP', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')
    
    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = { "rge" : "Large", "than10" : "than 10", "qLa rge" : "Large", "Morethan10" : "More than 10", "mber" : "Number", "umber" : "Number", "dium" : "Medium", "AUS qem" : "Semi", "edium" : "Medium", "w18.1" : "18.1", "AGRICULTURALLAND" : "AGRICULTURAL LAND", "arginal" : "Marginal", "EvS gem" : "Semi", "arge" : "Large", "than10" : "than 10", "gM arginal" : "Marginal", "Tqot alAgrl." : "Total Agrl.", "otal" : "Total", "qMe ium" : "Medium", "wSem" : "Semi", "emi" : "Semi", "MlTotal" : "Total", "allAgril." : "Small Agril.", "qSm all" : "Small", "than10" : "than 10", "2010-11Census" : "2010-11 Census", "4-10Ha." : "4-10 Ha.", "1Ha." : "1 Ha.", "2-4Ha." : "2-4 Ha.", "Below1Ha." : "Below 1 Ha.", "EvS egm" : "Semi", "AUT" : "Total", "AUM qed ium" : "Medium", "wSe" : "Semi", "emi" : "Semi", "gSm allAgril." : "Small Agril.", "qSm all" : "Small", "18.3P" : "18.3", "Area 2010-11" : "Area per 2010-11 Census"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(output_list)
output_list
# Out:
# [[['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1128', '1129', '1130', '1131', '1132', '1133', '1134', '1135']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1104', '1105', '1106', '1107', '1108', '1109', '1110', '1111']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1064', '1065', '1066', '1067', '1068', '1069', '1070', '1071']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    '',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1112', '1113', '1114', '1115', '1116', '1117', '1118', '1119']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['', '', '', '', '', '', '', '', '', ''],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '992', '993', '994', '995', '996', '997', '998', '999']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1000', '1001', '1002', '1003', '1004', '1005', '1006', '1007']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'g Aw Institutions',
#    'Total'],
#   ['1', '2', '1024', '1025', '1026', '1027', '1028', '1029', '1030', '1031']],
#  [['18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11'],
#   ['Sl.No',
#    'District',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1072', '1073', '1074', '1075', '1076', '1077', '1078', '1079']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1048', '1049', '1050', '1051', '1052', '1053', '1054', '1055']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    ''],
#   ['Sl.No',
#    'District',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    ''],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1152',
#    '1153',
#    '1154',
#    '1155',
#    '1156',
#    '1157',
#    '1158',
#    '1159',
#    '1159']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Large Agrl. Land Holder More than 10 Ha. Others'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1136', '1137', '1138', '1139', '1140', '1141', '1142', '1143']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1008', '1009', '1010', '1011', '1012', '1013', '1014', '1015']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Medium Agril. Land Holder 4-10 Ha. Sc'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1088', '1089', '1090', '1091', '1092', '1093', '1094', '1095']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Large Agrl. Land Holder More than 10 Ha. Total'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1144', '1145', '1146', '1147', '1148', '1149', '1150', '1151']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '1016',
#    '1017',
#    '1018',
#    '1019',
#    '1020',
#    '1021',
#    '1022',
#    '1023',
#    '']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1160', '1161', '1162', '1163', '1164', '1165', '1166', '1167']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.3 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    '',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1096', '1097', '1098', '1099', '1100', '1101', '1102', '1103']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1056', '1057', '1058', '1059', '1060', '1061', '1062', '1063']],
#  [['18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11',
#    '18.3 Agricultural Land Holdings And Area 2010-11'],
#   ['',
#    '',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1080', '1081', '1082', '1083', '1084', '1085', '1086', '1087']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    ''],
#   ['Sl.No',
#    'District',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    ''],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1120',
#    '1121',
#    '1122',
#    '1123',
#    '1124',
#    '1125',
#    '1126',
#    '1127',
#    '1127']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    ''],
#   ['Sl.No',
#    'District',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    ''],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1040',
#    '1041',
#    '1042',
#    '1043',
#    '1044',
#    '1045',
#    '1046',
#    '1047',
#    '1047']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl. No.',
#    'Districts',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St'],
#   ['Sl. No.',
#    'Districts',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl. No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1032', '1033', '1034', '1035', '1036', '1037', '1038', '1039']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    ''],
#   ['',
#    '',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    ''],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1176',
#    '1177',
#    '1178',
#    '1179',
#    '1180',
#    '1181',
#    '1182',
#    '1183',
#    '1183']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census'],
#   ['Sl.No.',
#    'Districts',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others'],
#   ['Sl.No.',
#    'Districts',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1168', '1169', '1170', '1171', '1172', '1173', '1174', '1175']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Male',
#    '1128'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Female',
#    '1129'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Institutions',
#    '1130'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Total',
#    '1131'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Male',
#    '1132'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Female',
#    '1133'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Institutions',
#    '1134'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Total',
#    '1135']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Male',
#    '1104'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Female',
#    '1105'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Institutions',
#    '1106'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Total',
#    '1107'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Male',
#    '1108'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Female',
#    '1109'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Institutions',
#    '1110'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Total',
#    '1111']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Male',
#    '1064'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Female',
#    '1065'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Institutions',
#    '1066'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Total',
#    '1067'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Male',
#    '1068'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Female',
#    '1069'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Institutions',
#    '1070'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Total',
#    '1071']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Male',
#    '1112'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Female',
#    '1113'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Institutions',
#    '1114'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Total',
#    '1115'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Male',
#    '1116'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Female',
#    '1117'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Institutions',
#    '1118'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Total',
#    '1119']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    '',
#    'Male',
#    '992'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    '',
#    'Female',
#    '993'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    '',
#    'Institutions',
#    '994'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    '',
#    'Total',
#    '995'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    '',
#    'Male',
#    '996'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    '',
#    'Female',
#    '997'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    '',
#    'Institutions',
#    '998'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    '',
#    'Total',
#    '999']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Male',
#    '1000'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Female',
#    '1001'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Institutions',
#    '1002'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Total',
#    '1003'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Male',
#    '1004'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Female',
#    '1005'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Institutions',
#    '1006'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Total',
#    '1007']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Male',
#    '1024'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Female',
#    '1025'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Institutions',
#    '1026'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Total',
#    '1027'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'Male',
#    '1028'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'Female',
#    '1029'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'g Aw Institutions',
#    '1030'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'Total',
#    '1031']],
#  [['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Male',
#    '1072'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Female',
#    '1073'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Institutions',
#    '1074'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Total',
#    '1075'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Male',
#    '1076'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Female',
#    '1077'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Institutions',
#    '1078'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Total',
#    '1079']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Male',
#    '1048'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Female',
#    '1049'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Institutions',
#    '1050'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Total',
#    '1051'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Male',
#    '1052'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Female',
#    '1053'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Institutions',
#    '1054'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Total',
#    '1055']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Male',
#    '1152'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Female',
#    '1153'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Institutions',
#    '1154'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Total',
#    '1155'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Male',
#    '1156'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Female',
#    '1157'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Institutions',
#    '1158'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Total',
#    '1159'],
#   ['', '', '', 'Total', '1159']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Number',
#    'Male',
#    '1136'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Number',
#    'Female',
#    '1137'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Number',
#    'Institutions',
#    '1138'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Number',
#    'Total',
#    '1139'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Area',
#    'Male',
#    '1140'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Area',
#    'Female',
#    '1141'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Area',
#    'Institutions',
#    '1142'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Others',
#    'Area',
#    'Total',
#    '1143']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Male',
#    '1008'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Female',
#    '1009'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Institutions',
#    '1010'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Total',
#    '1011'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Male',
#    '1012'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Female',
#    '1013'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Institutions',
#    '1014'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Total',
#    '1015']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Number',
#    'Male',
#    '1088'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Number',
#    'Female',
#    '1089'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Number',
#    'Institutions',
#    '1090'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Number',
#    'Total',
#    '1091'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Area',
#    'Male',
#    '1092'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Area',
#    'Female',
#    '1093'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Area',
#    'Institutions',
#    '1094'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Sc',
#    'Area',
#    'Total',
#    '1095']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Number',
#    'Male',
#    '1144'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Number',
#    'Female',
#    '1145'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Number',
#    'Institutions',
#    '1146'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Number',
#    'Total',
#    '1147'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Area',
#    'Male',
#    '1148'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Area',
#    'Female',
#    '1149'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Area',
#    'Institutions',
#    '1150'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Total',
#    'Area',
#    'Total',
#    '1151']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Male',
#    '1016'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Female',
#    '1017'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Institutions',
#    '1018'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Total',
#    '1019'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Male',
#    '1020'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Female',
#    '1021'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Institutions',
#    '1022'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Total',
#    '1023'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    '',
#    '',
#    '']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Male',
#    '1160'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Female',
#    '1161'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Institutions',
#    '1162'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Total',
#    '1163'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Male',
#    '1164'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Female',
#    '1165'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Institutions',
#    '1166'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Total',
#    '1167']],
#  [['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Male',
#    '1096'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Female',
#    '1097'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Institutions',
#    '1098'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Total',
#    '1099'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Male',
#    '1100'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Female',
#    '1101'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Institutions',
#    '1102'],
#   ['18.3 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Total',
#    '1103']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Male',
#    '1056'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Female',
#    '1057'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Institutions',
#    '1058'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Total',
#    '1059'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Male',
#    '1060'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Female',
#    '1061'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Institutions',
#    '1062'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Total',
#    '1063']],
#  [['18.3 Agricultural Land Holdings And Area 2010-11', '', '', '', '1'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11', '', '', '', '2'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Male',
#    '1080'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Female',
#    '1081'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Institutions',
#    '1082'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Total',
#    '1083'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Male',
#    '1084'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Female',
#    '1085'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Institutions',
#    '1086'],
#   ['18.3 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Total',
#    '1087']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Male',
#    '1120'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Female',
#    '1121'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Institutions',
#    '1122'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Total',
#    '1123'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Male',
#    '1124'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Female',
#    '1125'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Institutions',
#    '1126'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Total',
#    '1127'],
#   ['', '', '', 'Total', '1127']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Male',
#    '1040'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Female',
#    '1041'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Institutions',
#    '1042'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Total',
#    '1043'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Male',
#    '1044'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Female',
#    '1045'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Institutions',
#    '1046'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Total',
#    '1047'],
#   ['', '', '', 'Total', '1047']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl. No.',
#    'Sl. No.',
#    'Sl. No.',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Male',
#    '1032'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Female',
#    '1033'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Institutions',
#    '1034'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Total',
#    '1035'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Male',
#    '1036'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Female',
#    '1037'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Institutions',
#    '1038'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Total',
#    '1039']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Male',
#    '1176'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Female',
#    '1177'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Institutions',
#    '1178'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Total',
#    '1179'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Male',
#    '1180'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Female',
#    '1181'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Institutions',
#    '1182'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Total',
#    '1183'],
#   ['', '', '', 'Total', '1183']],
#  [['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Male',
#    '1168'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Female',
#    '1169'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Institutions',
#    '1170'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Total',
#    '1171'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Male',
#    '1172'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Female',
#    '1173'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Institutions',
#    '1174'],
#   ['18.3 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Total',
#    '1175']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 18
chapter_name = "Additional information"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id, table_name = find_table_details(inner_list[0][0])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list):
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv(absolute_result_path, sep=';', index=False)
    df.to_csv(absolute_dictionary_path, sep=';', index=False)

# %%
process_dictionary(transp_list)
