# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
relative_path_html = "../HTML/Output_html_Chapter4/kaggle/working/out/output/"
relative_path_pdf = "../HTML/Output_html_Chapter4/kaggle/working/out/pages/"
relative_dictionary_path = "../Dictionary/Chapter4_Attributes.csv"
relative_result_path = "../HTML/Output_html_Chapter4/Chapter4_Attributes.csv"
# Get the absolute path by joining the current directory with the relative path
absolute_path_html = os.path.join(os.getcwd(), relative_path_html)
absolute_path_pdf = os.path.join(os.getcwd(), relative_path_pdf)
absolute_dictionary_path = os.path.join(os.getcwd(), relative_dictionary_path)
absolute_result_path = os.path.join(os.getcwd(), relative_result_path)

# %%
absolute_path_html
# Out:
# '/home/riya/Downloads/ADT/2015-16/Processing_Files/../HTML/Output_html_Chapter4/kaggle/working/out/output/'

# %%
os.listdir(absolute_path_html)
# Out:
# ['output_page_18.html',
#  'output_page_15.html',
#  'output_page_10.html',
#  'output_page_16.html',
#  'output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_11.html',
#  'output_page_8.html',
#  'output_page_21.html',
#  'output_page_19.html',
#  'output_page_3.html',
#  'output_page_13.html',
#  'output_page_20.html',
#  'output_page_4.html',
#  'output_page_22.html',
#  'output_page_23.html',
#  'output_page_25.html',
#  'output_page_14.html',
#  'output_page_9.html',
#  'output_page_26.html',
#  'output_page_12.html',
#  'output_page_17.html',
#  'output_page_7.html',
#  'output_page_6.html',
#  'output_page_24.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(absolute_path_html): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = os.path.join(absolute_path_html, file)
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)
# Out:
# /home/riya/Downloads/ADT/2015-16/Processing_Files/../HTML/Output_html_Chapter4/kaggle/working/out/output/output_page_4.html

# %%
output_list
# Out:
# [[['4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14',
#    '4.12 jof Important Cro Year 2013-14'],
#   ['Sl.NO',
#    'Districts',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect',
#    'gie Of Pulses K.G Hect'],
#   ['Sl.NO',
#    'Districts',
#    'Tur',
#    'HorseGram',
#    'BlackGram',
#    'Green Gram',
#    'Avare',
#    'Cfi Cowpea',
#    'BengalGram',
#    'Other Pulses',
#    'Total Pulses',
#    'Total Food Grains'],
#   ['1',
#    '2',
#    '285',
#    '286',
#    '287',
#    '288',
#    '289',
#    '290',
#    '291',
#    '292',
#    '293',
#    '294']],
#  [['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15'],
#   ['',
#    'ffl',
#    'Banana',
#    'Mango',
#    'Lemon',
#    'Pine Apple',
#    'Guava',
#    'Grapes',
#    'Sapota',
#    'Poma- granate',
#    'Papaya'],
#   ['1', '2', '259', '260', '261', '262', '263', '264', '265', '266', '267']],
#  [['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes'],
#   ['Sl.No',
#    'Districts',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals'],
#   ['Sl.No',
#    'Districts',
#    'Rice',
#    'Jowar',
#    'Bajra',
#    'Maize',
#    'Ragi',
#    'Wheat',
#    'tzs Total Small Minor Millets',
#    'Total Cereals Minor Millets'],
#   ['1', '2', '223', '224', '225', '226', '227', '228', '229', '230']],
#  [['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15'],
#   ['Sl.No',
#    'Districts',
#    'Dfi Potato',
#    'Tomato',
#    'Brinjal',
#    'Beans',
#    'Cluster Beans',
#    'Onion',
#    'Green Chillies',
#    'Total Leafy Vegetables',
#    'Total Gourd Variety Vegetables',
#    ''],
#   ['1',
#    '2',
#    '268',
#    '269',
#    '270',
#    '271',
#    '272',
#    '273',
#    '274',
#    '275',
#    '276',
#    '']],
#  [['Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares',
#    'Agriculture Horticulture and Sericulture4.1 Pnd Utilisation in Hectares'],
#   ['Sl.No',
#    'District',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15',
#    'and Utilisation 2014-15'],
#   ['Sl.No',
#    'District',
#    'Geo- graphical Area',
#    'Forest',
#    'sfi Land not available for cultivation',
#    'sfi Land not available for cultivation',
#    'sfi Land not available for cultivation',
#    'Other Uncultivated Land',
#    'Other Uncultivated Land',
#    'Other Uncultivated Land',
#    'Other Uncultivated Land'],
#   ['Sl.No',
#    'District',
#    'Geo- graphical Area',
#    'Forest',
#    'Land put to Non- Agricultural uses',
#    'Adg Barren cultivable land',
#    'Total',
#    'Adg Cultivable-waste',
#    'Permanent Pasture',
#    'Trees and Groves',
#    'Total'],
#   ['1', '2', '156', '157', '158', '159', '160', '161', '162', '163', '164']],
#  [['4.1 Pnd Utilisation in Hectares',
#    '4.1 Pnd Utilisation in Hectares',
#    '4.1 Pnd Utilisation in Hectares',
#    '4.1 Pnd Utilisation in Hectares',
#    '4.1 Pnd Utilisation in Hectares',
#    '4.1 Pnd Utilisation in Hectares',
#    '4.1 Pnd Utilisation in Hectares',
#    '4.1 Pnd Utilisation in Hectares'],
#   ['',
#    'ffl',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares'],
#   ['',
#    'ffl',
#    'Fallow Land',
#    'Fallow Land',
#    'Fallow Land',
#    'Area Sown',
#    'Area Sown',
#    'Area Sown'],
#   ['',
#    'ffl',
#    'Current',
#    'Other',
#    'Total',
#    'Net',
#    'MAz More than once',
#    'Total'],
#   ['1', '2', '165', '166', '167', '168', '169', '170']],
#  [['4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15'],
#   ['Sl.No.',
#    'Districts',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.'],
#   ['Sl.No.',
#    'Districts',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.'],
#   ['Sl.No.',
#    'Districts',
#    'Paddy',
#    'Jowar',
#    'Bajra',
#    'Maize',
#    'Ragi',
#    'Wheat',
#    'Other Cereals Minor Millets',
#    'Total Cereals Minor millets'],
#   ['1', '2', '190', '191', '192', '193', '194', '195', '196', '197']],
#  [['4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes',
#    '4.6 uction of portant Cro Year Year 2013-14 in Tonnes'],
#   ['',
#    'ffl',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes',
#    'uction of Pulses In Tonnes'],
#   ['',
#    'ffl',
#    'Tur',
#    'Horse Gram',
#    'BlackGram',
#    'Green Gram',
#    'Avare',
#    'Cfi Cowpea',
#    'BengalGram',
#    'Other Pulses',
#    'Total Pulses',
#    'Total Food Grains'],
#   ['1',
#    '2',
#    '231',
#    '232',
#    '233',
#    '234',
#    '235',
#    '236',
#    '237',
#    '238',
#    '239',
#    '240']],
#  [['4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15'],
#   ['A.P',
#    'ffl',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops'],
#   ['A.P',
#    'ffl',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect'],
#   ['A.P',
#    'ffl',
#    'Ground Nut',
#    'Sun Flower',
#    'Safflower',
#    'Castor',
#    'Sesamum',
#    'Niger seed',
#    'Soyabean',
#    'Linseed',
#    'other oil Seeds',
#    'Total oil Seeds'],
#   ['1',
#    '2',
#    '210',
#    '211',
#    '212',
#    '213',
#    '214',
#    '215',
#    '216',
#    '217',
#    '218',
#    '219']],
#  [['4.15 jYield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 jYield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 jYield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 jYield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 jYield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 jYield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 jYield of Plantation crops in Kgs Hect Year 2013-14'],
#   ['Sl.NO',
#    'Districts',
#    'CrP Arecanut Processed',
#    'KfiQ Cardamom',
#    'Pepper',
#    'Cashewnut Processed',
#    'Cocoa M.Tonnes Hect'],
#   ['1', '2', '307', '308', '309', '310', '311']],
#  [['4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14',
#    '4.13 ejld of Important Oil Seeds 2013-14'],
#   ['',
#    'ffl',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect',
#    'Yield Of Oil Seeds K.G Hect'],
#   ['',
#    'ffl',
#    'Ground Nut',
#    'Sun Flower',
#    'Safflower',
#    'Castor',
#    'Linseed',
#    'Soyabean',
#    'Sesamum',
#    'Niger seed',
#    'Total oil Seeds'],
#   ['1', '2', '295', '296', '297', '298', '299', '300', '301', '302', '303']],
#  [['4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
#    '4.2 fiU jAi Gross and Net area Irrigated under Different Sources'],
#   ['Sl.No.',
#    'Districts',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares',
#    'jAi 2014-15 Net area irrigated Hectares'],
#   ['Sl.No.',
#    'Districts',
#    'anals',
#    'anals',
#    'anals',
#    'AzTa nks',
#    'AzTa nks',
#    'AzTa nks',
#    'Wells',
#    'Wells',
#    'Wells'],
#   ['Sl.No.',
#    'Districts',
#    'Length in KMs',
#    'jAi Gross Irrigated Area',
#    'Net Area Irrigated',
#    'Nos',
#    'jAi Gross Irrigated Area',
#    'Net Area Irrigated',
#    'Nos',
#    'jAi Gross Irrigated Area',
#    'Net Area Irrigated'],
#   ['1', '2', '171', '172', '173', '174', '175', '176', '177', '178', '179']],
#  [['4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14'],
#   ['', 'ffl', 'Cotton', 'Sugarcane', 'Tobacco'],
#   ['1', '2', '250', '251', '252']],
#  [['4.14 jYield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 jYield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 jYield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 jYield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 jYield of Commercial crops in Kgs Hectare Year 2013-14'],
#   ['Sl.NO',
#    'Districts',
#    'Cotton inBales',
#    'Sugar Cane In Tonnes per Hectare',
#    'Tobacco'],
#   ['1', '2', '304', '305', '306']],
#  [['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16'],
#   ['', 'ffl', 'Nitrozen', 'AdP Phosphorus', 'Potash', 'Total'],
#   ['1', '2', '312', '313', '314', '315']],
#  [['4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    '4.17 uSo wing Seeds Distribution',
#    ''],
#   ['Sl.No.',
#    'District',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    ''],
#   ['Sl.No.', 'District', '', '', '', '', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Paddy',
#    'Wheat',
#    'Jowar',
#    'Ragi',
#    'Maize',
#    'Bajra',
#    'Bengal Gram',
#    'Safflower',
#    'Tur',
#    'Tur'],
#   ['1',
#    '2',
#    '316',
#    '317',
#    '318',
#    '319',
#    '320',
#    '321',
#    '322',
#    '323',
#    '324',
#    '324']],
#  [['4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.',
#    '4.18. Sericulture Year 2015-16 in Nos.'],
#   ['',
#    'ffl',
#    'Area undermulberry Hects',
#    'Cocoon Production intonnes',
#    'Arg No.ofvillages engaged on Mulberry',
#    'No.of farmers engaged in occupation',
#    'No.of farmers engaged in occupation',
#    'No.of farmers engaged in occupation',
#    'No.of farmers engaged in occupation',
#    'fiP Value ofSilk Produced Rs.inlakhs',
#    'UCocoon Markets'],
#   ['',
#    'ffl',
#    'Area undermulberry Hects',
#    'Cocoon Production intonnes',
#    'Arg No.ofvillages engaged on Mulberry',
#    'SC',
#    'AUq ST',
#    'Others',
#    'Total',
#    'fiP Value ofSilk Produced Rs.inlakhs',
#    'UCocoon Markets'],
#   ['1', '2', '332', '333', '334', '335', '336', '337', '338', '339', '340']],
#  [['4.9 Year 2013-14Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14Production of Plantation crops In Tonnes'],
#   ['Sl.NO',
#    'Districts',
#    'Coconut Thousand nuts',
#    'CrP Arecanut Processed',
#    'KfiQ Cardamom',
#    'Pepper',
#    'Cashewnut Processed',
#    'Cocoa in M.Tonnes'],
#   ['1', '2', '253', '254', '255', '256', '257', '258']],
#  [['4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15'],
#   ['Sl. NO',
#    'Districts',
#    'Area under Commercial Crops in Hectares',
#    'Area under Commercial Crops in Hectares',
#    'Area under Commercial Crops in Hectares'],
#   ['Sl. NO', 'Districts', 'Cotton', 'Sugar Cane', 'Tobacco'],
#   ['1', '2', '220', '221', '222']],
#  [['4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.',
#    '4.18.g Sericulture Year 2015-16 in Nos.'],
#   ['Sl.No.',
#    'District',
#    '',
#    '',
#    '',
#    '',
#    'fiv',
#    'fiv',
#    'fiv',
#    'fiv',
#    'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan',
#    'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan'],
#   ['Sl.No.',
#    'District',
#    'SC',
#    '',
#    'SOthers',
#    'Total',
#    'SC',
#    'ST',
#    'Others',
#    'Total',
#    'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan',
#    'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan'],
#   ['Sl.No.',
#    'District',
#    'SC',
#    '',
#    'SOthers',
#    'Total',
#    'SC',
#    'ST',
#    'Others',
#    'Total',
#    'SCP',
#    'TSP'],
#   ['1',
#    '2',
#    '341',
#    '342',
#    '343',
#    '344',
#    '345',
#    '346',
#    '347',
#    '348',
#    '349',
#    '350']],
#  [['4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 zPr uction of Important Oil Seeds Year 2013-14 in Tonnes'],
#   ['Sl.NO',
#    'Districts',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    'oduction of Oil Seeds in tonnes',
#    ''],
#   ['Sl.NO',
#    'Districts',
#    'Ground Nut',
#    'Sun Flower',
#    'Safflower',
#    'Castor',
#    'Sesamum',
#    'Linseed',
#    'Soya bean',
#    'Niger seed',
#    'Total oil Seeds',
#    ''],
#   ['1',
#    '2',
#    '241',
#    '242',
#    '243',
#    '244',
#    '245',
#    '246',
#    '247',
#    '248',
#    '249',
#    '']],
#  [['4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201'],
#   ['',
#    'ffl',
#    'ige Of Cereals K.G Hect',
#    'ige Of Cereals K.G Hect',
#    'ige Of Cereals K.G Hect',
#    'ige Of Cereals K.G Hect',
#    'ige Of Cereals K.G Hect',
#    'ige Of Cereals K.G Hect',
#    'ige Of Cereals K.G Hect',
#    'ige Of Cereals K.G Hect'],
#   ['',
#    'ffl',
#    'Rice',
#    'Jowar',
#    'Bajra',
#    'Maize',
#    'Ragi',
#    'Wheat',
#    'otal Small Millets',
#    'Total Cereals Millets'],
#   ['1', '2', '277', '278', '279', '280', '281', '282', '283', '284']],
#  [['4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15'],
#   ['Sl.No',
#    'Districts',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops'],
#   ['Sl.No',
#    'Districts',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'Area under Total Fruits',
#    'Area under Total Vegetables'],
#   ['Sl.No',
#    'Districts',
#    'Bengal Gram',
#    'Others Pulses',
#    'Total Pulses including Tur Bengalgram',
#    'Total Food Grains',
#    'Area under Total Fruits',
#    'Area under Total Vegetables'],
#   ['1', '2', '204', '205', '206', '207', '208', '209']],
#  [['4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.',
#    '4.3 Art under principal crops Year 2014-15.'],
#   ['',
#    'ffl',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    ''],
#   ['',
#    'ffl',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    ''],
#   ['',
#    'ffl',
#    'Tur',
#    'Horse Gram',
#    'Black Gram',
#    'Green Gram',
#    'Avare',
#    'Cfi Cowpea',
#    ''],
#   ['1', '2', '198', '199', '200', '201', '202', '203', '']],
#  [['4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution'],
#   ['',
#    'ffl',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16',
#    '2015-16 Sowing Seeds distributed during 2015-16'],
#   ['',
#    'ffl',
#    'BlackGram',
#    'Grean Gram',
#    'Cfi Cowpea',
#    'Ground Nut',
#    'Sun Flower',
#    'Soya bean',
#    'TotalQuantity'],
#   ['1', '2', '325', '326', '327', '328', '329', '330', '331']]]

# %%
list_to_remove = [[['4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.'],
  ['Sl.No.',
   'District',
   '',
   '',
   '',
   '',
   'fiv',
   'fiv',
   'fiv',
   'fiv',
   'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan',
   'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan'],
  ['Sl.No.',
   'District',
   'SC',
   '',
   'SOthers',
   'Total',
   'SC',
   'ST',
   'Others',
   'Total',
   'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan',
   'Vjd rAi Beneficiaries under Special Component and Tribal Sub Plan'],
  ['Sl.No.',
   'District',
   'SC',
   '',
   'SOthers',
   'Total',
   'SC',
   'ST',
   'Others',
   'Total',
   'SCP',
   'TSP'],
  ['1',
   '2',
   '341',
   '342',
   '343',
   '344',
   '345',
   '346',
   '347',
   '348',
   '349',
   '350']]]

# %%
for item in list_to_remove:
    output_list.remove(item)

# %%
list_to_add = [[['4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.',
   '4.18.g Sericulture Year 2015-16 in Nos.'],
  ['Sl.No.',
   'District',
   'Set 1',
   'Set 1',
   'Set 1',
   'Set 1',
   'Set 2',
   'Set 2',
   'Set 2',
   'Set 2',
   'Beneficiaries under Special Component and Tribal Sub Plan',
   'Beneficiaries under Special Component and Tribal Sub Plan'],
  ['Sl.No.',
   'District',
   'SC',
   'ST',
   'Others',
   'Total',
   'SC',
   'ST',
   'Others',
   'Total',
   'Beneficiaries under Special Component and Tribal Sub Plan',
   'Beneficiaries under Special Component and Tribal Sub Plan'],
  ['Sl.No.',
   'District',
   'SC',
   'ST',
   'Sthers',
   'Total',
   'SC',
   'ST',
   'Others',
   'Total',
   'SCP',
   'TSP'],
  ['1',
   '2',
   '341',
   '342',
   '343',
   '344',
   '345',
   '346',
   '347',
   '348',
   '349',
   '350']],
  [['4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources',
   '4.2 fiU jAi Gross and Net area Irrigated under Different Sources'],
  ['Sl.No.',
   'Districts',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources',
   'Net area Irrigated under Different Sources'],
  ['Sl.No.',
   'Districts',
   'Tube Wells',
   'Tube Wells',
   'Tube Wells',
   'Lift Irrigation',
   'Lift Irrigation',
   'Lift Irrigation',
   'Other Sources',
   'Other Sources',
   'Total',
   'Total'],
  ['Sl.No.',
   'Districts',
   'Nos',
   'jAi Gross Irrigated Area',
   'Net Area Irrigated',
   'Nos',
   'jAi Gross Irrigated Area',
   'Net Area Irrigated',
   'Gross Irrigated Area',
   'Net Area Irrigated',
   'Gross Irrigated Area',
   'Net Area Irrigated'],
  ['1', '2', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189']]]

# %%
output_list.extend(list_to_add)

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['zPr', 'AUq', 'MAz', 'sfi', 'Raing', 'ema', '.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2005 jAz 2015', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2016', '31.3.201', '31.3.2016', '31.3.2016.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'tP', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')
    
    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = { "jof" : "Yield of" , "gie" : "Yield", "Pnd" : "Land", "and Utilisation" : "Land Utilisation", "uction" : "Production", "Cro" : "Crop", "portant" : "Important", "Year Year" : "Year", "jYield" : "Yield", "ejld" : "Yield", "anals" : "Canals", "AzTa nks" : "Tanks", "uSo wing" : "Sowing", "2015-16 Sowing" : "Sowing", "4.18." : "4.18", "No.ofvillages" : "No.of villages", "2013-14Production" : "2013-14 Production", "4.18.g" : "4.18", "oduction" : "Production", "ige" : "Yield", "otal" : "Total", "Art" : "Area", "Sericulture4.1" : "Sericulture 4.1", "UCocoon" : "Cocoon"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(output_list)
output_list
# Out:
# [[['4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14',
#    '4.12 Yield of Important Crop Year 2013-14'],
#   ['Sl.NO',
#    'Districts',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect',
#    'Yield Of Pulses K.g Hect'],
#   ['Sl.NO',
#    'Districts',
#    'Tur',
#    'Horse Gram',
#    'Black Gram',
#    'Green Gram',
#    'Avare',
#    'Cowpea',
#    'Bengal Gram',
#    'Other Pulses',
#    'Total Pulses',
#    'Total Food Grains'],
#   ['1',
#    '2',
#    '285',
#    '286',
#    '287',
#    '288',
#    '289',
#    '290',
#    '291',
#    '292',
#    '293',
#    '294']],
#  [['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15'],
#   ['',
#    '',
#    'Banana',
#    'Mango',
#    'Lemon',
#    'Pine Apple',
#    'Guava',
#    'Grapes',
#    'Sapota',
#    'Poma- granate',
#    'Papaya'],
#   ['1', '2', '259', '260', '261', '262', '263', '264', '265', '266', '267']],
#  [['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crops Year 2013-14 in Tonnes'],
#   ['Sl.No',
#    'Districts',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals',
#    'Production of Cereals'],
#   ['Sl.No',
#    'Districts',
#    'Rice',
#    'Jowar',
#    'Bajra',
#    'Maize',
#    'Ragi',
#    'Wheat',
#    'Total Small Minor Millets',
#    'Total Cereals Minor Millets'],
#   ['1', '2', '223', '224', '225', '226', '227', '228', '229', '230']],
#  [['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '4.11 Production of Important Vegetable Crops in.Tons Year 2014-15'],
#   ['Sl.No',
#    'Districts',
#    'Potato',
#    'Tomato',
#    'Brinjal',
#    'Beans',
#    'Cluster Beans',
#    'Onion',
#    'Green Chillies',
#    'Total Leafy Vegetables',
#    'Total Gourd Variety Vegetables',
#    ''],
#   ['1',
#    '2',
#    '268',
#    '269',
#    '270',
#    '271',
#    '272',
#    '273',
#    '274',
#    '275',
#    '276',
#    '']],
#  [['4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares'],
#   ['Sl.No',
#    'District',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15',
#    'Land Utilisation 2014-15'],
#   ['Sl.No',
#    'District',
#    'Geo- graphical Area',
#    'Forest',
#    'Land not available for cultivation',
#    'Land not available for cultivation',
#    'Land not available for cultivation',
#    'Other Uncultivated Land',
#    'Other Uncultivated Land',
#    'Other Uncultivated Land',
#    'Other Uncultivated Land'],
#   ['Sl.No',
#    'District',
#    'Geo- graphical Area',
#    'Forest',
#    'Land put to Non- Agricultural uses',
#    'Barren cultivable land',
#    'Total',
#    'Cultivable-waste',
#    'Permanent Pasture',
#    'Trees and Groves',
#    'Total'],
#   ['1', '2', '156', '157', '158', '159', '160', '161', '162', '163', '164']],
#  [['4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares',
#    '4.1 Land Utilisation in Hectares'],
#   ['',
#    '',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Land Utilisation 2014-15 in Hectares'],
#   ['',
#    '',
#    'Fallow Land',
#    'Fallow Land',
#    'Fallow Land',
#    'Area Sown',
#    'Area Sown',
#    'Area Sown'],
#   ['', '', 'Current', 'Other', 'Total', 'Net', 'More than once', 'Total'],
#   ['1', '2', '165', '166', '167', '168', '169', '170']],
#  [['4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15'],
#   ['Sl.No.',
#    'Districts',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.',
#    'Area under principal crops In Hect.'],
#   ['Sl.No.',
#    'Districts',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.',
#    'Area under Cereals Hect.'],
#   ['Sl.No.',
#    'Districts',
#    'Paddy',
#    'Jowar',
#    'Bajra',
#    'Maize',
#    'Ragi',
#    'Wheat',
#    'Other Cereals Minor Millets',
#    'Total Cereals Minor millets'],
#   ['1', '2', '190', '191', '192', '193', '194', '195', '196', '197']],
#  [['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    '4.6 Production of Important Crop Year 2013-14 in Tonnes'],
#   ['',
#    '',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes',
#    'Production of Pulses In Tonnes'],
#   ['',
#    '',
#    'Tur',
#    'Horse Gram',
#    'Black Gram',
#    'Green Gram',
#    'Avare',
#    'Cowpea',
#    'Bengal Gram',
#    'Other Pulses',
#    'Total Pulses',
#    'Total Food Grains'],
#   ['1',
#    '2',
#    '231',
#    '232',
#    '233',
#    '234',
#    '235',
#    '236',
#    '237',
#    '238',
#    '239',
#    '240']],
#  [['4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15',
#    '4.4 Area under Important Oil Seeds Year 2014-15'],
#   ['A.p',
#    '',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops'],
#   ['A.p',
#    '',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect',
#    'Seeds Hect'],
#   ['A.p',
#    '',
#    'Ground Nut',
#    'Sun Flower',
#    'Safflower',
#    'Castor',
#    'Sesamum',
#    'Niger seed',
#    'Soyabean',
#    'Linseed',
#    'other oil Seeds',
#    'Total oil Seeds'],
#   ['1',
#    '2',
#    '210',
#    '211',
#    '212',
#    '213',
#    '214',
#    '215',
#    '216',
#    '217',
#    '218',
#    '219']],
#  [['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    '4.15 Yield of Plantation crops in Kgs Hect Year 2013-14'],
#   ['Sl.NO',
#    'Districts',
#    'Arecanut Processed',
#    'Cardamom',
#    'Pepper',
#    'Cashewnut Processed',
#    'Cocoa M.Tonnes Hect'],
#   ['1', '2', '307', '308', '309', '310', '311']],
#  [['4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14',
#    '4.13 Yield of Important Oil Seeds 2013-14'],
#   ['',
#    '',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect',
#    'Yield Of Oil Seeds K.g Hect'],
#   ['',
#    '',
#    'Ground Nut',
#    'Sun Flower',
#    'Safflower',
#    'Castor',
#    'Linseed',
#    'Soyabean',
#    'Sesamum',
#    'Niger seed',
#    'Total oil Seeds'],
#   ['1', '2', '295', '296', '297', '298', '299', '300', '301', '302', '303']],
#  [['4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources'],
#   ['Sl.No.',
#    'Districts',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares',
#    '2014-15 Net area irrigated Hectares'],
#   ['Sl.No.',
#    'Districts',
#    'Canals',
#    'Canals',
#    'Canals',
#    'Tanks',
#    'Tanks',
#    'Tanks',
#    'Wells',
#    'Wells',
#    'Wells'],
#   ['Sl.No.',
#    'Districts',
#    'Length in KMs',
#    'Gross Irrigated Area',
#    'Net Area Irrigated',
#    'Nos',
#    'Gross Irrigated Area',
#    'Net Area Irrigated',
#    'Nos',
#    'Gross Irrigated Area',
#    'Net Area Irrigated'],
#   ['1', '2', '171', '172', '173', '174', '175', '176', '177', '178', '179']],
#  [['4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14',
#    '4.8 Production of commercial crops in Tonnes Year 2013-14'],
#   ['', '', 'Cotton', 'Sugarcane', 'Tobacco'],
#   ['1', '2', '250', '251', '252']],
#  [['4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    '4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14'],
#   ['Sl.NO',
#    'Districts',
#    'Cotton in Bales',
#    'Sugar Cane In Tonnes per Hectare',
#    'Tobacco'],
#   ['1', '2', '304', '305', '306']],
#  [['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16'],
#   ['', '', 'Nitrozen', 'Phosphorus', 'Potash', 'Total'],
#   ['1', '2', '312', '313', '314', '315']],
#  [['4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    ''],
#   ['Sl.No.',
#    'District',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    ''],
#   ['Sl.No.', 'District', '', '', '', '', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Paddy',
#    'Wheat',
#    'Jowar',
#    'Ragi',
#    'Maize',
#    'Bajra',
#    'Bengal Gram',
#    'Safflower',
#    'Tur',
#    'Tur'],
#   ['1',
#    '2',
#    '316',
#    '317',
#    '318',
#    '319',
#    '320',
#    '321',
#    '322',
#    '323',
#    '324',
#    '324']],
#  [['4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.'],
#   ['',
#    '',
#    'Area undermulberry Hects',
#    'Cocoon Production intonnes',
#    'No.of villages engaged on Mulberry',
#    'No.of farmers engaged in occupation',
#    'No.of farmers engaged in occupation',
#    'No.of farmers engaged in occupation',
#    'No.of farmers engaged in occupation',
#    'Value of Silk Produced Rs.inlakhs',
#    'Cocoon Markets'],
#   ['',
#    '',
#    'Area undermulberry Hects',
#    'Cocoon Production intonnes',
#    'No.of villages engaged on Mulberry',
#    'Sc',
#    'St',
#    'Others',
#    'Total',
#    'Value of Silk Produced Rs.inlakhs',
#    'Cocoon Markets'],
#   ['1', '2', '332', '333', '334', '335', '336', '337', '338', '339', '340']],
#  [['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    '4.9 Year 2013-14 Production of Plantation crops In Tonnes'],
#   ['Sl.NO',
#    'Districts',
#    'Coconut Thousand nuts',
#    'Arecanut Processed',
#    'Cardamom',
#    'Pepper',
#    'Cashewnut Processed',
#    'Cocoa in M.Tonnes'],
#   ['1', '2', '253', '254', '255', '256', '257', '258']],
#  [['4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15',
#    '4.5 Area under Commercial Crops Year 2014-15'],
#   ['Sl. No',
#    'Districts',
#    'Area under Commercial Crops in Hectares',
#    'Area under Commercial Crops in Hectares',
#    'Area under Commercial Crops in Hectares'],
#   ['Sl. No', 'Districts', 'Cotton', 'Sugar Cane', 'Tobacco'],
#   ['1', '2', '220', '221', '222']],
#  [['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes'],
#   ['Sl.NO',
#    'Districts',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Production of Oil Seeds in tonnes',
#    ''],
#   ['Sl.NO',
#    'Districts',
#    'Ground Nut',
#    'Sun Flower',
#    'Safflower',
#    'Castor',
#    'Sesamum',
#    'Linseed',
#    'Soya bean',
#    'Niger seed',
#    'Total oil Seeds',
#    ''],
#   ['1',
#    '2',
#    '241',
#    '242',
#    '243',
#    '244',
#    '245',
#    '246',
#    '247',
#    '248',
#    '249',
#    '']],
#  [['4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201',
#    '4.12 Yield of Important Crops Year 201'],
#   ['',
#    '',
#    'Yield Of Cereals K.g Hect',
#    'Yield Of Cereals K.g Hect',
#    'Yield Of Cereals K.g Hect',
#    'Yield Of Cereals K.g Hect',
#    'Yield Of Cereals K.g Hect',
#    'Yield Of Cereals K.g Hect',
#    'Yield Of Cereals K.g Hect',
#    'Yield Of Cereals K.g Hect'],
#   ['',
#    '',
#    'Rice',
#    'Jowar',
#    'Bajra',
#    'Maize',
#    'Ragi',
#    'Wheat',
#    'Total Small Millets',
#    'Total Cereals Millets'],
#   ['1', '2', '277', '278', '279', '280', '281', '282', '283', '284']],
#  [['4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15',
#    '4.3 Area under principal crops Year 2014-15'],
#   ['Sl.No',
#    'Districts',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops'],
#   ['Sl.No',
#    'Districts',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'Area under Total Fruits',
#    'Area under Total Vegetables'],
#   ['Sl.No',
#    'Districts',
#    'Bengal Gram',
#    'Others Pulses',
#    'Total Pulses including Tur Bengalgram',
#    'Total Food Grains',
#    'Area under Total Fruits',
#    'Area under Total Vegetables'],
#   ['1', '2', '204', '205', '206', '207', '208', '209']],
#  [['4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.',
#    '4.3 Area under principal crops Year 2014-15.'],
#   ['',
#    '',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    'Area under principal crops',
#    ''],
#   ['',
#    '',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    'pulses Hect',
#    ''],
#   ['',
#    '',
#    'Tur',
#    'Horse Gram',
#    'Black Gram',
#    'Green Gram',
#    'Avare',
#    'Cowpea',
#    ''],
#   ['1', '2', '198', '199', '200', '201', '202', '203', '']],
#  [['4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution',
#    '4.17 Sowing Seeds Distribution'],
#   ['',
#    '',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16',
#    'Sowing Seeds distributed during 2015-16'],
#   ['',
#    '',
#    'Black Gram',
#    'Grean Gram',
#    'Cowpea',
#    'Ground Nut',
#    'Sun Flower',
#    'Soya bean',
#    'Total Quantity'],
#   ['1', '2', '325', '326', '327', '328', '329', '330', '331']],
#  [['4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.',
#    '4.18 Sericulture Year 2015-16 in Nos.'],
#   ['Sl.No.',
#    'District',
#    'Set 1',
#    'Set 1',
#    'Set 1',
#    'Set 1',
#    'Set 2',
#    'Set 2',
#    'Set 2',
#    'Set 2',
#    'Beneficiaries under Special Component and Tribal Sub Plan',
#    'Beneficiaries under Special Component and Tribal Sub Plan'],
#   ['Sl.No.',
#    'District',
#    'Sc',
#    'St',
#    'Others',
#    'Total',
#    'Sc',
#    'St',
#    'Others',
#    'Total',
#    'Beneficiaries under Special Component and Tribal Sub Plan',
#    'Beneficiaries under Special Component and Tribal Sub Plan'],
#   ['Sl.No.',
#    'District',
#    'Sc',
#    'St',
#    'Sthers',
#    'Total',
#    'Sc',
#    'St',
#    'Others',
#    'Total',
#    'Scp',
#    'Tsp'],
#   ['1',
#    '2',
#    '341',
#    '342',
#    '343',
#    '344',
#    '345',
#    '346',
#    '347',
#    '348',
#    '349',
#    '350']],
#  [['4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources',
#    '4.2 Gross and Net area Irrigated under Different Sources'],
#   ['Sl.No.',
#    'Districts',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources'],
#   ['Sl.No.',
#    'Districts',
#    'Tube Wells',
#    'Tube Wells',
#    'Tube Wells',
#    'Lift Irrigation',
#    'Lift Irrigation',
#    'Lift Irrigation',
#    'Other Sources',
#    'Other Sources',
#    'Total',
#    'Total'],
#   ['Sl.No.',
#    'Districts',
#    'Nos',
#    'Gross Irrigated Area',
#    'Net Area Irrigated',
#    'Nos',
#    'Gross Irrigated Area',
#    'Net Area Irrigated',
#    'Gross Irrigated Area',
#    'Net Area Irrigated',
#    'Gross Irrigated Area',
#    'Net Area Irrigated'],
#   ['1',
#    '2',
#    '180',
#    '181',
#    '182',
#    '183',
#    '184',
#    '185',
#    '186',
#    '187',
#    '188',
#    '189']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['4.12 Yield of Important Crop Year 2013-14', 'Sl.NO', 'Sl.NO', '1'],
#   ['4.12 Yield of Important Crop Year 2013-14', 'Districts', 'Districts', '2'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Tur',
#    '285'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Horse Gram',
#    '286'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Black Gram',
#    '287'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Green Gram',
#    '288'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Avare',
#    '289'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Cowpea',
#    '290'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Bengal Gram',
#    '291'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Other Pulses',
#    '292'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Total Pulses',
#    '293'],
#   ['4.12 Yield of Important Crop Year 2013-14',
#    'Yield Of Pulses K.g Hect',
#    'Total Food Grains',
#    '294']],
#  [['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '',
#    '1'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    '',
#    '2'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Banana',
#    '259'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Mango',
#    '260'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Lemon',
#    '261'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Pine Apple',
#    '262'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Guava',
#    '263'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Grapes',
#    '264'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Sapota',
#    '265'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Poma- granate',
#    '266'],
#   ['4.10 Production of Important Horticulture Crops Fruits Crops M.Tonnes Year 2014-15',
#    'Papaya',
#    '267']],
#  [['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Districts',
#    'Districts',
#    '2'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Rice',
#    '223'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Jowar',
#    '224'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Bajra',
#    '225'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Maize',
#    '226'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Ragi',
#    '227'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Wheat',
#    '228'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Total Small Minor Millets',
#    '229'],
#   ['4.6 Production of Important Crops Year 2013-14 in Tonnes',
#    'Production of Cereals',
#    'Total Cereals Minor Millets',
#    '230']],
#  [['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Sl.No',
#    '1'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Districts',
#    '2'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Potato',
#    '268'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Tomato',
#    '269'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Brinjal',
#    '270'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Beans',
#    '271'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Cluster Beans',
#    '272'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Onion',
#    '273'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Green Chillies',
#    '274'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Total Leafy Vegetables',
#    '275'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    'Total Gourd Variety Vegetables',
#    '276'],
#   ['4.11 Production of Important Vegetable Crops in.Tons Year 2014-15',
#    '',
#    '']],
#  [['4.1 Land Utilisation in Hectares', 'Sl.No', 'Sl.No', 'Sl.No', '1'],
#   ['4.1 Land Utilisation in Hectares',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Geo- graphical Area',
#    'Geo- graphical Area',
#    '156'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Forest',
#    'Forest',
#    '157'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Land not available for cultivation',
#    'Land put to Non- Agricultural uses',
#    '158'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Land not available for cultivation',
#    'Barren cultivable land',
#    '159'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Land not available for cultivation',
#    'Total',
#    '160'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Other Uncultivated Land',
#    'Cultivable-waste',
#    '161'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Other Uncultivated Land',
#    'Permanent Pasture',
#    '162'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Other Uncultivated Land',
#    'Trees and Groves',
#    '163'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15',
#    'Other Uncultivated Land',
#    'Total',
#    '164']],
#  [['4.1 Land Utilisation in Hectares', '', '', '', '1'],
#   ['4.1 Land Utilisation in Hectares', '', '', '', '2'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Fallow Land',
#    'Current',
#    '165'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Fallow Land',
#    'Other',
#    '166'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Fallow Land',
#    'Total',
#    '167'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Area Sown',
#    'Net',
#    '168'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Area Sown',
#    'More than once',
#    '169'],
#   ['4.1 Land Utilisation in Hectares',
#    'Land Utilisation 2014-15 in Hectares',
#    'Area Sown',
#    'Total',
#    '170']],
#  [['4.3 Area under principal crops Year 2014-15',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Paddy',
#    '190'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Jowar',
#    '191'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Bajra',
#    '192'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Maize',
#    '193'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Ragi',
#    '194'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Wheat',
#    '195'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Other Cereals Minor Millets',
#    '196'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops In Hect.',
#    'Area under Cereals Hect.',
#    'Total Cereals Minor millets',
#    '197']],
#  [['4.6 Production of Important Crop Year 2013-14 in Tonnes', '', '', '1'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes', '', '', '2'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Tur',
#    '231'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Horse Gram',
#    '232'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Black Gram',
#    '233'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Green Gram',
#    '234'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Avare',
#    '235'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Cowpea',
#    '236'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Bengal Gram',
#    '237'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Other Pulses',
#    '238'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Total Pulses',
#    '239'],
#   ['4.6 Production of Important Crop Year 2013-14 in Tonnes',
#    'Production of Pulses In Tonnes',
#    'Total Food Grains',
#    '240']],
#  [['4.4 Area under Important Oil Seeds Year 2014-15',
#    'A.p',
#    'A.p',
#    'A.p',
#    '1'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15', '', '', '', '2'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Ground Nut',
#    '210'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Sun Flower',
#    '211'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Safflower',
#    '212'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Castor',
#    '213'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Sesamum',
#    '214'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Niger seed',
#    '215'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Soyabean',
#    '216'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Linseed',
#    '217'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'other oil Seeds',
#    '218'],
#   ['4.4 Area under Important Oil Seeds Year 2014-15',
#    'Area under principal crops',
#    'Seeds Hect',
#    'Total oil Seeds',
#    '219']],
#  [['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14', 'Sl.NO', '1'],
#   ['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    'Districts',
#    '2'],
#   ['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    'Arecanut Processed',
#    '307'],
#   ['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    'Cardamom',
#    '308'],
#   ['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14', 'Pepper', '309'],
#   ['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    'Cashewnut Processed',
#    '310'],
#   ['4.15 Yield of Plantation crops in Kgs Hect Year 2013-14',
#    'Cocoa M.Tonnes Hect',
#    '311']],
#  [['4.13 Yield of Important Oil Seeds 2013-14', '', '', '1'],
#   ['4.13 Yield of Important Oil Seeds 2013-14', '', '', '2'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Ground Nut',
#    '295'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Sun Flower',
#    '296'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Safflower',
#    '297'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Castor',
#    '298'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Linseed',
#    '299'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Soyabean',
#    '300'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Sesamum',
#    '301'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Niger seed',
#    '302'],
#   ['4.13 Yield of Important Oil Seeds 2013-14',
#    'Yield Of Oil Seeds K.g Hect',
#    'Total oil Seeds',
#    '303']],
#  [['4.2 Gross and Net area Irrigated under Different Sources',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Canals',
#    'Length in KMs',
#    '171'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Canals',
#    'Gross Irrigated Area',
#    '172'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Canals',
#    'Net Area Irrigated',
#    '173'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Tanks',
#    'Nos',
#    '174'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Tanks',
#    'Gross Irrigated Area',
#    '175'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Tanks',
#    'Net Area Irrigated',
#    '176'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Wells',
#    'Nos',
#    '177'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Wells',
#    'Gross Irrigated Area',
#    '178'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    '2014-15 Net area irrigated Hectares',
#    'Wells',
#    'Net Area Irrigated',
#    '179']],
#  [['4.8 Production of commercial crops in Tonnes Year 2013-14', '', '1'],
#   ['4.8 Production of commercial crops in Tonnes Year 2013-14', '', '2'],
#   ['4.8 Production of commercial crops in Tonnes Year 2013-14',
#    'Cotton',
#    '250'],
#   ['4.8 Production of commercial crops in Tonnes Year 2013-14',
#    'Sugarcane',
#    '251'],
#   ['4.8 Production of commercial crops in Tonnes Year 2013-14',
#    'Tobacco',
#    '252']],
#  [['4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14', 'Sl.NO', '1'],
#   ['4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    'Districts',
#    '2'],
#   ['4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    'Cotton in Bales',
#    '304'],
#   ['4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    'Sugar Cane In Tonnes per Hectare',
#    '305'],
#   ['4.14 Yield of Commercial crops in Kgs Hectare Year 2013-14',
#    'Tobacco',
#    '306']],
#  [['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '',
#    '1'],
#   ['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    '',
#    '2'],
#   ['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    'Nitrozen',
#    '312'],
#   ['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    'Phosphorus',
#    '313'],
#   ['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    'Potash',
#    '314'],
#   ['4.16 Distribution of chemical fertilizers In Tonnes Year 2015-16',
#    'Total',
#    '315']],
#  [['4.17 Sowing Seeds Distribution', 'Sl.No.', 'Sl.No.', 'Sl.No.', '1'],
#   ['4.17 Sowing Seeds Distribution', 'District', 'District', 'District', '2'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Paddy',
#    '316'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Wheat',
#    '317'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Jowar',
#    '318'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Ragi',
#    '319'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Maize',
#    '320'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Bajra',
#    '321'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Bengal Gram',
#    '322'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Safflower',
#    '323'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    '',
#    'Tur',
#    '324'],
#   ['', '', '', 'Tur', '324']],
#  [['4.18 Sericulture Year 2015-16 in Nos.', '', '', '1'],
#   ['4.18 Sericulture Year 2015-16 in Nos.', '', '', '2'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Area undermulberry Hects',
#    'Area undermulberry Hects',
#    '332'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Cocoon Production intonnes',
#    'Cocoon Production intonnes',
#    '333'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'No.of villages engaged on Mulberry',
#    'No.of villages engaged on Mulberry',
#    '334'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'No.of farmers engaged in occupation',
#    'Sc',
#    '335'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'No.of farmers engaged in occupation',
#    'St',
#    '336'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'No.of farmers engaged in occupation',
#    'Others',
#    '337'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'No.of farmers engaged in occupation',
#    'Total',
#    '338'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Value of Silk Produced Rs.inlakhs',
#    'Value of Silk Produced Rs.inlakhs',
#    '339'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Cocoon Markets',
#    'Cocoon Markets',
#    '340']],
#  [['4.9 Year 2013-14 Production of Plantation crops In Tonnes', 'Sl.NO', '1'],
#   ['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    'Districts',
#    '2'],
#   ['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    'Coconut Thousand nuts',
#    '253'],
#   ['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    'Arecanut Processed',
#    '254'],
#   ['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    'Cardamom',
#    '255'],
#   ['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    'Pepper',
#    '256'],
#   ['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    'Cashewnut Processed',
#    '257'],
#   ['4.9 Year 2013-14 Production of Plantation crops In Tonnes',
#    'Cocoa in M.Tonnes',
#    '258']],
#  [['4.5 Area under Commercial Crops Year 2014-15', 'Sl. No', 'Sl. No', '1'],
#   ['4.5 Area under Commercial Crops Year 2014-15',
#    'Districts',
#    'Districts',
#    '2'],
#   ['4.5 Area under Commercial Crops Year 2014-15',
#    'Area under Commercial Crops in Hectares',
#    'Cotton',
#    '220'],
#   ['4.5 Area under Commercial Crops Year 2014-15',
#    'Area under Commercial Crops in Hectares',
#    'Sugar Cane',
#    '221'],
#   ['4.5 Area under Commercial Crops Year 2014-15',
#    'Area under Commercial Crops in Hectares',
#    'Tobacco',
#    '222']],
#  [['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Sl.NO',
#    'Sl.NO',
#    '1'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Districts',
#    'Districts',
#    '2'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Ground Nut',
#    '241'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Sun Flower',
#    '242'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Safflower',
#    '243'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Castor',
#    '244'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Sesamum',
#    '245'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Linseed',
#    '246'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Soya bean',
#    '247'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Niger seed',
#    '248'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    'Production of Oil Seeds in tonnes',
#    'Total oil Seeds',
#    '249'],
#   ['4.7 Production of Important Oil Seeds Year 2013-14 in Tonnes',
#    '',
#    '',
#    '']],
#  [['4.12 Yield of Important Crops Year 201', '', '', '1'],
#   ['4.12 Yield of Important Crops Year 201', '', '', '2'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Rice',
#    '277'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Jowar',
#    '278'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Bajra',
#    '279'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Maize',
#    '280'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Ragi',
#    '281'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Wheat',
#    '282'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Total Small Millets',
#    '283'],
#   ['4.12 Yield of Important Crops Year 201',
#    'Yield Of Cereals K.g Hect',
#    'Total Cereals Millets',
#    '284']],
#  [['4.3 Area under principal crops Year 2014-15',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops',
#    'pulses Hect',
#    'Bengal Gram',
#    '204'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops',
#    'pulses Hect',
#    'Others Pulses',
#    '205'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops',
#    'pulses Hect',
#    'Total Pulses including Tur Bengalgram',
#    '206'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops',
#    'pulses Hect',
#    'Total Food Grains',
#    '207'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops',
#    'Area under Total Fruits',
#    'Area under Total Fruits',
#    '208'],
#   ['4.3 Area under principal crops Year 2014-15',
#    'Area under principal crops',
#    'Area under Total Vegetables',
#    'Area under Total Vegetables',
#    '209']],
#  [['4.3 Area under principal crops Year 2014-15.', '', '', '', '1'],
#   ['4.3 Area under principal crops Year 2014-15.', '', '', '', '2'],
#   ['4.3 Area under principal crops Year 2014-15.',
#    'Area under principal crops',
#    'pulses Hect',
#    'Tur',
#    '198'],
#   ['4.3 Area under principal crops Year 2014-15.',
#    'Area under principal crops',
#    'pulses Hect',
#    'Horse Gram',
#    '199'],
#   ['4.3 Area under principal crops Year 2014-15.',
#    'Area under principal crops',
#    'pulses Hect',
#    'Black Gram',
#    '200'],
#   ['4.3 Area under principal crops Year 2014-15.',
#    'Area under principal crops',
#    'pulses Hect',
#    'Green Gram',
#    '201'],
#   ['4.3 Area under principal crops Year 2014-15.',
#    'Area under principal crops',
#    'pulses Hect',
#    'Avare',
#    '202'],
#   ['4.3 Area under principal crops Year 2014-15.',
#    'Area under principal crops',
#    'pulses Hect',
#    'Cowpea',
#    '203'],
#   ['4.3 Area under principal crops Year 2014-15.', '', '', '', '']],
#  [['4.17 Sowing Seeds Distribution', '', '', '1'],
#   ['4.17 Sowing Seeds Distribution', '', '', '2'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    'Black Gram',
#    '325'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    'Grean Gram',
#    '326'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    'Cowpea',
#    '327'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    'Ground Nut',
#    '328'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    'Sun Flower',
#    '329'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    'Soya bean',
#    '330'],
#   ['4.17 Sowing Seeds Distribution',
#    'Sowing Seeds distributed during 2015-16',
#    'Total Quantity',
#    '331']],
#  [['4.18 Sericulture Year 2015-16 in Nos.', 'Sl.No.', 'Sl.No.', 'Sl.No.', '1'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['4.18 Sericulture Year 2015-16 in Nos.', 'Set 1', 'Sc', 'Sc', '341'],
#   ['4.18 Sericulture Year 2015-16 in Nos.', 'Set 1', 'St', 'St', '342'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Set 1',
#    'Others',
#    'Sthers',
#    '343'],
#   ['4.18 Sericulture Year 2015-16 in Nos.', 'Set 1', 'Total', 'Total', '344'],
#   ['4.18 Sericulture Year 2015-16 in Nos.', 'Set 2', 'Sc', 'Sc', '345'],
#   ['4.18 Sericulture Year 2015-16 in Nos.', 'Set 2', 'St', 'St', '346'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Set 2',
#    'Others',
#    'Others',
#    '347'],
#   ['4.18 Sericulture Year 2015-16 in Nos.', 'Set 2', 'Total', 'Total', '348'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Beneficiaries under Special Component and Tribal Sub Plan',
#    'Beneficiaries under Special Component and Tribal Sub Plan',
#    'Scp',
#    '349'],
#   ['4.18 Sericulture Year 2015-16 in Nos.',
#    'Beneficiaries under Special Component and Tribal Sub Plan',
#    'Beneficiaries under Special Component and Tribal Sub Plan',
#    'Tsp',
#    '350']],
#  [['4.2 Gross and Net area Irrigated under Different Sources',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Tube Wells',
#    'Nos',
#    '180'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Tube Wells',
#    'Gross Irrigated Area',
#    '181'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Tube Wells',
#    'Net Area Irrigated',
#    '182'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Lift Irrigation',
#    'Nos',
#    '183'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Lift Irrigation',
#    'Gross Irrigated Area',
#    '184'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Lift Irrigation',
#    'Net Area Irrigated',
#    '185'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Other Sources',
#    'Gross Irrigated Area',
#    '186'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Other Sources',
#    'Net Area Irrigated',
#    '187'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Total',
#    'Gross Irrigated Area',
#    '188'],
#   ['4.2 Gross and Net area Irrigated under Different Sources',
#    'Net area Irrigated under Different Sources',
#    'Total',
#    'Net Area Irrigated',
#    '189']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 4
chapter_name = "Agriculture, Horticulture and Sericulture"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id, table_name = find_table_details(inner_list[0][0])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list):
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv(absolute_result_path, sep=';', index=False)
    df.to_csv(absolute_dictionary_path, sep=';', index=False)

# %%
process_dictionary(transp_list)
