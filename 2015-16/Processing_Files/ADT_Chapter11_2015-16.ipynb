# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
relative_path_html = "../HTML/Output_html_Chapter11/kaggle/working/out/output/"
relative_path_pdf = "../HTML/Output_html_Chapter11/kaggle/working/out/pages/"
relative_dictionary_path = "../Dictionary/Chapter11_Attributes.csv"
relative_result_path = "../HTML/Output_html_Chapter11/Chapter11_Attributes.csv"
# Get the absolute path by joining the current directory with the relative path
absolute_path_html = os.path.join(os.getcwd(), relative_path_html)
absolute_path_pdf = os.path.join(os.getcwd(), relative_path_pdf)
absolute_dictionary_path = os.path.join(os.getcwd(), relative_dictionary_path)
absolute_result_path = os.path.join(os.getcwd(), relative_result_path)

# %%
absolute_path_html
# Out:
# '/home/riya/Downloads/ADT/2015-16/Processing_Files/../HTML/Output_html_Chapter11/kaggle/working/out/output/'

# %%
os.listdir(absolute_path_html)
# Out:
# ['output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_8.html',
#  'output_page_3.html',
#  'output_page_4.html',
#  'output_page_9.html',
#  'output_page_7.html',
#  'output_page_6.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(absolute_path_html): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = os.path.join(absolute_path_html, file)
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)

# %%
output_list
# Out:
# [[['11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'Tal Hospitals',
#    'Tal Hospitals',
#    'ffl uka District Hospitals',
#    'ffl uka District Hospitals',
#    'Other Hospitals under HFW',
#    'Other Hospitals under HFW',
#    'Autonomous Teaching Hospitals',
#    'Autonomous Teaching Hospitals',
#    'Others CHCs',
#    'Others CHCs',
#    'Total',
#    'Total'],
#   ['Sl. No.',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '648',
#    '649',
#    '650',
#    '651',
#    '652',
#    '653',
#    '654',
#    '655',
#    '656',
#    '657',
#    '658',
#    '659']],
#  [['11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.'],
#   ['',
#    'ffl',
#    'ANSo Hospitals',
#    'ANSo Hospitals',
#    'ANSo Hospitals',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Private',
#    'Total',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Nursing Home Hospitals',
#    'Total',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['1', '2', '660', '661', '662', '663', '664', '665', '666']],
#  [['11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos'],
#   ['',
#    'ffl',
#    'Sterlisation',
#    'Sterlisation',
#    'Family Planing Measures in users',
#    'Family Planing Measures in users',
#    'Family Planing Measures in users'],
#   ['', 'ffl', 'Vasectomy', 'Tubectomy', 'I.U.D user', 'C.C. user', 'O.P user'],
#   ['1', '2', '682', '683', '684', '685', '686']],
#  [['11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    ''],
#   ['Sl.No.',
#    'Districts',
#    'No ofIdentified T.B.patients',
#    'No ofIdentified T.B.patients',
#    'No ofIdentified T.B.patients',
#    'Patients Cured',
#    'Patients Cured',
#    'Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    ''],
#   ['Sl.No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '705',
#    '706',
#    '707',
#    '708',
#    '709',
#    '710',
#    '711',
#    '712',
#    '713',
#    '']],
#  [['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.'],
#   ['Sl.No',
#    'Districts',
#    'Dfl Allopathy Hospitals',
#    'Dfl Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'In dia System of Medicine',
#    '',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Dfl Allopathy Hospitals',
#    'Dfl Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'In dia System of Medicine',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '667',
#    '668',
#    '669',
#    '670',
#    '670',
#    '671',
#    '672',
#    '673',
#    '674',
#    '675']],
#  [['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['Sl.No.',
#    'Districts',
#    'fl. D.P.T.',
#    'Polio',
#    'BCG',
#    'Measles',
#    'T.T',
#    '.Pentavalent includes Hepatities D.P.T'],
#   ['1', '2', '676', '677', '678', '679', '680', '681']],
#  [['11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.'],
#   ['',
#    'ffl',
#    'FRUUnit First Referal Units',
#    '108 Ambulances',
#    '108 Ambulances',
#    '24 7 24hoursand 7 days workingHospitals',
#    '24 7 24hoursand 7 days workingHospitals',
#    'No.of benificiaries in Jananni SurakshYojana',
#    'No.of benificiaries madical kit',
#    'MaternalMortality Death'],
#   ['',
#    'ffl',
#    'FRUUnit First Referal Units',
#    'No.of Vehicals',
#    'No.ofbenefited patients',
#    'Nos.',
#    'No.of delivaries inthisHospitals',
#    'No.of benificiaries in Jananni SurakshYojana',
#    'No.of benificiaries madical kit',
#    'MaternalMortality Death'],
#   ['1', '2', '714', '715', '716', '717', '718', '719', '720', '721']],
#  [['11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016'],
#   ['',
#    'ffl',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme'],
#   ['',
#    'ffl',
#    'IdentifiedLeprosy Patients',
#    'IdentifiedLeprosy Patients',
#    'IdentifiedLeprosy Patients',
#    'No.of Patients Cured',
#    'No.of Patients Cured',
#    'No.of Patients Cured'],
#   ['', 'ffl', 'Afi Male', 'Female', 'Total', 'Afi Male', 'Female', 'Total'],
#   ['1', '2', '699', '700', '701', '702', '703', '704']],
#  [['11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    ''],
#   ['Sl. No.',
#    'Districts',
#    'identifiedAidspatients',
#    'identifiedAidspatients',
#    'identifiedAidspatients',
#    'identifiedAidspatients',
#    'o.of Patients Cured',
#    'o.of Patients Cured',
#    'o.of Patients Cured',
#    'o.of Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    ''],
#   ['Sl. No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    ''],
#   ['1',
#    '2',
#    '687',
#    '688',
#    '689',
#    '690',
#    '691',
#    '692',
#    '693',
#    '694',
#    '695',
#    '696',
#    '697',
#    '698',
#    '']]]

# %%
list_to_remove = [[['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of Medicine Hospitals',
   'In dia System of Medicine',
   '',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of Medicine Hospitals',
   'In dia System of Medicine',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds',
   'Nos',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds'],
  ['1',
   '2',
   '667',
   '668',
   '669',
   '670',
   '670',
   '671',
   '672',
   '673',
   '674',
   '675']]]

# %%
for item in list_to_remove:
    output_list.remove(item)

# %%
list_to_add =[[['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of Medicine Hospitals',
   'In dia System of Medicine',
   '',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of Medicine Hospitals',
   'In dia System of Medicine',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds',
   'Nos',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds'],
  ['1',
   '2',
   '667',
   '668',
   '669',
   '670',
   '670.1',
   '671',
   '672',
   '673',
   '674',
   '675']]]

# %%
output_list.extend(list_to_add)

# %%
output_list
# Out:
# [[['11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.',
#    '11. lth Family welfare Services11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2016 In Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'Tal Hospitals',
#    'Tal Hospitals',
#    'ffl uka District Hospitals',
#    'ffl uka District Hospitals',
#    'Other Hospitals under HFW',
#    'Other Hospitals under HFW',
#    'Autonomous Teaching Hospitals',
#    'Autonomous Teaching Hospitals',
#    'Others CHCs',
#    'Others CHCs',
#    'Total',
#    'Total'],
#   ['Sl. No.',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '648',
#    '649',
#    '650',
#    '651',
#    '652',
#    '653',
#    '654',
#    '655',
#    '656',
#    '657',
#    '658',
#    '659']],
#  [['11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.',
#    '11.2 UNo AHS pitals Doctors Beds on 31.3.2016 In Nos.'],
#   ['',
#    'ffl',
#    'ANSo Hospitals',
#    'ANSo Hospitals',
#    'ANSo Hospitals',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Private',
#    'Total',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Nursing Home Hospitals',
#    'Total',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['1', '2', '660', '661', '662', '663', '664', '665', '666']],
#  [['11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos'],
#   ['',
#    'ffl',
#    'Sterlisation',
#    'Sterlisation',
#    'Family Planing Measures in users',
#    'Family Planing Measures in users',
#    'Family Planing Measures in users'],
#   ['', 'ffl', 'Vasectomy', 'Tubectomy', 'I.U.D user', 'C.C. user', 'O.P user'],
#   ['1', '2', '682', '683', '684', '685', '686']],
#  [['11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.',
#    '11.5 tAvP TB Control Programmes on 31.3.2016 in Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    ''],
#   ['Sl.No.',
#    'Districts',
#    'No ofIdentified T.B.patients',
#    'No ofIdentified T.B.patients',
#    'No ofIdentified T.B.patients',
#    'Patients Cured',
#    'Patients Cured',
#    'Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    ''],
#   ['Sl.No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '705',
#    '706',
#    '707',
#    '708',
#    '709',
#    '710',
#    '711',
#    '712',
#    '713',
#    '']],
#  [['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['Sl.No.',
#    'Districts',
#    'fl. D.P.T.',
#    'Polio',
#    'BCG',
#    'Measles',
#    'T.T',
#    '.Pentavalent includes Hepatities D.P.T'],
#   ['1', '2', '676', '677', '678', '679', '680', '681']],
#  [['11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.',
#    '11.6 DifferentHealthFacilities Ason31.3.2016 inNos.'],
#   ['',
#    'ffl',
#    'FRUUnit First Referal Units',
#    '108 Ambulances',
#    '108 Ambulances',
#    '24 7 24hoursand 7 days workingHospitals',
#    '24 7 24hoursand 7 days workingHospitals',
#    'No.of benificiaries in Jananni SurakshYojana',
#    'No.of benificiaries madical kit',
#    'MaternalMortality Death'],
#   ['',
#    'ffl',
#    'FRUUnit First Referal Units',
#    'No.of Vehicals',
#    'No.ofbenefited patients',
#    'Nos.',
#    'No.of delivaries inthisHospitals',
#    'No.of benificiaries in Jananni SurakshYojana',
#    'No.of benificiaries madical kit',
#    'MaternalMortality Death'],
#   ['1', '2', '714', '715', '716', '717', '718', '719', '720', '721']],
#  [['11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016',
#    '11.5 Family Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.03.2016'],
#   ['',
#    'ffl',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme',
#    'LeprosyControlProgramme'],
#   ['',
#    'ffl',
#    'IdentifiedLeprosy Patients',
#    'IdentifiedLeprosy Patients',
#    'IdentifiedLeprosy Patients',
#    'No.of Patients Cured',
#    'No.of Patients Cured',
#    'No.of Patients Cured'],
#   ['', 'ffl', 'Afi Male', 'Female', 'Total', 'Afi Male', 'Female', 'Total'],
#   ['1', '2', '699', '700', '701', '702', '703', '704']],
#  [['11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.',
#    '11.5 AIDS Leprosy TB Control Programmes Year 2015-16 in Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    'AidsControlProgramme',
#    ''],
#   ['Sl. No.',
#    'Districts',
#    'identifiedAidspatients',
#    'identifiedAidspatients',
#    'identifiedAidspatients',
#    'identifiedAidspatients',
#    'o.of Patients Cured',
#    'o.of Patients Cured',
#    'o.of Patients Cured',
#    'o.of Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    ''],
#   ['Sl. No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    ''],
#   ['1',
#    '2',
#    '687',
#    '688',
#    '689',
#    '690',
#    '691',
#    '692',
#    '693',
#    '694',
#    '695',
#    '696',
#    '697',
#    '698',
#    '']],
#  [['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2016 In Nos.'],
#   ['Sl.No',
#    'Districts',
#    'Dfl Allopathy Hospitals',
#    'Dfl Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'In dia System of Medicine',
#    '',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Dfl Allopathy Hospitals',
#    'Dfl Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'In dia System of Medicine',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '667',
#    '668',
#    '669',
#    '670',
#    '670.1',
#    '671',
#    '672',
#    '673',
#    '674',
#    '675']]]

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['tAvP', 'uka', 'QjAi', 'flAi', '30.9.2015', 'iaxled', '2005Dy', 'zPr', 'AUq', 'MAz', 'sfi', 'Raing', 'ema', '.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2005 jAz 2015', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2016', '31.3.201', '31.3.2016', '31.3.2016.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'tP', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')
    
    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = { "Services11.1v" : "Services 11.1", "on" : "on 31-03-2016", "Tal" : "Taluka Hq", "UNo AHS pitals" : "No.of Hospitals", "ANSo" : "No.of", "In dia" : "Indian", ".Pentavalent" : "Pentavalent", "Ason31.3.2016" : "As on 31-03-2016", "FRUUnit" : "FRU Unit", "24hoursand" : "24 hours and", "madical" : "medical", "inthisHospitals" : "in this Hospitals", "Plannin" : "Planning", "Pro grammesAs" : "Programmes As", "identifiedAidspatients" : "identified Aids patients", "o.of" : "No.of", "TS" : "TS/TG", "TotalG" : "Total"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(output_list)
output_list
# Out:
# [[['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    '11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'Taluka Hq Hospitals',
#    'Taluka Hq Hospitals',
#    'District Hospitals',
#    'District Hospitals',
#    'Other Hospitals under Hfw',
#    'Other Hospitals under Hfw',
#    'Autonomous Teaching Hospitals',
#    'Autonomous Teaching Hospitals',
#    'Others CHCs',
#    'Others CHCs',
#    'Total',
#    'Total'],
#   ['Sl. No.',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '648',
#    '649',
#    '650',
#    '651',
#    '652',
#    '653',
#    '654',
#    '655',
#    '656',
#    '657',
#    '658',
#    '659']],
#  [['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    '11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.'],
#   ['',
#    '',
#    'No.of Hospitals',
#    'No.of Hospitals',
#    'No.of Hospitals',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    'Govt.',
#    'Private',
#    'Total',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    'Govt.',
#    'Nursing Home Hospitals',
#    'Total',
#    'No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'Blood Banks'],
#   ['1', '2', '660', '661', '662', '663', '664', '665', '666']],
#  [['11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos',
#    '11.5 Family Planning Measures Year 2015-16 In Nos'],
#   ['',
#    '',
#    'Sterlisation',
#    'Sterlisation',
#    'Family Planing Measures in users',
#    'Family Planing Measures in users',
#    'Family Planing Measures in users'],
#   ['', '', 'Vasectomy', 'Tubectomy', 'I.u.d user', 'C.c. user', 'O.p user'],
#   ['1', '2', '682', '683', '684', '685', '686']],
#  [['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    '11.5 Tb Control Programmes on 31-03-2016 in Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    'T.B.Control Programme',
#    ''],
#   ['Sl.No.',
#    'Districts',
#    'No of Identified T.B.patients',
#    'No of Identified T.B.patients',
#    'No of Identified T.B.patients',
#    'Patients Cured',
#    'Patients Cured',
#    'Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    ''],
#   ['Sl.No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '705',
#    '706',
#    '707',
#    '708',
#    '709',
#    '710',
#    '711',
#    '712',
#    '713',
#    '']],
#  [['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    '11.4 Immunisation given to Children Year 2015-16 In Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['Sl.No.',
#    'Districts',
#    'D.p.t.',
#    'Polio',
#    'Bcg',
#    'Measles',
#    'T.t',
#    'Pentavalent includes Hepatities D.p.t'],
#   ['1', '2', '676', '677', '678', '679', '680', '681']],
#  [['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '11.6 Different Health Facilities As on 31-03-2016 in Nos.'],
#   ['',
#    '',
#    'Fru Unit First Referal Units',
#    '108 Ambulances',
#    '108 Ambulances',
#    '24 hours and 7 days working Hospitals',
#    '24 hours and 7 days working Hospitals',
#    'No.of benificiaries in Jananni Suraksh Yojana',
#    'No.of benificiaries medical kit',
#    'Maternal Mortality Death'],
#   ['',
#    '',
#    'Fru Unit First Referal Units',
#    'No.of Vehicals',
#    'No.ofbenefited patients',
#    'Nos.',
#    'No.of delivaries in this Hospitals',
#    'No.of benificiaries in Jananni Suraksh Yojana',
#    'No.of benificiaries medical kit',
#    'Maternal Mortality Death'],
#   ['1', '2', '714', '715', '716', '717', '718', '719', '720', '721']],
#  [['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016'],
#   ['',
#    '',
#    'Leprosy Control Programme',
#    'Leprosy Control Programme',
#    'Leprosy Control Programme',
#    'Leprosy Control Programme',
#    'Leprosy Control Programme',
#    'Leprosy Control Programme'],
#   ['',
#    '',
#    'Identified Leprosy Patients',
#    'Identified Leprosy Patients',
#    'Identified Leprosy Patients',
#    'No.of Patients Cured',
#    'No.of Patients Cured',
#    'No.of Patients Cured'],
#   ['', '', 'Male', 'Female', 'Total', 'Male', 'Female', 'Total'],
#   ['1', '2', '699', '700', '701', '702', '703', '704']],
#  [['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    ''],
#   ['Sl. No.',
#    'Districts',
#    'identified Aids patients',
#    'identified Aids patients',
#    'identified Aids patients',
#    'identified Aids patients',
#    'No.of Patients Cured',
#    'No.of Patients Cured',
#    'No.of Patients Cured',
#    'No.of Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    ''],
#   ['Sl. No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Ts/tg',
#    'Total',
#    'Male',
#    'Female',
#    'Ts/tg',
#    'Total',
#    'Male',
#    'Female',
#    'Ts/tg',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '687',
#    '688',
#    '689',
#    '690',
#    '691',
#    '692',
#    '693',
#    '694',
#    '695',
#    '696',
#    '697',
#    '698',
#    '']],
#  [['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.'],
#   ['Sl.No',
#    'Districts',
#    'Allopathy Hospitals',
#    'Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine',
#    '',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Allopathy Hospitals',
#    'Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '667',
#    '668',
#    '669',
#    '670',
#    '670.1',
#    '671',
#    '672',
#    '673',
#    '674',
#    '675']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Sl. No.',
#    'Sl. No.',
#    '1'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Taluka Hq Hospitals',
#    'Nos.',
#    '648'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Taluka Hq Hospitals',
#    'Beds',
#    '649'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'District Hospitals',
#    'Nos.',
#    '650'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'District Hospitals',
#    'Beds',
#    '651'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Other Hospitals under Hfw',
#    'Nos.',
#    '652'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Other Hospitals under Hfw',
#    'Beds',
#    '653'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Autonomous Teaching Hospitals',
#    'Nos.',
#    '654'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Autonomous Teaching Hospitals',
#    'Beds',
#    '655'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Others CHCs',
#    'Nos.',
#    '656'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Others CHCs',
#    'Beds',
#    '657'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Total',
#    'Nos.',
#    '658'],
#   ['11.1 Taluk District Autonomous Teaching Other Hospitals on 31-03-2016 In Nos.',
#    'Total',
#    'Beds',
#    '659']],
#  [['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.', '', '', '', '1'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.', '', '', '', '2'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    'No.of Hospitals',
#    'Govt.',
#    'Govt.',
#    '660'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    'No.of Hospitals',
#    'Private',
#    'Nursing Home Hospitals',
#    '661'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    'No.of Hospitals',
#    'Total',
#    'Total',
#    '662'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    'No.Govt. Doctors',
#    'No.Govt. Doctors',
#    'No.Govt. Doctors',
#    '663'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    'No.of beds in Govt. Hospitals',
#    'No.of beds in Govt. Hospitals',
#    'No.of beds in Govt. Hospitals',
#    '664'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    'Medical Shops',
#    'Medical Shops',
#    'Medical Shops',
#    '665'],
#   ['11.2 No.of Hospitals Doctors Beds on 31-03-2016 In Nos.',
#    'Blood Banks',
#    'Blood Banks',
#    'Blood Banks',
#    '666']],
#  [['11.5 Family Planning Measures Year 2015-16 In Nos', '', '', '1'],
#   ['11.5 Family Planning Measures Year 2015-16 In Nos', '', '', '2'],
#   ['11.5 Family Planning Measures Year 2015-16 In Nos',
#    'Sterlisation',
#    'Vasectomy',
#    '682'],
#   ['11.5 Family Planning Measures Year 2015-16 In Nos',
#    'Sterlisation',
#    'Tubectomy',
#    '683'],
#   ['11.5 Family Planning Measures Year 2015-16 In Nos',
#    'Family Planing Measures in users',
#    'I.u.d user',
#    '684'],
#   ['11.5 Family Planning Measures Year 2015-16 In Nos',
#    'Family Planing Measures in users',
#    'C.c. user',
#    '685'],
#   ['11.5 Family Planning Measures Year 2015-16 In Nos',
#    'Family Planing Measures in users',
#    'O.p user',
#    '686']],
#  [['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'No of Identified T.B.patients',
#    'Male',
#    '705'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'No of Identified T.B.patients',
#    'Female',
#    '706'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'No of Identified T.B.patients',
#    'Total',
#    '707'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'Patients Cured',
#    'Male',
#    '708'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'Patients Cured',
#    'Female',
#    '709'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'Patients Cured',
#    'Total',
#    '710'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'Death Occurred',
#    'Male',
#    '711'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'Death Occurred',
#    'Female',
#    '712'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.',
#    'T.B.Control Programme',
#    'Death Occurred',
#    'Total',
#    '713'],
#   ['11.5 Tb Control Programmes on 31-03-2016 in Nos.', '', '', '', '']],
#  [['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Immunisation',
#    'D.p.t.',
#    '676'],
#   ['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Immunisation',
#    'Polio',
#    '677'],
#   ['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Immunisation',
#    'Bcg',
#    '678'],
#   ['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Immunisation',
#    'Measles',
#    '679'],
#   ['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Immunisation',
#    'T.t',
#    '680'],
#   ['11.4 Immunisation given to Children Year 2015-16 In Nos.',
#    'Immunisation',
#    'Pentavalent includes Hepatities D.p.t',
#    '681']],
#  [['11.6 Different Health Facilities As on 31-03-2016 in Nos.', '', '', '1'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.', '', '', '2'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    'Fru Unit First Referal Units',
#    'Fru Unit First Referal Units',
#    '714'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '108 Ambulances',
#    'No.of Vehicals',
#    '715'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '108 Ambulances',
#    'No.ofbenefited patients',
#    '716'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '24 hours and 7 days working Hospitals',
#    'Nos.',
#    '717'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    '24 hours and 7 days working Hospitals',
#    'No.of delivaries in this Hospitals',
#    '718'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    'No.of benificiaries in Jananni Suraksh Yojana',
#    'No.of benificiaries in Jananni Suraksh Yojana',
#    '719'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    'No.of benificiaries medical kit',
#    'No.of benificiaries medical kit',
#    '720'],
#   ['11.6 Different Health Facilities As on 31-03-2016 in Nos.',
#    'Maternal Mortality Death',
#    'Maternal Mortality Death',
#    '721']],
#  [['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '',
#    '',
#    '',
#    '1'],
#   ['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    '',
#    '',
#    '',
#    '2'],
#   ['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    'Leprosy Control Programme',
#    'Identified Leprosy Patients',
#    'Male',
#    '699'],
#   ['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    'Leprosy Control Programme',
#    'Identified Leprosy Patients',
#    'Female',
#    '700'],
#   ['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    'Leprosy Control Programme',
#    'Identified Leprosy Patients',
#    'Total',
#    '701'],
#   ['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    'Leprosy Control Programme',
#    'No.of Patients Cured',
#    'Male',
#    '702'],
#   ['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    'Leprosy Control Programme',
#    'No.of Patients Cured',
#    'Female',
#    '703'],
#   ['11.5 Family Planning Measures and Aids prosy Tb Control Programmes As on 31-03-2016',
#    'Leprosy Control Programme',
#    'No.of Patients Cured',
#    'Total',
#    '704']],
#  [['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Sl. No.',
#    'Sl. No.',
#    'Sl. No.',
#    '1'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'identified Aids patients',
#    'Male',
#    '687'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'identified Aids patients',
#    'Female',
#    '688'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'identified Aids patients',
#    'Ts/tg',
#    '689'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'identified Aids patients',
#    'Total',
#    '690'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'No.of Patients Cured',
#    'Male',
#    '691'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'No.of Patients Cured',
#    'Female',
#    '692'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'No.of Patients Cured',
#    'Ts/tg',
#    '693'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'No.of Patients Cured',
#    'Total',
#    '694'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'Death Occurred',
#    'Male',
#    '695'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'Death Occurred',
#    'Female',
#    '696'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'Death Occurred',
#    'Ts/tg',
#    '697'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    'Aids Control Programme',
#    'Death Occurred',
#    'Total',
#    '698'],
#   ['11.5 Aids Leprosy Tb Control Programmes Year 2015-16 in Nos.',
#    '',
#    '',
#    '',
#    '']],
#  [['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Allopathy Hospitals',
#    'Allopathy Hospitals',
#    'Nos.',
#    '667'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Allopathy Hospitals',
#    'Allopathy Hospitals',
#    'Beds',
#    '668'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Nos.',
#    '669'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Beds',
#    '670'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Indian System of Medicine',
#    'Indian System of Medicine',
#    'Nos',
#    '670.1'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    '',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    '671'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Nos.',
#    '672'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Beds',
#    '673'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Community Health Centres',
#    'Community Health Centres',
#    'Nos.',
#    '674'],
#   ['11.3 Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31-03-2016 In Nos.',
#    'Community Health Centres',
#    'Community Health Centres',
#    'Beds',
#    '675']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 11
chapter_name = "Health & Family welfare Services"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id, table_name = find_table_details(inner_list[0][0])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list):
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv(absolute_result_path, sep=';', index=False)
    df.to_csv(absolute_dictionary_path, sep=';', index=False)

# %%
process_dictionary(transp_list)
