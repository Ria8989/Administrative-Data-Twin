# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
path = "/home/riya/Downloads/ADT_2019-20/Output_html_Chapter11/kaggle/working/out/output/"

# %%
os.chdir(path)

# %%
os.listdir()
# Out:
# ['output_page_10.html',
#  'output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_8.html',
#  'output_page_3.html',
#  'output_page_4.html',
#  'output_page_9.html',
#  'output_page_7.html',
#  'output_page_6.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'td', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'mm'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = f"{path}{file}"
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)

# %%
output_list
# Out:
# [[['11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020'],
#   ['Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020'],
#   ['',
#    '',
#    '31-03-2020 on 31-03-2020',
#    '31-03-2020 on 31-03-2020',
#    '31-03-2020 on 31-03-2020',
#    '24 7 Number of 24 7 working Hospitals',
#    '24 7 Number of 24 7 working Hospitals',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['',
#    '',
#    'F.R.U FirstReferral Units',
#    '108 108 Ambulances',
#    '108 108 Ambulances',
#    '24 7 Number of 24 7 working Hospitals',
#    '24 7 Number of 24 7 working Hospitals',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['',
#    '',
#    'F.R.U FirstReferral Units',
#    '108 108 Ambulances',
#    '108 108 Ambulances',
#    'Nos',
#    '2019-20 24 7 24 7 Delivaries occured in Hospitals during 2019-20',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['',
#    '',
#    'F.R.U FirstReferral Units',
#    'No. of Vehicles',
#    'No. of Patients benefited',
#    'Nos',
#    '2019-20 24 7 24 7 Delivaries occured in Hospitals during 2019-20',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['1', '2', '1216', '1217', '1218', '1219', '1220', '1221', '1222', '1223']],
#  [['11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services'],
#   ['11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['SI.No',
#    'Districts',
#    'Taluk Hospitals',
#    'Taluk Hospitals',
#    'District Hospitals',
#    'District Hospitals',
#    'Other Hospitals under HFW',
#    'Other Hospitals under HFW'],
#   ['SI.No', 'Districts', '', '', '', '', '', ''],
#   ['SI.No', 'Districts', 'Nos.', 'Beds', 'Nos.', 'Beds', 'Nos.', 'Beds'],
#   ['1', '2', '1151', '1152', '1153', '1154', '1155', '1156']],
#  [['11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services',
#    '11. Health Family Welfare Services'],
#   ['11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['SI.No',
#    'Districts',
#    'Autonom Teaching Hospitals',
#    'Autonom Teaching Hospitals',
#    'ous CommuniHealth Centres',
#    'ous CommuniHealth Centres',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Total Allopathy Hospitals',
#    'Total Allopathy Hospitals'],
#   ['SI.No', 'Districts', '', '', '', '', '', '', '', ''],
#   ['SI.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1', '2', '1157', '1158', '1159', '1160', '1161', '1162', '1163', '1164']],
#  [['11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20'],
#   ['Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers'],
#   ['',
#    '',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['',
#    '',
#    'D.P.T',
#    'Polio',
#    'BCG',
#    'M.R',
#    'TD',
#    'Pentavalent includes DPT Hepatities',
#    'Rota']],
#  [['11.5', '11.5', '11.5', '11.5', '11.5', '11.5', '11.5', '11.5'],
#   ['AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers'],
#   ['SI.No',
#    'Districts',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20'],
#   ['SI.No',
#    'Districts',
#    'Identified Leprosy patients',
#    'Identified Leprosy patients',
#    'Identified Leprosy patients',
#    'Leprosy Patients Cured',
#    'Leprosy Patients Cured',
#    'Leprosy Patients Cured'],
#   ['SI.No', 'Districts', 'Male', 'Female', 'Total', 'Male', 'Female', 'Total'],
#   ['1', '2', '1201', '1202', '1203', '1204', '1205', '1206']],
#  [['11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020'],
#   ['No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative'],
#   ['SI. No',
#    'Districts',
#    'Ayush Hospitals',
#    'Ayush Hospitals',
#    'Ayush Hospitals',
#    'Govt.Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    'Govt.Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    'Pvt. Hospitals Including Nursing Homes Clinics',
#    'Pvt. Hospitals Including Nursing Homes Clinics'],
#   ['SI. No', 'Districts', '', '', '', '', '', '', ''],
#   ['SI. No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Dispensary',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1', '2', '1165', '1166', '1167', '1168', '1169', '1170', '1171']],
#  [['11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020'],
#   ['No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative'],
#   ['',
#    '',
#    'Total No. of Hospitals and Beds Govt Private',
#    'Total No. of Hospitals and Beds Govt Private',
#    'Total No. of Hospitals and Beds Govt Private',
#    'No. of Doctors',
#    'No. of Doctors',
#    'No. of Doctors',
#    'No. of Doctors',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    '',
#    '',
#    '% to state total',
#    '',
#    '',
#    '',
#    '% to state total',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    'Nos.',
#    'Beds',
#    '% to state total',
#    'ovt',
#    'Priva.',
#    'Total',
#    '% to state total',
#    'Medical Shops',
#    'Blood Banks'],
#   ['1',
#    '2',
#    '1172',
#    '1173',
#    '1174',
#    '1175',
#    '1176',
#    '1177',
#    '1178',
#    '1179',
#    '1180']],
#  [['11.5', '11.5', '11.5'],
#   ['AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers'],
#   ['SI. No',
#    'Districts',
#    '2019-20 T.B patients identified cured and death occured during 2019-20'],
#   ['SI. No',
#    'Districts',
#    'Identified T.B Patients Cured T.B Patients T.B Patients Death Occured'],
#   ['SI. No',
#    'Districts',
#    'Male Female Total Male Female Total Male Female Total']],
#  [['11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5'],
#   ['AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers'],
#   ['SI.No',
#    'Districts',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20'],
#   ['SI.No',
#    'Districts',
#    'Identified AIDS patients',
#    'Identified AIDS patients',
#    'Identified AIDS patients',
#    'Identified AIDS patients',
#    'AIDS Patients Death Occured',
#    'AIDS Patients Death Occured',
#    'AIDS Patients Death Occured',
#    'AIDS Patients Death Occured'],
#   ['SI.No',
#    'Districts',
#    'Male',
#    'Female',
#    'TS TG',
#    'Total',
#    'Male',
#    'Female',
#    'TS TG',
#    'Total'],
#   ['1', '2', '1193', '1194', '1195', '1196', '1197', '1198', '1199', '1200']],
#  [['11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4'],
#   ['Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers'],
#   ['SI. No',
#    'Districts',
#    '2019-20 Sterlisation during 2019-20',
#    '2019-20 Sterlisation during 2019-20',
#    '2019-20 Users of Family Welfare Services during 2019-20',
#    '2019-20 Users of Family Welfare Services during 2019-20',
#    '2019-20 Users of Family Welfare Services during 2019-20'],
#   ['SI. No',
#    'Districts',
#    'Vasectomy',
#    'Tubectomy',
#    'I.U.D users',
#    'C.C.users',
#    'O.P users'],
#   ['1', '2', '1188', '1189', '1190', '1191', '1192']]]

# %%
def contain_table_id(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'(?<!\S)(?:' + '(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})' + r')(?!\S)', flags=re.IGNORECASE)

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) == 0:
        return False
    return True

# %%
def are_all_same_id(lst):
    if not lst:
        return False  # An empty list cannot have all same elements.
    first_element = lst[0]
    if first_element != '' and contain_table_id(first_element):
        return all(element == first_element for element in lst[:-1])
    return False

def are_all_same_name(lst):
    if not lst:
        return False  # An empty list cannot have all same elements.
    first_element = lst[0]
    if first_element != '':
        return all(element == first_element for element in lst[:-1])
    return False

# %%
def check_for_table(item):
    i=0
    new_item = item
    for k in range(len(item)):
        id_list=[]
        if are_all_same_id(item[k]):
            if i<1:
                i = i+1
            elif i==2:
                return item
        elif i==1 and are_all_same_name(item[k]):
            return item
        elif i==1 and not are_all_same_name(item[k]):
            n_lst = item[k-1]
            new_item.insert(0,n_lst)
            i = i+1
            return new_item
        else:
            new_item.remove(item[k])
            return check_for_table(new_item)

# %%
corrected_list=[]
error_list=[]
for inner_list in output_list:
    initial_val = inner_list.copy()
    item = check_for_table(inner_list)
    if item is not None and len(item)>0:
        corrected_list.append(item)
    else:
        error_list.append(initial_val)

# %%
corrected_list
# Out:
# [[['11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020'],
#   ['Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020',
#    'Different Health Facilities on 31.03.2020'],
#   ['',
#    '',
#    '31-03-2020 on 31-03-2020',
#    '31-03-2020 on 31-03-2020',
#    '31-03-2020 on 31-03-2020',
#    '24 7 Number of 24 7 working Hospitals',
#    '24 7 Number of 24 7 working Hospitals',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['',
#    '',
#    'F.R.U FirstReferral Units',
#    '108 108 Ambulances',
#    '108 108 Ambulances',
#    '24 7 Number of 24 7 working Hospitals',
#    '24 7 Number of 24 7 working Hospitals',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['',
#    '',
#    'F.R.U FirstReferral Units',
#    '108 108 Ambulances',
#    '108 108 Ambulances',
#    'Nos',
#    '2019-20 24 7 24 7 Delivaries occured in Hospitals during 2019-20',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['',
#    '',
#    'F.R.U FirstReferral Units',
#    'No. of Vehicles',
#    'No. of Patients benefited',
#    'Nos',
#    '2019-20 24 7 24 7 Delivaries occured in Hospitals during 2019-20',
#    '2019-20 No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '2019-20 No. oBeneficiaries receivedMadilu kit during 2019- 20',
#    '2019- 20 Mater nal 20Deat19-h20'],
#   ['1', '2', '1216', '1217', '1218', '1219', '1220', '1221', '1222', '1223']],
#  [['11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['SI.No',
#    'Districts',
#    'Taluk Hospitals',
#    'Taluk Hospitals',
#    'District Hospitals',
#    'District Hospitals',
#    'Other Hospitals under HFW',
#    'Other Hospitals under HFW'],
#   ['SI.No', 'Districts', '', '', '', '', '', ''],
#   ['SI.No', 'Districts', 'Nos.', 'Beds', 'Nos.', 'Beds', 'Nos.', 'Beds'],
#   ['1', '2', '1151', '1152', '1153', '1154', '1155', '1156']],
#  [['11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 31-3-2020 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['SI.No',
#    'Districts',
#    'Autonom Teaching Hospitals',
#    'Autonom Teaching Hospitals',
#    'ous CommuniHealth Centres',
#    'ous CommuniHealth Centres',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Total Allopathy Hospitals',
#    'Total Allopathy Hospitals'],
#   ['SI.No', 'Districts', '', '', '', '', '', '', '', ''],
#   ['SI.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1', '2', '1157', '1158', '1159', '1160', '1161', '1162', '1163', '1164']],
#  [['11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20'],
#   ['Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers'],
#   ['',
#    '',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['',
#    '',
#    'D.P.T',
#    'Polio',
#    'BCG',
#    'M.R',
#    'TD',
#    'Pentavalent includes DPT Hepatities',
#    'Rota']],
#  [['11.5', '11.5', '11.5', '11.5', '11.5', '11.5', '11.5', '11.5'],
#   ['AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers'],
#   ['SI.No',
#    'Districts',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20',
#    '2019-20 Lepros Patients identified and cured durin 2019-20'],
#   ['SI.No',
#    'Districts',
#    'Identified Leprosy patients',
#    'Identified Leprosy patients',
#    'Identified Leprosy patients',
#    'Leprosy Patients Cured',
#    'Leprosy Patients Cured',
#    'Leprosy Patients Cured'],
#   ['SI.No', 'Districts', 'Male', 'Female', 'Total', 'Male', 'Female', 'Total'],
#   ['1', '2', '1201', '1202', '1203', '1204', '1205', '1206']],
#  [['11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020'],
#   ['No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative'],
#   ['SI. No',
#    'Districts',
#    'Ayush Hospitals',
#    'Ayush Hospitals',
#    'Ayush Hospitals',
#    'Govt.Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    'Govt.Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    'Pvt. Hospitals Including Nursing Homes Clinics',
#    'Pvt. Hospitals Including Nursing Homes Clinics'],
#   ['SI. No', 'Districts', '', '', '', '', '', '', ''],
#   ['SI. No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Dispensary',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1', '2', '1165', '1166', '1167', '1168', '1169', '1170', '1171']],
#  [['11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020'],
#   ['No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No. of Hospitals Doctors Beds on 31-3-2020 Cumulative'],
#   ['',
#    '',
#    'Total No. of Hospitals and Beds Govt Private',
#    'Total No. of Hospitals and Beds Govt Private',
#    'Total No. of Hospitals and Beds Govt Private',
#    'No. of Doctors',
#    'No. of Doctors',
#    'No. of Doctors',
#    'No. of Doctors',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    '',
#    '',
#    '% to state total',
#    '',
#    '',
#    '',
#    '% to state total',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    'Nos.',
#    'Beds',
#    '% to state total',
#    'ovt',
#    'Priva.',
#    'Total',
#    '% to state total',
#    'Medical Shops',
#    'Blood Banks'],
#   ['1',
#    '2',
#    '1172',
#    '1173',
#    '1174',
#    '1175',
#    '1176',
#    '1177',
#    '1178',
#    '1179',
#    '1180']],
#  [['11.5', '11.5', '11.5'],
#   ['AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers'],
#   ['SI. No',
#    'Districts',
#    '2019-20 T.B patients identified cured and death occured during 2019-20'],
#   ['SI. No',
#    'Districts',
#    'Identified T.B Patients Cured T.B Patients T.B Patients Death Occured'],
#   ['SI. No',
#    'Districts',
#    'Male Female Total Male Female Total Male Female Total']],
#  [['11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5'],
#   ['AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers',
#    'AIDS Leprosy and TB Control Programmes In numbers'],
#   ['SI.No',
#    'Districts',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20',
#    '2019-20 AIDS Patients identified and death occured during 2019-20'],
#   ['SI.No',
#    'Districts',
#    'Identified AIDS patients',
#    'Identified AIDS patients',
#    'Identified AIDS patients',
#    'Identified AIDS patients',
#    'AIDS Patients Death Occured',
#    'AIDS Patients Death Occured',
#    'AIDS Patients Death Occured',
#    'AIDS Patients Death Occured'],
#   ['SI.No',
#    'Districts',
#    'Male',
#    'Female',
#    'TS TG',
#    'Total',
#    'Male',
#    'Female',
#    'TS TG',
#    'Total'],
#   ['1', '2', '1193', '1194', '1195', '1196', '1197', '1198', '1199', '1200']],
#  [['11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4'],
#   ['Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers'],
#   ['SI. No',
#    'Districts',
#    '2019-20 Sterlisation during 2019-20',
#    '2019-20 Sterlisation during 2019-20',
#    '2019-20 Users of Family Welfare Services during 2019-20',
#    '2019-20 Users of Family Welfare Services during 2019-20',
#    '2019-20 Users of Family Welfare Services during 2019-20'],
#   ['SI. No',
#    'Districts',
#    'Vasectomy',
#    'Tubectomy',
#    'I.U.D users',
#    'C.C.users',
#    'O.P users'],
#   ['1', '2', '1188', '1189', '1190', '1191', '1192']]]

# %%
error_list
# Out:
# []

# %%
list_to_remove = [[['11.5', '11.5', '11.5'],
  ['AIDS Leprosy and TB Control Programmes In numbers',
   'AIDS Leprosy and TB Control Programmes In numbers',
   'AIDS Leprosy and TB Control Programmes In numbers'],
  ['SI. No',
   'Districts',
   '2019-20 T.B patients identified cured and death occured during 2019-20'],
  ['SI. No',
   'Districts',
   'Identified T.B Patients Cured T.B Patients T.B Patients Death Occured'],
  ['SI. No',
   'Districts',
   'Male Female Total Male Female Total Male Female Total']],
  [['11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20'],
  ['Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers'],
  ['',
   '',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation'],
  ['',
   '',
   'D.P.T',
   'Polio',
   'BCG',
   'M.R',
   'TD',
   'Pentavalent includes DPT Hepatities',
   'Rota']]]

# %%
for item in list_to_remove:
    corrected_list.remove(item)

# %%
list_to_add = [[['11.5', '11.5', '11.5','11.5', '11.5', '11.5','11.5','11.5', '11.5', '11.5','11.5'],
  ['AIDS Leprosy and TB Control Programmes In numbers', 
  'AIDS Leprosy and TB Control Programmes In numbers', 
  'AIDS Leprosy and TB Control Programmes In numbers', 
  'AIDS Leprosy and TB Control Programmes In numbers', 
  'AIDS Leprosy and TB Control Programmes In numbers',
   'AIDS Leprosy and TB Control Programmes In numbers', 
   'AIDS Leprosy and TB Control Programmes In numbers', 
   'AIDS Leprosy and TB Control Programmes In numbers', 
   'AIDS Leprosy and TB Control Programmes In numbers', 
   'AIDS Leprosy and TB Control Programmes In numbers',
   'AIDS Leprosy and TB Control Programmes In numbers'],
  ['SI. No',
   'Districts',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20',
   'T.B patients identified cured and death occured during 2019-20'],
  ['SI. No',
   'Districts',
   'Identified T.B Patients',
   'Identified T.B Patients',
   'Identified T.B Patients',
   'Cured T.B Patients',
   'Cured T.B Patients',
   'Cured T.B Patients',
   'T.B Patients Death Occured',
   'T.B Patients Death Occured',
   'T.B Patients Death Occured'],
  ['SI. No',
   'Districts',
   'Male',
   'Female',
   'Total',
   'Male',
   'Female',
   'Total',
   'Male',
   'Female',
   'Total'],
   ['1', '2', '1207','1208','1209','1210','1211','1212','1213','1214','1215']],
   [['11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20',
   '11.3 2019 20'],
  ['Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers',
   'Immunisation given to Children during 2019-20 In Numbers'],
  ['',
   '',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation',
   'Immunisation'],
  ['',
   '',
   'D.P.T',
   'Polio',
   'BCG',
   'M.R',
   'TD',
   'Pentavalent includes DPT Hepatities',
   'Rota'],
   ['1','2','1181','1182','1183','1184','1185','1186','1187']]]

# %%
corrected_list.extend(list_to_add)

# %%
len(output_list)
# Out:
# 10

# %%
len(corrected_list)
# Out:
# 10

# %%
len(error_list)
# Out:
# 0

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].end()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def remove_after_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].end()
        input_string = input_string[:second_occurrence_index]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['ous', '2019-20 24 7', '1 2', '6 14', '2009 2019', '1961 201', '-2011', '0-6 2011', '0-6 2001', '0-6 2001 2011', '2001 and 2011', '20 01', '2011 2021', '31.03', '.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2020', '31.3.202', '31.3.2020', '31.3.2020.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')

    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = {"Facilities on" : "Facilities on 31-01-2020", "31-03-2020 on" : "as on", "24 7 Number" : "Number", "2019-20 No." : "No.", "oBeneficiaries" : "of Beneficiaries", "24 7 working" : "24/7 working", "2019- 20 Mater nal 20Deat19-h20" : "Maternal Death 2019-20", "108 108" : "108", "24 7 Delivaries" : "24/7 Delivaries", "31-3-2020 Taluk" : "Taluk", "CommuniHealth" : "Community Health", "Hepatities" : "Hepatities B", "2019-20 Lepros" : "Lepros", "durin" : "during","Govt.Hospitals" : "Govt. Hospitals", "No. of" : "No.of", "ovt" : "Govt", "2019-20 AIDS" : "AIDS", "TS TG" : "TS/TG", "2019-20 Sterlisation" : "Sterlisation", "2019-20 Users" : "Users"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(corrected_list)
corrected_list
# Out:
# [[['11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020',
#    '11.6 31-03-2020'],
#   ['Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Different Health Facilities on 31-01-2020'],
#   ['',
#    '',
#    'as on 31-03-2020',
#    'as on 31-03-2020',
#    'as on 31-03-2020',
#    'Number of working Hospitals',
#    'Number of working Hospitals',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    'Maternal Death 2019-20'],
#   ['',
#    '',
#    'F.r.u First Referral Units',
#    '108 Ambulances',
#    '108 Ambulances',
#    'Number of working Hospitals',
#    'Number of working Hospitals',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    'Maternal Death 2019-20'],
#   ['',
#    '',
#    'F.r.u First Referral Units',
#    '108 Ambulances',
#    '108 Ambulances',
#    'Nos',
#    'Delivaries occured in Hospitals during 2019-20',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    'Maternal Death 2019-20'],
#   ['',
#    '',
#    'F.r.u First Referral Units',
#    'No.of Vehicles',
#    'No.of Patients benefited',
#    'Nos',
#    'Delivaries occured in Hospitals during 2019-20',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    'Maternal Death 2019-20'],
#   ['1', '2', '1216', '1217', '1218', '1219', '1220', '1221', '1222', '1223']],
#  [['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['SI.No',
#    'Districts',
#    'Taluk Hospitals',
#    'Taluk Hospitals',
#    'District Hospitals',
#    'District Hospitals',
#    'Other Hospitals under Hfw',
#    'Other Hospitals under Hfw'],
#   ['SI.No', 'Districts', '', '', '', '', '', ''],
#   ['SI.No', 'Districts', 'Nos.', 'Beds', 'Nos.', 'Beds', 'Nos.', 'Beds'],
#   ['1', '2', '1151', '1152', '1153', '1154', '1155', '1156']],
#  [['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative'],
#   ['SI.No',
#    'Districts',
#    'Autonom Teaching Hospitals',
#    'Autonom Teaching Hospitals',
#    'Community Health Centres',
#    'Community Health Centres',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Total Allopathy Hospitals',
#    'Total Allopathy Hospitals'],
#   ['SI.No', 'Districts', '', '', '', '', '', '', '', ''],
#   ['SI.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1', '2', '1157', '1158', '1159', '1160', '1161', '1162', '1163', '1164']],
#  [['11.5', '11.5', '11.5', '11.5', '11.5', '11.5', '11.5', '11.5'],
#   ['Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers'],
#   ['SI.No',
#    'Districts',
#    'Lepros Patients identified and cured during 2019-20',
#    'Lepros Patients identified and cured during 2019-20',
#    'Lepros Patients identified and cured during 2019-20',
#    'Lepros Patients identified and cured during 2019-20',
#    'Lepros Patients identified and cured during 2019-20',
#    'Lepros Patients identified and cured during 2019-20'],
#   ['SI.No',
#    'Districts',
#    'Identified Leprosy patients',
#    'Identified Leprosy patients',
#    'Identified Leprosy patients',
#    'Leprosy Patients Cured',
#    'Leprosy Patients Cured',
#    'Leprosy Patients Cured'],
#   ['SI.No', 'Districts', 'Male', 'Female', 'Total', 'Male', 'Female', 'Total'],
#   ['1', '2', '1201', '1202', '1203', '1204', '1205', '1206']],
#  [['11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020'],
#   ['No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative'],
#   ['Si. No',
#    'Districts',
#    'Ayush Hospitals',
#    'Ayush Hospitals',
#    'Ayush Hospitals',
#    'Govt. Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    'Govt. Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    'Pvt. Hospitals Including Nursing Homes Clinics',
#    'Pvt. Hospitals Including Nursing Homes Clinics'],
#   ['Si. No', 'Districts', '', '', '', '', '', '', ''],
#   ['Si. No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Dispensary',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1', '2', '1165', '1166', '1167', '1168', '1169', '1170', '1171']],
#  [['11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020',
#    '11.2 31-3-2020'],
#   ['No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative'],
#   ['',
#    '',
#    'Total No.of Hospitals and Beds Govt Private',
#    'Total No.of Hospitals and Beds Govt Private',
#    'Total No.of Hospitals and Beds Govt Private',
#    'No.of Doctors',
#    'No.of Doctors',
#    'No.of Doctors',
#    'No.of Doctors',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    '',
#    '',
#    '% to state total',
#    '',
#    '',
#    '',
#    '% to state total',
#    'Medical Shops',
#    'Blood Banks'],
#   ['',
#    '',
#    'Nos.',
#    'Beds',
#    '% to state total',
#    'Govt',
#    'Priva.',
#    'Total',
#    '% to state total',
#    'Medical Shops',
#    'Blood Banks'],
#   ['1',
#    '2',
#    '1172',
#    '1173',
#    '1174',
#    '1175',
#    '1176',
#    '1177',
#    '1178',
#    '1179',
#    '1180']],
#  [['11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5'],
#   ['Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers'],
#   ['SI.No',
#    'Districts',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients identified and death occured during 2019-20'],
#   ['SI.No',
#    'Districts',
#    'Identified Aids patients',
#    'Identified Aids patients',
#    'Identified Aids patients',
#    'Identified Aids patients',
#    'Aids Patients Death Occured',
#    'Aids Patients Death Occured',
#    'Aids Patients Death Occured',
#    'Aids Patients Death Occured'],
#   ['SI.No',
#    'Districts',
#    'Male',
#    'Female',
#    'Ts/tg',
#    'Total',
#    'Male',
#    'Female',
#    'Ts/tg',
#    'Total'],
#   ['1', '2', '1193', '1194', '1195', '1196', '1197', '1198', '1199', '1200']],
#  [['11.4', '11.4', '11.4', '11.4', '11.4', '11.4', '11.4'],
#   ['Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers',
#    'Family Welfare Services In numbers'],
#   ['Si. No',
#    'Districts',
#    'Sterlisation during 2019-20',
#    'Sterlisation during 2019-20',
#    'Users of Family Welfare Services during 2019-20',
#    'Users of Family Welfare Services during 2019-20',
#    'Users of Family Welfare Services during 2019-20'],
#   ['Si. No',
#    'Districts',
#    'Vasectomy',
#    'Tubectomy',
#    'I.u.d users',
#    'C.C.users',
#    'O.p users'],
#   ['1', '2', '1188', '1189', '1190', '1191', '1192']],
#  [['11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5',
#    '11.5'],
#   ['Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Leprosy and Tb Control Programmes In numbers'],
#   ['Si. No',
#    'Districts',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b patients identified cured and death occured during 2019-20'],
#   ['Si. No',
#    'Districts',
#    'Identified T.b Patients',
#    'Identified T.b Patients',
#    'Identified T.b Patients',
#    'Cured T.b Patients',
#    'Cured T.b Patients',
#    'Cured T.b Patients',
#    'T.b Patients Death Occured',
#    'T.b Patients Death Occured',
#    'T.b Patients Death Occured'],
#   ['Si. No',
#    'Districts',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total'],
#   ['1',
#    '2',
#    '1207',
#    '1208',
#    '1209',
#    '1210',
#    '1211',
#    '1212',
#    '1213',
#    '1214',
#    '1215']],
#  [['11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20',
#    '11.3 2019 20'],
#   ['Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation given to Children during 2019-20 In Numbers'],
#   ['',
#    '',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['',
#    '',
#    'D.p.t',
#    'Polio',
#    'Bcg',
#    'M.r',
#    'Td',
#    'Pentavalent includes Dpt Hepatities B',
#    'Rota'],
#   ['1', '2', '1181', '1182', '1183', '1184', '1185', '1186', '1187']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in corrected_list]
transp_list
# Out:
# [[['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    '',
#    '',
#    '',
#    '',
#    '1'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    '',
#    '',
#    '',
#    '',
#    '2'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'as on 31-03-2020',
#    'F.r.u First Referral Units',
#    'F.r.u First Referral Units',
#    'F.r.u First Referral Units',
#    '1216'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'as on 31-03-2020',
#    '108 Ambulances',
#    '108 Ambulances',
#    'No.of Vehicles',
#    '1217'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'as on 31-03-2020',
#    '108 Ambulances',
#    '108 Ambulances',
#    'No.of Patients benefited',
#    '1218'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Number of working Hospitals',
#    'Number of working Hospitals',
#    'Nos',
#    'Nos',
#    '1219'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Number of working Hospitals',
#    'Number of working Hospitals',
#    'Delivaries occured in Hospitals during 2019-20',
#    'Delivaries occured in Hospitals during 2019-20',
#    '1220'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    'No. of Beneficiaries availed Janani Suraksha Yojana during 2019-20',
#    '1221'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    'No. of Beneficiaries received Madilu kit during 2019- 20',
#    '1222'],
#   ['11.6 31-03-2020',
#    'Different Health Facilities on 31-01-2020',
#    'Maternal Death 2019-20',
#    'Maternal Death 2019-20',
#    'Maternal Death 2019-20',
#    'Maternal Death 2019-20',
#    '1223']],
#  [['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Taluk Hospitals',
#    '',
#    'Nos.',
#    '1151'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Taluk Hospitals',
#    '',
#    'Beds',
#    '1152'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'District Hospitals',
#    '',
#    'Nos.',
#    '1153'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'District Hospitals',
#    '',
#    'Beds',
#    '1154'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Other Hospitals under Hfw',
#    '',
#    'Nos.',
#    '1155'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Other Hospitals under Hfw',
#    '',
#    'Beds',
#    '1156']],
#  [['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Autonom Teaching Hospitals',
#    '',
#    'Nos.',
#    '1157'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Autonom Teaching Hospitals',
#    '',
#    'Beds',
#    '1158'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Community Health Centres',
#    '',
#    'Nos.',
#    '1159'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Community Health Centres',
#    '',
#    'Beds',
#    '1160'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Primary Health Centres',
#    '',
#    'Nos.',
#    '1161'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Primary Health Centres',
#    '',
#    'Beds',
#    '1162'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Total Allopathy Hospitals',
#    '',
#    'Nos.',
#    '1163'],
#   ['11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    '11.1 Taluk District Autonomous Teaching and Other Hospitals on 31-3-2020 In numbers Cumulative',
#    'Total Allopathy Hospitals',
#    '',
#    'Beds',
#    '1164']],
#  [['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Lepros Patients identified and cured during 2019-20',
#    'Identified Leprosy patients',
#    'Male',
#    '1201'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Lepros Patients identified and cured during 2019-20',
#    'Identified Leprosy patients',
#    'Female',
#    '1202'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Lepros Patients identified and cured during 2019-20',
#    'Identified Leprosy patients',
#    'Total',
#    '1203'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Lepros Patients identified and cured during 2019-20',
#    'Leprosy Patients Cured',
#    'Male',
#    '1204'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Lepros Patients identified and cured during 2019-20',
#    'Leprosy Patients Cured',
#    'Female',
#    '1205'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Lepros Patients identified and cured during 2019-20',
#    'Leprosy Patients Cured',
#    'Total',
#    '1206']],
#  [['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Si. No',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Ayush Hospitals',
#    '',
#    'Nos.',
#    '1165'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Ayush Hospitals',
#    '',
#    'Beds',
#    '1166'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Ayush Hospitals',
#    '',
#    'Dispensary',
#    '1167'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Govt. Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    '',
#    'Nos.',
#    '1168'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Govt. Hospitals Allopathy Hospitals Indian System of Medicine Hospitals',
#    '',
#    'Beds',
#    '1169'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Pvt. Hospitals Including Nursing Homes Clinics',
#    '',
#    'Nos.',
#    '1170'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Pvt. Hospitals Including Nursing Homes Clinics',
#    '',
#    'Beds',
#    '1171']],
#  [['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    '',
#    '',
#    '',
#    '1'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    '',
#    '',
#    '',
#    '2'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Total No.of Hospitals and Beds Govt Private',
#    '',
#    'Nos.',
#    '1172'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Total No.of Hospitals and Beds Govt Private',
#    '',
#    'Beds',
#    '1173'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Total No.of Hospitals and Beds Govt Private',
#    '% to state total',
#    '% to state total',
#    '1174'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Doctors',
#    '',
#    'Govt',
#    '1175'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Doctors',
#    '',
#    'Priva.',
#    '1176'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Doctors',
#    '',
#    'Total',
#    '1177'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'No.of Doctors',
#    '% to state total',
#    '% to state total',
#    '1178'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Medical Shops',
#    'Medical Shops',
#    'Medical Shops',
#    '1179'],
#   ['11.2 31-3-2020',
#    'No.of Hospitals Doctors Beds on 31-3-2020 Cumulative',
#    'Blood Banks',
#    'Blood Banks',
#    'Blood Banks',
#    '1180']],
#  [['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Identified Aids patients',
#    'Male',
#    '1193'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Identified Aids patients',
#    'Female',
#    '1194'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Identified Aids patients',
#    'Ts/tg',
#    '1195'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Identified Aids patients',
#    'Total',
#    '1196'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients Death Occured',
#    'Male',
#    '1197'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients Death Occured',
#    'Female',
#    '1198'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients Death Occured',
#    'Ts/tg',
#    '1199'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Aids Patients identified and death occured during 2019-20',
#    'Aids Patients Death Occured',
#    'Total',
#    '1200']],
#  [['11.4', 'Family Welfare Services In numbers', 'Si. No', 'Si. No', '1'],
#   ['11.4',
#    'Family Welfare Services In numbers',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.4',
#    'Family Welfare Services In numbers',
#    'Sterlisation during 2019-20',
#    'Vasectomy',
#    '1188'],
#   ['11.4',
#    'Family Welfare Services In numbers',
#    'Sterlisation during 2019-20',
#    'Tubectomy',
#    '1189'],
#   ['11.4',
#    'Family Welfare Services In numbers',
#    'Users of Family Welfare Services during 2019-20',
#    'I.u.d users',
#    '1190'],
#   ['11.4',
#    'Family Welfare Services In numbers',
#    'Users of Family Welfare Services during 2019-20',
#    'C.C.users',
#    '1191'],
#   ['11.4',
#    'Family Welfare Services In numbers',
#    'Users of Family Welfare Services during 2019-20',
#    'O.p users',
#    '1192']],
#  [['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Si. No',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'Identified T.b Patients',
#    'Male',
#    '1207'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'Identified T.b Patients',
#    'Female',
#    '1208'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'Identified T.b Patients',
#    'Total',
#    '1209'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'Cured T.b Patients',
#    'Male',
#    '1210'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'Cured T.b Patients',
#    'Female',
#    '1211'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'Cured T.b Patients',
#    'Total',
#    '1212'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b Patients Death Occured',
#    'Male',
#    '1213'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b Patients Death Occured',
#    'Female',
#    '1214'],
#   ['11.5',
#    'Aids Leprosy and Tb Control Programmes In numbers',
#    'T.b patients identified cured and death occured during 2019-20',
#    'T.b Patients Death Occured',
#    'Total',
#    '1215']],
#  [['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    '',
#    '',
#    '1'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    '',
#    '',
#    '2'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation',
#    'D.p.t',
#    '1181'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation',
#    'Polio',
#    '1182'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation',
#    'Bcg',
#    '1183'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation',
#    'M.r',
#    '1184'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation',
#    'Td',
#    '1185'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation',
#    'Pentavalent includes Dpt Hepatities B',
#    '1186'],
#   ['11.3 2019 20',
#    'Immunisation given to Children during 2019-20 In Numbers',
#    'Immunisation',
#    'Rota',
#    '1187']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            print(string)
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 11
chapter_name = "Health & Family Welfare Services"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id = remove_after_all_occurrence(inner_list[0][0])
        table_name = remove_before_all_occurrence(inner_list[0][1])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list)-1:
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Output_html_Chapter11/Chapter11_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Dictionary/Chapter11_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)
