# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
path = "/home/riya/Downloads/ADT_2019-20/Output_html_Chapter9/kaggle/working/out/output/"

# %%
os.chdir(path)

# %%
os.listdir()
# Out:
# ['output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_3.html',
#  'output_page_4.html',
#  'output_page_7.html',
#  'output_page_6.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'mm'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = f"{path}{file}"
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)

# %%
output_list
# Out:
# [[['Transport and Communication',
#    'Transport and Communication',
#    'Transport and Communication',
#    'Transport and Communication',
#    'Transport and Communication',
#    'Transport and Communication',
#    'Transport and Communication'],
#   ['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers'],
#   ['SI.',
#    'Distircts',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles'],
#   ['SI.', 'Distircts', '', '', '', '', ''],
#   ['SI.',
#    'Distircts',
#    'Multiaxled Airculated Vehicles',
#    'Trucks and Lorries',
#    'Four Wheelers',
#    'Three Wheelers',
#    'Total'],
#   ['1', '2', '977', '978', '979', '980', '981']],
#  [['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers'],
#   ['', '', 'Buses', 'Buses', 'Buses', 'Buses', 'Buses', 'Total Buses'],
#   ['',
#    '',
#    'Stage Carriag',
#    'Contract Vehicles',
#    'Private Service Vehicles',
#    'Educational InstitutionVehicles',
#    'Other Buses',
#    'Total Buses'],
#   ['1', '2', '982', '983', '984', '985', '986', '987']],
#  [['9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020'],
#   ['P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative'],
#   ['',
#    '',
#    'National Highway',
#    'State Highway',
#    'Major District Roads',
#    'Major Bridges in Nos.',
#    'Length of Railway Lines'],
#   ['1', '2', '1006', '1007', '1008', '1009', '1010']],
#  [['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers'],
#   ['SI. No',
#    'Distircts',
#    'Taxies',
#    'Taxies',
#    'Taxies',
#    'Passengers Vehicles',
#    'Passengers Vehicles',
#    'Two Wheelers',
#    'Two Wheelers',
#    'Two Wheelers',
#    'Two Wheelers'],
#   ['SI. No', 'Distircts', '', '', '', '', '', '', '', '', ''],
#   ['SI. No',
#    'Distircts',
#    'Motor Cabs',
#    'Maxi Cabs',
#    'Other Cabs',
#    'Three Seated Vehicles Auto Rickshaws',
#    'Four to SixSeated Vehiclea',
#    'Scooters',
#    'Mopeds',
#    'Motor Cycles',
#    'Total'],
#   ['1', '2', '988', '989', '990', '991', '992', '993', '994', '995', '996']],
#  [['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers'],
#   ['',
#    '',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Vehicles For Carrying Construction Materials',
#    'Others Vehicles',
#    'Total Motor Vehicles',
#    '% of total motor vehicles to the statetotal'],
#   ['',
#    '',
#    'Cars',
#    'Jeep',
#    'Omni Bus',
#    'Tractors',
#    'Tillers',
#    'Vehicles For Carrying Construction Materials',
#    'Others Vehicles',
#    'Total Motor Vehicles',
#    '% of total motor vehicles to the statetotal'],
#   ['1',
#    '2',
#    '997',
#    '998',
#    '999',
#    '1000',
#    '1001',
#    '1002',
#    '1003',
#    '1004',
#    '1005']],
#  [['9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020'],
#   ['Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative'],
#   ['',
#    '',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers'],
#   ['',
#    '',
#    'Post Offices',
#    'Telephone Exchanges',
#    'Telephones',
#    'Mobile Phones',
#    'Internet Connections'],
#   ['1', '2', '1018', '1019', '1020', '1021', '1022']],
#  [['9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.'],
#   ['Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative'],
#   ['SI. No',
#    'Distircts',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads'],
#   ['SI. No',
#    'Distircts',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads'],
#   ['SI. No',
#    'Distircts',
#    'Pucca Road',
#    'Water Bound Macadam Road',
#    'Kaccha Road',
#    'Total Road',
#    'Total No. of Habitations',
#    'No. of Habitations access to all weather roads',
#    'of Habitations access to all weather roads'],
#   ['1', '2', '1011', '1012', '1013', '1014', '1015', '1016', '1017']]]

# %%
def contain_table_id(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'(?<!\S)(?:' + '(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})' + r')(?!\S)', flags=re.IGNORECASE)

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) == 0:
        return False
    return True

# %%
def are_all_same_id(lst):
    if not lst:
        return False  # An empty list cannot have all same elements.
    first_element = lst[0]
    if first_element != '' and contain_table_id(first_element):
        return all(element == first_element for element in lst[:-1])
    return False

def are_all_same_name(lst):
    if not lst:
        return False  # An empty list cannot have all same elements.
    first_element = lst[0]
    if first_element != '':
        return all(element == first_element for element in lst[:-1])
    return False

# %%
def check_for_table(item):
    i=0
    new_item = item
    for k in range(len(item)):
        id_list=[]
        if are_all_same_id(item[k]):
            if i<1:
                i = i+1
            elif i==2:
                return item
        elif i==1 and are_all_same_name(item[k]):
            return item
        elif i==1 and not are_all_same_name(item[k]):
            n_lst = item[k-1]
            new_item.insert(0,n_lst)
            i = i+1
            return new_item
        else:
            new_item.remove(item[k])
            return check_for_table(new_item)

# %%
corrected_list=[]
error_list=[]
for inner_list in output_list:
    initial_val = inner_list.copy()
    item = check_for_table(inner_list)
    if item is not None and len(item)>0:
        corrected_list.append(item)
    else:
        error_list.append(initial_val)

# %%
corrected_list
# Out:
# [[['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers'],
#   ['SI.',
#    'Distircts',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles'],
#   ['SI.', 'Distircts', '', '', '', '', ''],
#   ['SI.',
#    'Distircts',
#    'Multiaxled Airculated Vehicles',
#    'Trucks and Lorries',
#    'Four Wheelers',
#    'Three Wheelers',
#    'Total'],
#   ['1', '2', '977', '978', '979', '980', '981']],
#  [['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers'],
#   ['', '', 'Buses', 'Buses', 'Buses', 'Buses', 'Buses', 'Total Buses'],
#   ['',
#    '',
#    'Stage Carriag',
#    'Contract Vehicles',
#    'Private Service Vehicles',
#    'Educational InstitutionVehicles',
#    'Other Buses',
#    'Total Buses'],
#   ['1', '2', '982', '983', '984', '985', '986', '987']],
#  [['9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020',
#    '9.2 31.03.2020'],
#   ['P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative',
#    'P.W.D Road Length on 31.03.2020 In Kms. Cumulative'],
#   ['',
#    '',
#    'National Highway',
#    'State Highway',
#    'Major District Roads',
#    'Major Bridges in Nos.',
#    'Length of Railway Lines'],
#   ['1', '2', '1006', '1007', '1008', '1009', '1010']],
#  [['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers',
#    'Motor Vehicles on 31.03.2020 In CumulativeNumbers'],
#   ['SI. No',
#    'Distircts',
#    'Taxies',
#    'Taxies',
#    'Taxies',
#    'Passengers Vehicles',
#    'Passengers Vehicles',
#    'Two Wheelers',
#    'Two Wheelers',
#    'Two Wheelers',
#    'Two Wheelers'],
#   ['SI. No', 'Distircts', '', '', '', '', '', '', '', '', ''],
#   ['SI. No',
#    'Distircts',
#    'Motor Cabs',
#    'Maxi Cabs',
#    'Other Cabs',
#    'Three Seated Vehicles Auto Rickshaws',
#    'Four to SixSeated Vehiclea',
#    'Scooters',
#    'Mopeds',
#    'Motor Cycles',
#    'Total'],
#   ['1', '2', '988', '989', '990', '991', '992', '993', '994', '995', '996']],
#  [['9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020',
#    '9.1 31.03.2020'],
#   ['Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers',
#    'Motor Vehicles on 31.03.2020 In Cumulative Numbers'],
#   ['',
#    '',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Vehicles For Carrying Construction Materials',
#    'Others Vehicles',
#    'Total Motor Vehicles',
#    '% of total motor vehicles to the statetotal'],
#   ['',
#    '',
#    'Cars',
#    'Jeep',
#    'Omni Bus',
#    'Tractors',
#    'Tillers',
#    'Vehicles For Carrying Construction Materials',
#    'Others Vehicles',
#    'Total Motor Vehicles',
#    '% of total motor vehicles to the statetotal'],
#   ['1',
#    '2',
#    '997',
#    '998',
#    '999',
#    '1000',
#    '1001',
#    '1002',
#    '1003',
#    '1004',
#    '1005']],
#  [['9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020',
#    '9.4 31.03.2020'],
#   ['Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31.03.2020 Cumulative'],
#   ['',
#    '',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers'],
#   ['',
#    '',
#    'Post Offices',
#    'Telephone Exchanges',
#    'Telephones',
#    'Mobile Phones',
#    'Internet Connections'],
#   ['1', '2', '1018', '1019', '1020', '1021', '1022']],
#  [['9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.'],
#   ['Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31.03.2020 Cumulative'],
#   ['SI. No',
#    'Distircts',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads'],
#   ['SI. No',
#    'Distircts',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads',
#    'No. of Habitations access to all weather roads'],
#   ['SI. No',
#    'Distircts',
#    'Pucca Road',
#    'Water Bound Macadam Road',
#    'Kaccha Road',
#    'Total Road',
#    'Total No. of Habitations',
#    'No. of Habitations access to all weather roads',
#    'of Habitations access to all weather roads'],
#   ['1', '2', '1011', '1012', '1013', '1014', '1015', '1016', '1017']]]

# %%
error_list
# Out:
# []

# %%
for item in error_list:
    corrected_list.remove(item)

# %%
list_to_add = [[['5.1',
   '5.1',
   '5.1',
   '5.1',
   '5.1',
   '5.1',
   '5.1',
   '5.1',
   '5.1',
   '5.1',
   '5.1'],
  ['5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers',
   '5.1 20 12 Livestock Census 2012 In Numbers'],
  ['',
   '',
   'Cattle',
   'Cattle',
   'Cattle',
   'Cattle',
   'Bufaloes',
   'Sheep',
   'Sheep',
   'Sheep',
   'Sheep'],
  ['',
   '',
   'Indigenous Breed',
   'Exotic Breed',
   'Cross Breed',
   'Total',
   'Bufaloes',
   'Indigenous Breed',
   'Exotic Breed',
   'Cross Breed',
   'Total'],
  ['1', '2', '790', '791', '792', '793', '794', '795', '796', '797', '798']],
 [['5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012'],
   ['5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012',
   '5.1 Livestock Census 2012'],
  ['',
   '',
   'Rabbits',
   'Dogs',
   'Others',
   'Total Livestock',
   'Total Poultry',
   '% of Total Livestock to state total'],
  ['1', '2', '804', '805', '806', '807', '808', '809']]]

# %%
corrected_list.extend(list_to_add)

# %%
len(output_list)
# Out:
# 7

# %%
len(corrected_list)
# Out:
# 7

# %%
len(error_list)
# Out:
# 0

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].end()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def remove_after_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].end()
        input_string = input_string[:second_occurrence_index]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['ells', '2009 2019', '1961 201', '-2011', '0-6 2011', '0-6 2001', '0-6 2001 2011', '2001 and 2011', '20 01', '2011 2021', '31.03', '.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2020', '31.3.202', '31.3.2020', '31.3.2020.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')

    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = {"on" : "on 31-03-2020", "statetotal" : "state total", "No. of" : "No.of", "of Habitations access" : "% of Habitations access"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(corrected_list)
corrected_list
# Out:
# [[['9.1', '9.1', '9.1', '9.1', '9.1', '9.1', '9.1'],
#   ['Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers'],
#   ['Si.',
#    'Distircts',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles',
#    'Goods Vehicles'],
#   ['Si.', 'Distircts', '', '', '', '', ''],
#   ['Si.',
#    'Distircts',
#    'Multiaxled Airculated Vehicles',
#    'Trucks and Lorries',
#    'Four Wheelers',
#    'Wheelers',
#    'Total'],
#   ['1', '2', '977', '978', '979', '980', '981']],
#  [['9.1', '9.1', '9.1', '9.1', '9.1', '9.1', '9.1', '9.1'],
#   ['Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers'],
#   ['', '', 'Buses', 'Buses', 'Buses', 'Buses', 'Buses', 'Total Buses'],
#   ['',
#    '',
#    'Stage Carriag',
#    'Contract Vehicles',
#    'Private Service Vehicles',
#    'Educational Institution Vehicles',
#    'Other Buses',
#    'Total Buses'],
#   ['1', '2', '982', '983', '984', '985', '986', '987']],
#  [['9.2', '9.2', '9.2', '9.2', '9.2', '9.2', '9.2'],
#   ['P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative'],
#   ['',
#    '',
#    'National Highway',
#    'State Highway',
#    'Major District Roads',
#    'Major Bridges in Nos.',
#    'Length of Railway Lines'],
#   ['1', '2', '1006', '1007', '1008', '1009', '1010']],
#  [['9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1'],
#   ['Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers'],
#   ['Si. No',
#    'Distircts',
#    'Taxies',
#    'Taxies',
#    'Taxies',
#    'Passengers Vehicles',
#    'Passengers Vehicles',
#    'Two Wheelers',
#    'Two Wheelers',
#    'Two Wheelers',
#    'Two Wheelers'],
#   ['Si. No', 'Distircts', '', '', '', '', '', '', '', '', ''],
#   ['Si. No',
#    'Distircts',
#    'Motor Cabs',
#    'Maxi Cabs',
#    'Other Cabs',
#    'Seated Vehicles Auto Rickshaws',
#    'Four to Six Seated Vehiclea',
#    'Scooters',
#    'Mopeds',
#    'Motor Cycles',
#    'Total'],
#   ['1', '2', '988', '989', '990', '991', '992', '993', '994', '995', '996']],
#  [['9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1',
#    '9.1'],
#   ['Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers'],
#   ['',
#    '',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Motor Vehicles',
#    'Vehicles For Carrying Construction Materials',
#    'Others Vehicles',
#    'Total Motor Vehicles',
#    '% of total motor vehicles to the state total'],
#   ['',
#    '',
#    'Cars',
#    'Jeep',
#    'Omni Bus',
#    'Tractors',
#    'Tillers',
#    'Vehicles For Carrying Construction Materials',
#    'Others Vehicles',
#    'Total Motor Vehicles',
#    '% of total motor vehicles to the state total'],
#   ['1',
#    '2',
#    '997',
#    '998',
#    '999',
#    '1000',
#    '1001',
#    '1002',
#    '1003',
#    '1004',
#    '1005']],
#  [['9.4', '9.4', '9.4', '9.4', '9.4', '9.4', '9.4'],
#   ['Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative'],
#   ['',
#    '',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers',
#    'Communications in Numbers'],
#   ['',
#    '',
#    'Post Offices',
#    'Telephone Exchanges',
#    'Telephones',
#    'Mobile Phones',
#    'Internet Connections'],
#   ['1', '2', '1018', '1019', '1020', '1021', '1022']],
#  [['9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.',
#    '9.3 31.'],
#   ['Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative'],
#   ['Si. No',
#    'Distircts',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'Length of Rural Roads In Kms.',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads'],
#   ['Si. No',
#    'Distircts',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'Panchayat Roads',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads'],
#   ['Si. No',
#    'Distircts',
#    'Pucca Road',
#    'Water Bound Macadam Road',
#    'Kaccha Road',
#    'Total Road',
#    'Total No.of Habitations',
#    'No.of Habitations access to all weather roads',
#    '% of Habitations access to all weather roads'],
#   ['1', '2', '1011', '1012', '1013', '1014', '1015', '1016', '1017']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in corrected_list]
transp_list
# Out:
# [[['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Si.',
#    'Si.',
#    'Si.',
#    '1'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Distircts',
#    'Distircts',
#    'Distircts',
#    '2'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Goods Vehicles',
#    '',
#    'Multiaxled Airculated Vehicles',
#    '977'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Goods Vehicles',
#    '',
#    'Trucks and Lorries',
#    '978'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Goods Vehicles',
#    '',
#    'Four Wheelers',
#    '979'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Goods Vehicles',
#    '',
#    'Wheelers',
#    '980'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Goods Vehicles',
#    '',
#    'Total',
#    '981']],
#  [['9.1', 'Motor Vehicles on 31-03-2020 In Cumulative Numbers', '', '', '1'],
#   ['9.1', 'Motor Vehicles on 31-03-2020 In Cumulative Numbers', '', '', '2'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Buses',
#    'Stage Carriag',
#    '982'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Buses',
#    'Contract Vehicles',
#    '983'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Buses',
#    'Private Service Vehicles',
#    '984'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Buses',
#    'Educational Institution Vehicles',
#    '985'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Buses',
#    'Other Buses',
#    '986'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Total Buses',
#    'Total Buses',
#    '987']],
#  [['9.2', 'P.w.d Road Length on 31-03-2020 In Kms. Cumulative', '', '1'],
#   ['9.2', 'P.w.d Road Length on 31-03-2020 In Kms. Cumulative', '', '2'],
#   ['9.2',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'National Highway',
#    '1006'],
#   ['9.2',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'State Highway',
#    '1007'],
#   ['9.2',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'Major District Roads',
#    '1008'],
#   ['9.2',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'Major Bridges in Nos.',
#    '1009'],
#   ['9.2',
#    'P.w.d Road Length on 31-03-2020 In Kms. Cumulative',
#    'Length of Railway Lines',
#    '1010']],
#  [['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Si. No',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Distircts',
#    'Distircts',
#    'Distircts',
#    '2'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Taxies',
#    '',
#    'Motor Cabs',
#    '988'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Taxies',
#    '',
#    'Maxi Cabs',
#    '989'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Taxies',
#    '',
#    'Other Cabs',
#    '990'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Passengers Vehicles',
#    '',
#    'Seated Vehicles Auto Rickshaws',
#    '991'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Passengers Vehicles',
#    '',
#    'Four to Six Seated Vehiclea',
#    '992'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Two Wheelers',
#    '',
#    'Scooters',
#    '993'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Two Wheelers',
#    '',
#    'Mopeds',
#    '994'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Two Wheelers',
#    '',
#    'Motor Cycles',
#    '995'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Two Wheelers',
#    '',
#    'Total',
#    '996']],
#  [['9.1', 'Motor Vehicles on 31-03-2020 In Cumulative Numbers', '', '', '1'],
#   ['9.1', 'Motor Vehicles on 31-03-2020 In Cumulative Numbers', '', '', '2'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles',
#    'Cars',
#    '997'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles',
#    'Jeep',
#    '998'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles',
#    'Omni Bus',
#    '999'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles',
#    'Tractors',
#    '1000'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Motor Vehicles',
#    'Tillers',
#    '1001'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Vehicles For Carrying Construction Materials',
#    'Vehicles For Carrying Construction Materials',
#    '1002'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Others Vehicles',
#    'Others Vehicles',
#    '1003'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    'Total Motor Vehicles',
#    'Total Motor Vehicles',
#    '1004'],
#   ['9.1',
#    'Motor Vehicles on 31-03-2020 In Cumulative Numbers',
#    '% of total motor vehicles to the state total',
#    '% of total motor vehicles to the state total',
#    '1005']],
#  [['9.4',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    '',
#    '',
#    '1'],
#   ['9.4',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    '',
#    '',
#    '2'],
#   ['9.4',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Communications in Numbers',
#    'Post Offices',
#    '1018'],
#   ['9.4',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Communications in Numbers',
#    'Telephone Exchanges',
#    '1019'],
#   ['9.4',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Communications in Numbers',
#    'Telephones',
#    '1020'],
#   ['9.4',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Communications in Numbers',
#    'Mobile Phones',
#    '1021'],
#   ['9.4',
#    'Post Offices Telephone Exchanges and Telephones on 31-03-2020 Cumulative',
#    'Communications in Numbers',
#    'Internet Connections',
#    '1022']],
#  [['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Si. No',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Distircts',
#    'Distircts',
#    'Distircts',
#    '2'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads In Kms.',
#    'Panchayat Roads',
#    'Pucca Road',
#    '1011'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads In Kms.',
#    'Panchayat Roads',
#    'Water Bound Macadam Road',
#    '1012'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads In Kms.',
#    'Panchayat Roads',
#    'Kaccha Road',
#    '1013'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'Length of Rural Roads In Kms.',
#    'Panchayat Roads',
#    'Total Road',
#    '1014'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads',
#    'Total No.of Habitations',
#    '1015'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads',
#    '1016'],
#   ['9.3 31.',
#    'Length of Rural Roads and Number of Habitations having access to All Weather Roads on 31-03-2020 Cumulative',
#    'No.of Habitations access to all weather roads',
#    'No.of Habitations access to all weather roads',
#    '% of Habitations access to all weather roads',
#    '1017']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            print(string)
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 9
chapter_name = "Transport and Communication"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id = remove_after_all_occurrence(inner_list[0][0])
        table_name = remove_before_all_occurrence(inner_list[0][1])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list)-1:
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Output_html_Chapter9/Chapter9_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Dictionary/Chapter9_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)
