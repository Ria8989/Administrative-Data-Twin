# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
path = "/home/riya/Downloads/ADT_2019-20/Output_html_Chapter6/kaggle/working/out/output/"

# %%
os.chdir(path)

# %%
os.listdir()
# Out:
# ['output_page_10.html',
#  'output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_11.html',
#  'output_page_8.html',
#  'output_page_3.html',
#  'output_page_4.html',
#  'output_page_9.html',
#  'output_page_12.html',
#  'output_page_7.html',
#  'output_page_6.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us', 'mm'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = f"{path}{file}"
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            if table_tag is not None:
                replace_td_content(table_tag)

                process_table_cells(table_tag)

                extractor1 = Extractor(table_tag)
                extractor1.parse()
                output_list.append(extractor1.return_list())
            else:
                print(file_path)

# %%
output_list
# Out:
# [[['6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20'],
#   ['Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees'],
#   ['',
#    '',
#    'No.',
#    'Employees Total FemaleMale',
#    'Employees Total FemaleMale',
#    'Employees Total FemaleMale'],
#   ['1', '2', '906', '907', '908', '909']],
#  [['INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES',
#    'INDUSTRIES'],
#   ['6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020'],
#   ['Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative'],
#   ['SI.No',
#    'Distircts',
#    'Read ymade Garments',
#    'Read ymade Garments',
#    'Read ymade Garments',
#    'Textiles',
#    'Textiles',
#    'Textiles',
#    'Chemical',
#    'Chemical',
#    'Chemical'],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees',
#    'ctories',
#    'Employees',
#    'Employees'],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'ctories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'ctories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    '',
#    '',
#    'ctories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'ctories',
#    'Male',
#    'Female'],
#   ['1', '2', '834', '835', '836', '837', '838', '839', '840', '841', '842']],
#  [['6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020'],
#   ['Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative'],
#   ['',
#    '',
#    'Engineering',
#    'Engineering',
#    'Engineering',
#    'Others',
#    'Others',
#    'Others',
#    'Total',
#    'Total',
#    'Total'],
#   ['',
#    '',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees'],
#   ['',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    'Employees',
#    'Employees'],
#   ['', '', 'Factories', '', '', 'Factories', '', '', 'Factories', '', ''],
#   ['',
#    '',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    '',
#    ''],
#   ['',
#    '',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female'],
#   ['1', '2', '843', '844', '845', '846', '847', '848', '849', '850', '851']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Chemicals',
#    'Chemicals',
#    'Chemicals',
#    'Chemicals',
#    'Food Intoxicants',
#    'Food Intoxicants',
#    'Food Intoxicants',
#    'Food Intoxicants'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '864', '865', '866', '867', '868', '869', '870', '871']],
#  [['6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises'],
#   ['20', '20', '20', '20', '20', '20'],
#   ['No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20'],
#   ['',
#    '',
#    'No. of Working Factories and Cane Crushed',
#    'No. of Working Factories and Cane Crushed',
#    'No. of Working Factories and Cane Crushed',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
#   ['',
#    '',
#    'Working Factories Nos',
#    'Cane rushed In MTs',
#    'Sugar Produced In MTs',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
#   ['1', '2', '910', '911', '912', '913']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Wood',
#    'Wood',
#    'Wood',
#    'Wood',
#    'Others',
#    'Others',
#    'Others',
#    'Others'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '888', '889', '890', '891', '892', '893', '894', '895']],
#  [['6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20'],
#   ['Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees'],
#   ['', '', 'Factories', 'Employees', 'Employees', 'Employees'],
#   ['', '', 'Factories', '', '', ''],
#   ['', '', 'Factories', 'Male', 'Female', 'Total'],
#   ['1', '2', '852', '853', '854', '855']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Automobiles',
#    'Automobiles',
#    'Automobiles',
#    'Automobiles',
#    'Electricals Electronics',
#    'Electricals Electronics',
#    'Electricals Electronics',
#    'Electricals Electronics'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '856', '857', '858', '859', '860', '861', '862', '863']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Total',
#    'Total',
#    'Total',
#    'Total',
#    'Total',
#    'Total'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    '% of Industries to state total',
#    'Employees',
#    'Employees',
#    'Employees',
#    '% of Employment to State total'],
#   ['',
#    '',
#    'No.',
#    'Male',
#    'Female',
#    'Total',
#    'No.',
#    '% of Industries to state total',
#    'Male',
#    'Female',
#    'Total',
#    '% of Employment to State total'],
#   ['1',
#    '2',
#    '896',
#    '897',
#    '898',
#    '899',
#    '900',
#    '901',
#    '902',
#    '903',
#    '904',
#    '905']],
#  [['6.4 31.03.2020',
#    '6.4 31.03.2020',
#    '6.4 31.03.2020',
#    '6.4 31.03.2020',
#    '6.4 31.03.2020'],
#   ['Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020'],
#   ['SI. No', 'Distircts', 'Factories', 'Factories', 'Factories'],
#   ['SI. No', 'Distircts', 'Estates', 'Sheds', 'Plots'],
#   ['1', '2', '914', '915', '916']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Textiles',
#    'Textiles',
#    'Textiles',
#    'Textiles'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '880', '881', '882', '883', '884', '885', '886', '887']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Leather',
#    'Leather',
#    'Leather',
#    'Leather',
#    'Paper and Printing',
#    'Paper and Printing',
#    'Paper and Printing',
#    'Paper and Printing'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '872', '873', '874', '875', '876', '877', '878', '879']]]

# %%
def contain_table_id(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'(?<!\S)(?:' + '(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})' + r')(?!\S)', flags=re.IGNORECASE)

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) == 0:
        return False
    return True

# %%
def are_all_same_id(lst):
    if not lst:
        return False  # An empty list cannot have all same elements.
    first_element = lst[0]
    if first_element != '' and contain_table_id(first_element):
        return all(element == first_element for element in lst[:-1])
    return False

def are_all_same_name(lst):
    if not lst:
        return False  # An empty list cannot have all same elements.
    first_element = lst[0]
    if first_element != '':
        return all(element == first_element for element in lst[:-1])
    return False

# %%
def check_for_table(item):
    i=0
    new_item = item
    for k in range(len(item)):
        id_list=[]
        if are_all_same_id(item[k]):
            if i<1:
                i = i+1
            elif i==2:
                return item
        elif i==1 and are_all_same_name(item[k]):
            return item
        elif i==1 and not are_all_same_name(item[k]):
            n_lst = item[k-1]
            new_item.insert(0,n_lst)
            i = i+1
            return new_item
        else:
            new_item.remove(item[k])
            return check_for_table(new_item)

# %%
corrected_list=[]
error_list=[]
for inner_list in output_list:
    initial_val = inner_list.copy()
    item = check_for_table(inner_list)
    if item is not None and len(item)>0:
        corrected_list.append(item)
    else:
        error_list.append(initial_val)

# %%
corrected_list
# Out:
# [[['6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20'],
#   ['Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees'],
#   ['',
#    '',
#    'No.',
#    'Employees Total FemaleMale',
#    'Employees Total FemaleMale',
#    'Employees Total FemaleMale'],
#   ['1', '2', '906', '907', '908', '909']],
#  [['6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020'],
#   ['Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative',
#    'Number of Factories and Employees on 31.03.2020 Cumulative'],
#   ['SI.No',
#    'Distircts',
#    'Read ymade Garments',
#    'Read ymade Garments',
#    'Read ymade Garments',
#    'Textiles',
#    'Textiles',
#    'Textiles',
#    'Chemical',
#    'Chemical',
#    'Chemical'],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees',
#    'ctories',
#    'Employees',
#    'Employees'],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'ctories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'ctories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    '',
#    '',
#    'ctories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'ctories',
#    'Male',
#    'Female'],
#   ['1', '2', '834', '835', '836', '837', '838', '839', '840', '841', '842']],
#  [['6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020',
#    '6.1 31.03.2020'],
#   ['Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative',
#    'Number of Factories Employees on 31.03.2020 Cumulative'],
#   ['',
#    '',
#    'Engineering',
#    'Engineering',
#    'Engineering',
#    'Others',
#    'Others',
#    'Others',
#    'Total',
#    'Total',
#    'Total'],
#   ['',
#    '',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees'],
#   ['',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    'Employees',
#    'Employees'],
#   ['', '', 'Factories', '', '', 'Factories', '', '', 'Factories', '', ''],
#   ['',
#    '',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    '',
#    ''],
#   ['',
#    '',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female'],
#   ['1', '2', '843', '844', '845', '846', '847', '848', '849', '850', '851']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Chemicals',
#    'Chemicals',
#    'Chemicals',
#    'Chemicals',
#    'Food Intoxicants',
#    'Food Intoxicants',
#    'Food Intoxicants',
#    'Food Intoxicants'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '864', '865', '866', '867', '868', '869', '870', '871']],
#  [['6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises'],
#   ['20', '20', '20', '20', '20', '20'],
#   ['No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20'],
#   ['',
#    '',
#    'No. of Working Factories and Cane Crushed',
#    'No. of Working Factories and Cane Crushed',
#    'No. of Working Factories and Cane Crushed',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
#   ['',
#    '',
#    'Working Factories Nos',
#    'Cane rushed In MTs',
#    'Sugar Produced In MTs',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
#   ['1', '2', '910', '911', '912', '913']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Wood',
#    'Wood',
#    'Wood',
#    'Wood',
#    'Others',
#    'Others',
#    'Others',
#    'Others'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '888', '889', '890', '891', '892', '893', '894', '895']],
#  [['6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20'],
#   ['Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees'],
#   ['', '', 'Factories', 'Employees', 'Employees', 'Employees'],
#   ['', '', 'Factories', '', '', ''],
#   ['', '', 'Factories', 'Male', 'Female', 'Total'],
#   ['1', '2', '852', '853', '854', '855']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Automobiles',
#    'Automobiles',
#    'Automobiles',
#    'Automobiles',
#    'Electricals Electronics',
#    'Electricals Electronics',
#    'Electricals Electronics',
#    'Electricals Electronics'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '856', '857', '858', '859', '860', '861', '862', '863']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Total',
#    'Total',
#    'Total',
#    'Total',
#    'Total',
#    'Total'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    '% of Industries to state total',
#    'Employees',
#    'Employees',
#    'Employees',
#    '% of Employment to State total'],
#   ['',
#    '',
#    'No.',
#    'Male',
#    'Female',
#    'Total',
#    'No.',
#    '% of Industries to state total',
#    'Male',
#    'Female',
#    'Total',
#    '% of Employment to State total'],
#   ['1',
#    '2',
#    '896',
#    '897',
#    '898',
#    '899',
#    '900',
#    '901',
#    '902',
#    '903',
#    '904',
#    '905']],
#  [['6.4 31.03.2020',
#    '6.4 31.03.2020',
#    '6.4 31.03.2020',
#    '6.4 31.03.2020',
#    '6.4 31.03.2020'],
#   ['Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020',
#    'Number of Industrial Estates Sheds and Plots on 31.03.2020'],
#   ['SI. No', 'Distircts', 'Factories', 'Factories', 'Factories'],
#   ['SI. No', 'Distircts', 'Estates', 'Sheds', 'Plots'],
#   ['1', '2', '914', '915', '916']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Textiles',
#    'Textiles',
#    'Textiles',
#    'Textiles'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '880', '881', '882', '883', '884', '885', '886', '887']],
#  [['6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020',
#    '6.2 31.03.2020'],
#   ['Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31.03.2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Leather',
#    'Leather',
#    'Leather',
#    'Leather',
#    'Paper and Printing',
#    'Paper and Printing',
#    'Paper and Printing',
#    'Paper and Printing'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '872', '873', '874', '875', '876', '877', '878', '879']]]

# %%
len(corrected_list)
# Out:
# 12

# %%
list_to_remove = [[['6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20'],
  ['Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees'],
  ['',
   '',
   'No.',
   'Employees Total FemaleMale',
   'Employees Total FemaleMale',
   'Employees Total FemaleMale'],
  ['1', '2', '906', '907', '908', '909']],
  [['6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises'],
  ['20', '20', '20', '20', '20', '20'],
  ['No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20'],
  ['',
   '',
   'No. of Working Factories and Cane Crushed',
   'No. of Working Factories and Cane Crushed',
   'No. of Working Factories and Cane Crushed',
   'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
  ['',
   '',
   'Working Factories Nos',
   'Cane rushed In MTs',
   'Sugar Produced In MTs',
   'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
  ['1', '2', '910', '911', '912', '913']]]

# %%
for item in list_to_remove:
    corrected_list.remove(item)

# %%
list_to_add = [[['6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20',
   '6.2 2019-20'],
  ['Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
   'Of the Total New Small Scale Industries started in 2019-20 and their Employees'],
  ['',
   '',
   'No.',
   'Employees',
   'Employees',
   'Employees'],
  ['',
   '',
   'No.',
   'Male',
   'Female',
   'Total'],
  ['1', '2', '906', '907', '908', '909']],
  [['6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises',
   '6.3 Sugar Factories and Enterprises'],
  ['No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20',
   'No. of Working Factories and Cane Crushed 2019-20'],
  ['',
   '',
   'No. of Working Factories and Cane Crushed',
   'No. of Working Factories and Cane Crushed',
   'No. of Working Factories and Cane Crushed',
   'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
  ['',
   '',
   'Working Factories Nos',
   'Cane rushed In MTs',
   'Sugar Produced In MTs',
   'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
  ['1', '2', '910', '911', '912', '913']]]

# %%
corrected_list.extend(list_to_add)

# %%
len(output_list)
# Out:
# 12

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].end()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def remove_after_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].end()
        input_string = input_string[:second_occurrence_index]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['ells', '2009 2019', '1961 201', '-2011', '0-6 2011', '0-6 2001', '0-6 2001 2011', '2001 and 2011', '20 01', '2011 2021', '31.03', '.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2020', '31.3.202', '31.3.2020', '31.3.2020.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')

    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = {"Read ymade" : "Readymade", "ctories" : "Factories", "on" : "on 31-03-2020"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(corrected_list)
corrected_list
# Out:
# [[['6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1'],
#   ['Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Number of Factories and Employees on 31-03-2020 Cumulative'],
#   ['SI.No',
#    'Distircts',
#    'Readymade Garments',
#    'Readymade Garments',
#    'Readymade Garments',
#    'Textiles',
#    'Textiles',
#    'Textiles',
#    'Chemical',
#    'Chemical',
#    'Chemical'],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees'],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    ''],
#   ['SI.No',
#    'Distircts',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female'],
#   ['1', '2', '834', '835', '836', '837', '838', '839', '840', '841', '842']],
#  [['6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1',
#    '6.1'],
#   ['Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Number of Factories Employees on 31-03-2020 Cumulative'],
#   ['',
#    '',
#    'Engineering',
#    'Engineering',
#    'Engineering',
#    'Others',
#    'Others',
#    'Others',
#    'Total',
#    'Total',
#    'Total'],
#   ['',
#    '',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees',
#    'Factories',
#    'Employees',
#    'Employees'],
#   ['',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    '',
#    '',
#    'Factories',
#    'Employees',
#    'Employees'],
#   ['', '', 'Factories', '', '', 'Factories', '', '', 'Factories', '', ''],
#   ['',
#    '',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    '',
#    ''],
#   ['',
#    '',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female',
#    'Factories',
#    'Male',
#    'Female'],
#   ['1', '2', '843', '844', '845', '846', '847', '848', '849', '850', '851']],
#  [['6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2'],
#   ['Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Chemicals',
#    'Chemicals',
#    'Chemicals',
#    'Chemicals',
#    'Food Intoxicants',
#    'Food Intoxicants',
#    'Food Intoxicants',
#    'Food Intoxicants'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '864', '865', '866', '867', '868', '869', '870', '871']],
#  [['6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2'],
#   ['Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Wood',
#    'Wood',
#    'Wood',
#    'Wood',
#    'Others',
#    'Others',
#    'Others',
#    'Others'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '888', '889', '890', '891', '892', '893', '894', '895']],
#  [['6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20',
#    '6.1 2019-20'],
#   ['Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Of the total New Factories started in 2019-20 and their Employees'],
#   ['', '', 'Factories', 'Employees', 'Employees', 'Employees'],
#   ['', '', 'Factories', '', '', ''],
#   ['', '', 'Factories', 'Male', 'Female', 'Total'],
#   ['1', '2', '852', '853', '854', '855']],
#  [['6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2'],
#   ['Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Automobiles',
#    'Automobiles',
#    'Automobiles',
#    'Automobiles',
#    'Electricals Electronics',
#    'Electricals Electronics',
#    'Electricals Electronics',
#    'Electricals Electronics'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '856', '857', '858', '859', '860', '861', '862', '863']],
#  [['6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2',
#    '6.2'],
#   ['Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Other Service Activities',
#    'Total',
#    'Total',
#    'Total',
#    'Total',
#    'Total',
#    'Total'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    '% of Industries to state total',
#    'Employees',
#    'Employees',
#    'Employees',
#    '% of Employment to State total'],
#   ['',
#    '',
#    'No.',
#    'Male',
#    'Female',
#    'Total',
#    'No.',
#    '% of Industries to state total',
#    'Male',
#    'Female',
#    'Total',
#    '% of Employment to State total'],
#   ['1',
#    '2',
#    '896',
#    '897',
#    '898',
#    '899',
#    '900',
#    '901',
#    '902',
#    '903',
#    '904',
#    '905']],
#  [['6.4', '6.4', '6.4', '6.4', '6.4'],
#   ['Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020'],
#   ['Si. No', 'Distircts', 'Factories', 'Factories', 'Factories'],
#   ['Si. No', 'Distircts', 'Estates', 'Sheds', 'Plots'],
#   ['1', '2', '914', '915', '916']],
#  [['6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2'],
#   ['Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Rubber and plastic',
#    'Textiles',
#    'Textiles',
#    'Textiles',
#    'Textiles'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '880', '881', '882', '883', '884', '885', '886', '887']],
#  [['6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2', '6.2'],
#   ['Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers'],
#   ['',
#    '',
#    'Leather',
#    'Leather',
#    'Leather',
#    'Leather',
#    'Paper and Printing',
#    'Paper and Printing',
#    'Paper and Printing',
#    'Paper and Printing'],
#   ['',
#    '',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees',
#    'No.',
#    'Employees',
#    'Employees',
#    'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '872', '873', '874', '875', '876', '877', '878', '879']],
#  [['6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20',
#    '6.2 2019-20'],
#   ['Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees'],
#   ['', '', 'No.', 'Employees', 'Employees', 'Employees'],
#   ['', '', 'No.', 'Male', 'Female', 'Total'],
#   ['1', '2', '906', '907', '908', '909']],
#  [['6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises',
#    '6.3 Sugar Factories and Enterprises'],
#   ['No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed 2019-20'],
#   ['',
#    '',
#    'No. of Working Factories and Cane Crushed',
#    'No. of Working Factories and Cane Crushed',
#    'No. of Working Factories and Cane Crushed',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
#   ['',
#    '',
#    'Working Factories Nos',
#    'Cane rushed In MTs',
#    'Sugar Produced In MTs',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census'],
#   ['1', '2', '910', '911', '912', '913']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in corrected_list]
transp_list
# Out:
# [[['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    'SI.No',
#    '1'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Distircts',
#    'Distircts',
#    'Distircts',
#    'Distircts',
#    'Distircts',
#    'Distircts',
#    '2'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Readymade Garments',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    '834'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Readymade Garments',
#    'Employees',
#    '',
#    '',
#    'Male',
#    'Male',
#    '835'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Readymade Garments',
#    'Employees',
#    '',
#    '',
#    'Female',
#    'Female',
#    '836'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Textiles',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    '837'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Textiles',
#    'Employees',
#    '',
#    '',
#    '',
#    'Male',
#    '838'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Textiles',
#    'Employees',
#    '',
#    '',
#    '',
#    'Female',
#    '839'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Chemical',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    '840'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Chemical',
#    'Employees',
#    '',
#    '',
#    '',
#    'Male',
#    '841'],
#   ['6.1',
#    'Number of Factories and Employees on 31-03-2020 Cumulative',
#    'Chemical',
#    'Employees',
#    '',
#    '',
#    '',
#    'Female',
#    '842']],
#  [['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Engineering',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    '843'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Engineering',
#    'Employees',
#    '',
#    '',
#    'Male',
#    'Male',
#    '844'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Engineering',
#    'Employees',
#    '',
#    '',
#    'Female',
#    'Female',
#    '845'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Others',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    '846'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Others',
#    'Employees',
#    '',
#    '',
#    'Male',
#    'Male',
#    '847'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Others',
#    'Employees',
#    '',
#    '',
#    'Female',
#    'Female',
#    '848'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Total',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    'Factories',
#    '849'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Total',
#    'Employees',
#    'Employees',
#    '',
#    '',
#    'Male',
#    '850'],
#   ['6.1',
#    'Number of Factories Employees on 31-03-2020 Cumulative',
#    'Total',
#    'Employees',
#    'Employees',
#    '',
#    '',
#    'Female',
#    '851']],
#  [['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Chemicals',
#    'No.',
#    'No.',
#    '864'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Chemicals',
#    'Employees',
#    'Male',
#    '865'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Chemicals',
#    'Employees',
#    'Female',
#    '866'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Chemicals',
#    'Employees',
#    'Total',
#    '867'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Food Intoxicants',
#    'No.',
#    'No.',
#    '868'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Food Intoxicants',
#    'Employees',
#    'Male',
#    '869'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Food Intoxicants',
#    'Employees',
#    'Female',
#    '870'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Food Intoxicants',
#    'Employees',
#    'Total',
#    '871']],
#  [['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Wood',
#    'No.',
#    'No.',
#    '888'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Wood',
#    'Employees',
#    'Male',
#    '889'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Wood',
#    'Employees',
#    'Female',
#    '890'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Wood',
#    'Employees',
#    'Total',
#    '891'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Others',
#    'No.',
#    'No.',
#    '892'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Others',
#    'Employees',
#    'Male',
#    '893'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Others',
#    'Employees',
#    'Female',
#    '894'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Others',
#    'Employees',
#    'Total',
#    '895']],
#  [['6.1 2019-20',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.1 2019-20',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.1 2019-20',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Factories',
#    'Factories',
#    'Factories',
#    '852'],
#   ['6.1 2019-20',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Employees',
#    '',
#    'Male',
#    '853'],
#   ['6.1 2019-20',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Employees',
#    '',
#    'Female',
#    '854'],
#   ['6.1 2019-20',
#    'Of the total New Factories started in 2019-20 and their Employees',
#    'Employees',
#    '',
#    'Total',
#    '855']],
#  [['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Automobiles',
#    'No.',
#    'No.',
#    '856'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Automobiles',
#    'Employees',
#    'Male',
#    '857'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Automobiles',
#    'Employees',
#    'Female',
#    '858'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Automobiles',
#    'Employees',
#    'Total',
#    '859'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Electricals Electronics',
#    'No.',
#    'No.',
#    '860'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Electricals Electronics',
#    'Employees',
#    'Male',
#    '861'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Electricals Electronics',
#    'Employees',
#    'Female',
#    '862'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Electricals Electronics',
#    'Employees',
#    'Total',
#    '863']],
#  [['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Other Service Activities',
#    'No.',
#    'No.',
#    '896'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Other Service Activities',
#    'Employees',
#    'Male',
#    '897'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Other Service Activities',
#    'Employees',
#    'Female',
#    '898'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Other Service Activities',
#    'Employees',
#    'Total',
#    '899'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Total',
#    'No.',
#    'No.',
#    '900'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Total',
#    '% of Industries to state total',
#    '% of Industries to state total',
#    '901'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Total',
#    'Employees',
#    'Male',
#    '902'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Total',
#    'Employees',
#    'Female',
#    '903'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Total',
#    'Employees',
#    'Total',
#    '904'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Total',
#    '% of Employment to State total',
#    '% of Employment to State total',
#    '905']],
#  [['6.4',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Si. No',
#    'Si. No',
#    '1'],
#   ['6.4',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Distircts',
#    'Distircts',
#    '2'],
#   ['6.4',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Factories',
#    'Estates',
#    '914'],
#   ['6.4',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Factories',
#    'Sheds',
#    '915'],
#   ['6.4',
#    'Number of Industrial Estates Sheds and Plots on 31-03-2020',
#    'Factories',
#    'Plots',
#    '916']],
#  [['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Rubber and plastic',
#    'No.',
#    'No.',
#    '880'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Rubber and plastic',
#    'Employees',
#    'Male',
#    '881'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Rubber and plastic',
#    'Employees',
#    'Female',
#    '882'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Rubber and plastic',
#    'Employees',
#    'Total',
#    '883'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Textiles',
#    'No.',
#    'No.',
#    '884'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Textiles',
#    'Employees',
#    'Male',
#    '885'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Textiles',
#    'Employees',
#    'Female',
#    '886'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Textiles',
#    'Employees',
#    'Total',
#    '887']],
#  [['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '1'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    '',
#    '',
#    '',
#    '2'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Leather',
#    'No.',
#    'No.',
#    '872'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Leather',
#    'Employees',
#    'Male',
#    '873'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Leather',
#    'Employees',
#    'Female',
#    '874'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Leather',
#    'Employees',
#    'Total',
#    '875'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Paper and Printing',
#    'No.',
#    'No.',
#    '876'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Paper and Printing',
#    'Employees',
#    'Male',
#    '877'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Paper and Printing',
#    'Employees',
#    'Female',
#    '878'],
#   ['6.2',
#    'Small Scale Units Registered in District Industrial Centre on 31-03-2020 Cumulative In Numbers',
#    'Paper and Printing',
#    'Employees',
#    'Total',
#    '879']],
#  [['6.2 2019-20',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    '',
#    '',
#    '1'],
#   ['6.2 2019-20',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    '',
#    '',
#    '2'],
#   ['6.2 2019-20',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'No.',
#    'No.',
#    '906'],
#   ['6.2 2019-20',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Employees',
#    'Male',
#    '907'],
#   ['6.2 2019-20',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Employees',
#    'Female',
#    '908'],
#   ['6.2 2019-20',
#    'Of the Total New Small Scale Industries started in 2019-20 and their Employees',
#    'Employees',
#    'Total',
#    '909']],
#  [['6.3 Sugar Factories and Enterprises',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    '',
#    '',
#    '1'],
#   ['6.3 Sugar Factories and Enterprises',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    '',
#    '',
#    '2'],
#   ['6.3 Sugar Factories and Enterprises',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed',
#    'Working Factories Nos',
#    '910'],
#   ['6.3 Sugar Factories and Enterprises',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed',
#    'Cane rushed In MTs',
#    '911'],
#   ['6.3 Sugar Factories and Enterprises',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No. of Working Factories and Cane Crushed',
#    'Sugar Produced In MTs',
#    '912'],
#   ['6.3 Sugar Factories and Enterprises',
#    'No. of Working Factories and Cane Crushed 2019-20',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census',
#    'No of Enterprises engaged in Trade Hotels and Transport activities per 2015 Economic Census',
#    '913']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            print(string)
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 6
chapter_name = "Industries"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id = remove_after_all_occurrence(inner_list[0][0])
        table_name = remove_before_all_occurrence(inner_list[0][1])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list)-1:
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Output_html_Chapter6/Chapter6_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT_2019-20/Dictionary/Chapter6_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)

# %%
import re

def contain_tttable_id(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    #pattern = re.compile(r'(?<!\d)(\b\d\.\d|\b\d{2}\.\d|\b\d\.\d{2}|\b\d{2}\.\d{2})(?!\d)')
    #pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')
    pattern = re.compile(r'(?<!\S)(?:' + '(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})' + r')(?!\S)', flags=re.IGNORECASE)

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) == 0:
        return False
    return True

# Test the function
print(contain_tttable_id('Samll 31.03.2020 Cumulative In Numbers'))  # Output: False
# Out:
# False
