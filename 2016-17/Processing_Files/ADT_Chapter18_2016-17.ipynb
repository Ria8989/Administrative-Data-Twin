# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
path = "/home/riya/Downloads/ADT/Output_html_Chapter18/kaggle/working/output/"

# %%
os.chdir(path)

# %%
os.listdir()
# Out:
# ['output_page_18.html',
#  'output_page_15.html',
#  'output_page_10.html',
#  'output_page_16.html',
#  'output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_11.html',
#  'output_page_8.html',
#  'output_page_21.html',
#  'output_page_19.html',
#  'output_page_3.html',
#  'output_page_13.html',
#  'output_page_20.html',
#  'output_page_4.html',
#  'output_page_22.html',
#  'output_page_23.html',
#  'output_page_14.html',
#  'output_page_9.html',
#  'output_page_12.html',
#  'output_page_17.html',
#  'output_page_7.html',
#  'output_page_6.html',
#  'output_page_24.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = f"{path}{file}"
  
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            replace_td_content(table_tag)

            process_table_cells(table_tag)
            
            extractor1 = Extractor(table_tag)
            extractor1.parse()
            output_list.append(extractor1.return_list())

# %%
output_list
# Out:
# [[['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST',
#    'qLa rge Agrl. Land Holder Morethan10 Ha. ST'],
#   ['Sl.No',
#    'District',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1118', '1119', '1120', '1121', '1122', '1123', '1124', '1125']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others',
#    'dium Agril. Land Holder 4-10 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1094', '1095', '1096', '1097', '1098', '1099', '1100', '1101']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census'],
#   ['',
#    'ffl',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST',
#    'AUSe Medium Agril. Land Holder 2-4 Ha. ST'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1054', '1055', '1056', '1057', '1058', '1059', '1060', '1061']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    'ffl',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total',
#    'MlM edium Agril. Land Holder 4-10 Ha. Total'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'MlTotal',
#    'Male',
#    'Female',
#    'Institutions',
#    'MlTotal'],
#   ['1', '2', '1102', '1103', '1104', '1105', '1106', '1107', '1108', '1109']],
#  [['18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18. w18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census'],
#   ['',
#    'ffl',
#    'MarginalAgril. Land Holder Below 1Ha. SC',
#    'MarginalAgril. Land Holder Below 1Ha. SC',
#    'MarginalAgril. Land Holder Below 1Ha. SC',
#    'MarginalAgril. Land Holder Below 1Ha. SC',
#    'MarginalAgril. Land Holder Below 1Ha. SC',
#    'MarginalAgril. Land Holder Below 1Ha. SC',
#    'MarginalAgril. Land Holder Below 1Ha. SC',
#    'MarginalAgril. Land Holder Below 1Ha. SC'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '982', '983', '984', '985', '986', '987', '988', '989']],
#  [['18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    'arginal Agril. Land Holder Below 1 Ha. ST',
#    ''],
#   ['Sl.No',
#    'District',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1', '2', '990', '991', '992', '993', '994', '995', '996', '997', '']],
#  [['18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census'],
#   ['',
#    'ffl',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC',
#    'Small Agril. Land Holder 2 Ha. SC'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1014', '1015', '1016', '1017', '1018', '1019', '1020', '1021']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11'],
#   ['Sl.No',
#    'District',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others',
#    'EvS gem Medium Agril. Land Holder 2-4 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1062', '1063', '1064', '1065', '1066', '1067', '1068', '1069']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11Census'],
#   ['',
#    'ffl',
#    'SmallAgril. Land Holder 1-2 Ha. Total',
#    'SmallAgril. Land Holder 1-2 Ha. Total',
#    'SmallAgril. Land Holder 1-2 Ha. Total',
#    'SmallAgril. Land Holder 1-2 Ha. Total',
#    'SmallAgril. Land Holder 1-2 Ha. Total',
#    'SmallAgril. Land Holder 1-2 Ha. Total',
#    'SmallAgril. Land Holder 1-2 Ha. Total',
#    'SmallAgril. Land Holder 1-2 Ha. Total'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1038', '1039', '1040', '1041', '1042', '1043', '1044', '1045']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'TotalAgrl. Land Holder Sc',
#    'TotalAgrl. Land Holder Sc',
#    'TotalAgrl. Land Holder Sc',
#    'TotalAgrl. Land Holder Sc',
#    'TotalAgrl. Land Holder Sc',
#    'TotalAgrl. Land Holder Sc',
#    'TotalAgrl. Land Holder Sc',
#    'TotalAgrl. Land Holder Sc',
#    ''],
#   ['Sl.No',
#    'District',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '1142',
#    '1143',
#    '1144',
#    '1145',
#    '1146',
#    '1147',
#    '1148',
#    '1149',
#    '']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['',
#    'ffl',
#    'arge Agrl. Land Holder More than10 Ha.',
#    'arge Agrl. Land Holder More than10 Ha.',
#    'arge Agrl. Land Holder More than10 Ha.',
#    'arge Agrl. Land Holder More than10 Ha.',
#    'arge Agrl. Land Holder More than10 Ha.',
#    'arge Agrl. Land Holder More than10 Ha.',
#    'arge Agrl. Land Holder More than10 Ha.',
#    'arge Agrl. Land Holder More than10 Ha.'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1126', '1127', '1128', '1129', '1130', '1131', '1132', '1133']],
#  [['18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census'],
#   ['',
#    'ffl',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others',
#    'gM arginal Agril. Land Holder Below 1 Ha. Others'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '998', '999', '1000', '1001', '1002', '1003', '1004', '1005']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'edium Agril. Land Holder 4-10 Ha.',
#    'edium Agril. Land Holder 4-10 Ha.',
#    'edium Agril. Land Holder 4-10 Ha.',
#    'edium Agril. Land Holder 4-10 Ha.',
#    'edium Agril. Land Holder 4-10 Ha.',
#    'edium Agril. Land Holder 4-10 Ha.',
#    'edium Agril. Land Holder 4-10 Ha.',
#    'edium Agril. Land Holder 4-10 Ha.'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1078', '1079', '1080', '1081', '1082', '1083', '1084', '1085']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['',
#    'ffl',
#    'Large Agrl. Land Holder More than10 Ha.',
#    'Large Agrl. Land Holder More than10 Ha.',
#    'Large Agrl. Land Holder More than10 Ha.',
#    'Large Agrl. Land Holder More than10 Ha.',
#    'Large Agrl. Land Holder More than10 Ha.',
#    'Large Agrl. Land Holder More than10 Ha.',
#    'Large Agrl. Land Holder More than10 Ha.',
#    'Large Agrl. Land Holder More than10 Ha.'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1134', '1135', '1136', '1137', '1138', '1139', '1140', '1141']],
#  [['18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total',
#    'arginal Agril. Land Holder Below 1 Ha. Total'],
#   ['Sl.No',
#    'District',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1006', '1007', '1008', '1009', '1010', '1011', '1012', '1013']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Tqot alAgrl. Land Holder ST',
#    'Tqot alAgrl. Land Holder ST',
#    'Tqot alAgrl. Land Holder ST',
#    'Tqot alAgrl. Land Holder ST',
#    'Tqot alAgrl. Land Holder ST',
#    'Tqot alAgrl. Land Holder ST',
#    'Tqot alAgrl. Land Holder ST',
#    'Tqot alAgrl. Land Holder ST'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1150', '1151', '1152', '1153', '1154', '1155', '1156', '1157']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Agri.Census'],
#   ['Sl.No.',
#    'Districts',
#    'otal Agrl. Land Holder Others',
#    'otal Agrl. Land Holder Others',
#    'otal Agrl. Land Holder Others',
#    'otal Agrl. Land Holder Others',
#    'otal Agrl. Land Holder Others',
#    'otal Agrl. Land Holder Others',
#    'otal Agrl. Land Holder Others',
#    'otal Agrl. Land Holder Others'],
#   ['Sl.No.',
#    'Districts',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1158', '1159', '1160', '1161', '1162', '1163', '1164', '1165']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    'ffl',
#    'qMe ium Agril. Land Holder 4-10Ha. ST',
#    'qMe ium Agril. Land Holder 4-10Ha. ST',
#    'qMe ium Agril. Land Holder 4-10Ha. ST',
#    'qMe ium Agril. Land Holder 4-10Ha. ST',
#    'qMe ium Agril. Land Holder 4-10Ha. ST',
#    'qMe ium Agril. Land Holder 4-10Ha. ST',
#    'qMe ium Agril. Land Holder 4-10Ha. ST',
#    'qMe ium Agril. Land Holder 4-10Ha. ST'],
#   ['',
#    'ffl',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1086', '1087', '1088', '1089', '1090', '1091', '1092', '1093']],
#  [['18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC',
#    'wSem Medium Agril. Land Holder 2-4 Ha. SC'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1046', '1047', '1048', '1049', '1050', '1051', '1052', '1053']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA 2010-11',
#    ''],
#   ['',
#    'ffl',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    'emi Medium Agril. Land Holder 2-4 Ha. Total',
#    ''],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'MlTotal',
#    'Male',
#    'Female',
#    'Institutions',
#    'MlTotal',
#    'MlTotal'],
#   ['1',
#    '2',
#    '1070',
#    '1071',
#    '1072',
#    '1073',
#    '1074',
#    '1075',
#    '1076',
#    '1077',
#    '1077']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Large Agrl. Land Holder More than10Ha. SC',
#    'Large Agrl. Land Holder More than10Ha. SC',
#    'Large Agrl. Land Holder More than10Ha. SC',
#    'Large Agrl. Land Holder More than10Ha. SC',
#    'Large Agrl. Land Holder More than10Ha. SC',
#    'Large Agrl. Land Holder More than10Ha. SC',
#    'Large Agrl. Land Holder More than10Ha. SC',
#    'Large Agrl. Land Holder More than10Ha. SC'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1110', '1111', '1112', '1113', '1114', '1115', '1116', '1117']],
#  [['18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census'],
#   ['Sl.No',
#    'District',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others',
#    'allAgril. Land Holder 2 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '1030',
#    '1031',
#    '1032',
#    '1033',
#    '1034',
#    '1035',
#    '1036',
#    '1037',
#    '']],
#  [['18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census',
#    '18.1 AGRICULTURALLAND HOLDINGS AND AREA per2010-11Census'],
#   ['Sl. No.',
#    'Districts',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST',
#    'qSm all Agril. Land Holder 2 Ha. ST'],
#   ['Sl. No.',
#    'Districts',
#    'umber',
#    'umber',
#    'umber',
#    'umber',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl. No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1022', '1023', '1024', '1025', '1026', '1027', '1028', '1029']],
#  [['18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census',
#    '18.1 AGRICULTURAL LAND HOLDINGS AND AREA per2010-11 Census'],
#   ['',
#    'ffl',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total'],
#   ['',
#    'ffl',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    'ffl',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1166', '1167', '1168', '1169', '1170', '1171', '1172', '1173']]]

# %%
#list_to_remove = [[['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'aQv fiAi Indian System of Medicine HospitalsIndian System of MedicineDispensaries',
   'aQv fiAi Indian System of Medicine HospitalsIndian System of MedicineDispensaries',
   'aQv fiAi Indian System of Medicine HospitalsIndian System of MedicineDispensaries',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds',
   'Nos',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds'],
  ['1',
   '2',
   '667',
   '668',
   '669',
   '670',
   '670',
   '671',
   '672',
   '673',
   '674',
   '675']]]
# Out:
#   File "/tmp/ipykernel_16719/2863250876.py", line 2
#     '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#     ^
# IndentationError: unexpected indent

# %%
#for list_set in output_list:
    for item in list_to_remove: 
        if(list_set == item):
            output_list.remove(list_set)
# Out:
#   File "/tmp/ipykernel_16719/2081342099.py", line 2
#     for item in list_to_remove:
#     ^
# IndentationError: unexpected indent

# %%
#list_to_add = [[['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of MedicineDispensaries',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds',
   'Nos',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds'],
  ['1',
   '2',
   '667',
   '668',
   '669',
   '670',
   '670.1',
   '671',
   '672',
   '673',
   '674',
   '675']]]

for item in list_to_add:
    output_list.append(item)

# %%
#output_list
# Out:
# [[['11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'lukaHq Hospitals',
#    'lukaHq Hospitals',
#    'ffl District Hospitals',
#    'ffl District Hospitals',
#    'Other Hos pitals under HFW',
#    'Other Hos pitals under HFW',
#    'tP Autonomous Teaching Hospitals',
#    'tP Autonomous Teaching Hospitals',
#    'Others CHCs',
#    'Others CHCs',
#    'Total',
#    'Total'],
#   ['Sl. No.',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'UNos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '648',
#    '649',
#    '650',
#    '651',
#    '652',
#    '653',
#    '654',
#    '655',
#    '656',
#    '657',
#    '658',
#    '659']],
#  [['11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.'],
#   ['',
#    'ffl',
#    'No.Hospitals',
#    'No.Hospitals',
#    'No.Hospitals',
#    'ofD No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Private',
#    'Total',
#    'ofD No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Nursing Home Hospitals',
#    'Total',
#    'ofD No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['1', '2', '660', '661', '662', '663', '664', '665', '666']],
#  [['11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos'],
#   ['',
#    'ffl',
#    'Sterlisation',
#    'Sterlisation',
#    'Family Planning Measures in users',
#    'Family Planning Measures in users',
#    'Family Planning Measures in users'],
#   ['', 'ffl', 'Vasectomy', 'Tubectomy', 'I.U.D user', 'C.C. user', 'O.P user'],
#   ['1', '2', '682', '683', '684', '685', '686']],
#  [['11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.'],
#   ['Sl.No.',
#    'Districts',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme'],
#   ['Sl.No.',
#    'Districts',
#    'No ofIdentified T.B.patient',
#    'No ofIdentified T.B.patient',
#    'No ofIdentified T.B.patient',
#    'Patients Cured',
#    'Patients Cured',
#    'Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred'],
#   ['Sl.No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total'],
#   ['1', '2', '705', '706', '707', '708', '709', '710', '711', '712', '713']],
#  [['11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['Sl.No.',
#    'Districts',
#    'fl. D.P.T.',
#    'Polio',
#    'BCG',
#    'Measles',
#    'T.T',
#    '.Pentavalent includes Hepatities D.P.T'],
#   ['1', '2', '676', '677', '678', '679', '680', '681']],
#  [['11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in'],
#   ['',
#    'ffl',
#    'FRU Units First Referal Units',
#    '108 Ambulance',
#    '108 Ambulance',
#    '24 7 24 hoursand 7days workingHospitals',
#    '24 7 24 hoursand 7days workingHospitals',
#    'No.of enificiariesinJananni Suraksha Yojanas',
#    'No.of benificiaries medical kit',
#    'Maternal Mortalit Death'],
#   ['',
#    'ffl',
#    'FRU Units First Referal Units',
#    'No.of Vehical',
#    'SNo.of sbenefitted patients',
#    'Nos.',
#    'No.of delivariesinthisHospital',
#    'No.of enificiariesinJananni Suraksha Yojanas',
#    'No.of benificiaries medical kit',
#    'Maternal Mortalit Death'],
#   ['1', '2', '714', '715', '716', '717', '718', '719', '720', '721']],
#  [['11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017'],
#   ['',
#    'ffl',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme'],
#   ['',
#    'ffl',
#    'of Identified Leprosy Patients',
#    'of Identified Leprosy Patients',
#    'of Identified Leprosy Patients',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'No. Patients Cured'],
#   ['', 'ffl', 'Afi Male', 'Female', 'Total', 'Afi Male', 'Female', 'Total'],
#   ['1', '2', '699', '700', '701', '702', '703', '704']],
#  [['11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.'],
#   ['Sl. No.',
#    'Districts',
#    '',
#    '',
#    '',
#    '',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme'],
#   ['Sl. No.',
#    'Districts',
#    'of identifiedAidspatients',
#    'of identifiedAidspatients',
#    'of identifiedAidspatients',
#    'of identifiedAidspatients',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred'],
#   ['Sl. No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG'],
#   ['1',
#    '2',
#    '687',
#    '688',
#    '689',
#    '690',
#    '691',
#    '692',
#    '693',
#    '694',
#    '695',
#    '696',
#    '697',
#    '698']],
#  [['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.'],
#   ['Sl.No',
#    'Districts',
#    'Dfl Allopathy Hospitals',
#    'Dfl Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of MedicineDispensaries',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '667',
#    '668',
#    '669',
#    '670',
#    '670.1',
#    '671',
#    '672',
#    '673',
#    '674',
#    '675']]]

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2017', '31.3.201', '31.3.2017', '31.3.2017.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'tP', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')

    
    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = { "qLa rge" : "Large", "Morethan10" : "More than 10", "umber" : "Number", "dium" : "Medium", "AUSe" : "Semi", "edium" : "Medium", "w18.1" : "18.1", "AGRICULTURALLAND" : "AGRICULTURAL LAND", "arginal" : "Marginal", "EvS gem" : "Semi", "arge" : "Large", "than10" : "than 10", "gM arginal" : "Marginal", "Tqot alAgrl." : "Total Agrl.", "otal" : "Total", "qMe ium" : "Medium", "wSem" : "Semi", "emi" : "Semi", "MlTotal" : "Total", "allAgril." : "Small Agril.", "qSm all" : "Small", "than10Ha." : "than 10 Ha.", "2010-11Census" : "2010-11 Census", "4-10Ha." : "4-10 Ha.", "1Ha." : "1 Ha."}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(output_list)
output_list
# Out:
# [[['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Large Agrl. Land Holder More than 10 Ha. St'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1118', '1119', '1120', '1121', '1122', '1123', '1124', '1125']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Medium Agril. Land Holder 4-10 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1094', '1095', '1096', '1097', '1098', '1099', '1100', '1101']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1054', '1055', '1056', '1057', '1058', '1059', '1060', '1061']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    '',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Medium Agril. Land Holder 4-10 Ha. Total'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1102', '1103', '1104', '1105', '1106', '1107', '1108', '1109']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '982', '983', '984', '985', '986', '987', '988', '989']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    ''],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1', '2', '990', '991', '992', '993', '994', '995', '996', '997', '']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Small Agril. Land Holder 2 Ha. Sc'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1014', '1015', '1016', '1017', '1018', '1019', '1020', '1021']],
#  [['18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11'],
#   ['Sl.No',
#    'District',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1062', '1063', '1064', '1065', '1066', '1067', '1068', '1069']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Small Agril. Land Holder 1-2 Ha. Total'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1038', '1039', '1040', '1041', '1042', '1043', '1044', '1045']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    'Total Agrl. Land Holder Sc',
#    ''],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '1142',
#    '1143',
#    '1144',
#    '1145',
#    '1146',
#    '1147',
#    '1148',
#    '1149',
#    '']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1126', '1127', '1128', '1129', '1130', '1131', '1132', '1133']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Marginal Agril. Land Holder Below 1 Ha. Others'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '998', '999', '1000', '1001', '1002', '1003', '1004', '1005']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Medium Agril. Land Holder 4-10 Ha.'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1078', '1079', '1080', '1081', '1082', '1083', '1084', '1085']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Large Agrl. Land Holder More than 10 Ha.'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1134', '1135', '1136', '1137', '1138', '1139', '1140', '1141']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Marginal Agril. Land Holder Below 1 Ha. Total'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1006', '1007', '1008', '1009', '1010', '1011', '1012', '1013']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St',
#    'Total Agrl. Land Holder St'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1150', '1151', '1152', '1153', '1154', '1155', '1156', '1157']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census'],
#   ['Sl.No.',
#    'Districts',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others',
#    'Total Agrl. Land Holder Others'],
#   ['Sl.No.',
#    'Districts',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1158', '1159', '1160', '1161', '1162', '1163', '1164', '1165']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '18.1 Agricultural Land holdings and Area per 2010-11 Census'],
#   ['',
#    '',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Medium Agril. Land Holder 4-10 Ha. St'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1086', '1087', '1088', '1089', '1090', '1091', '1092', '1093']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1046', '1047', '1048', '1049', '1050', '1051', '1052', '1053']],
#  [['18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    '18.1 Agricultural Land Holdings And Area 2010-11',
#    ''],
#   ['',
#    '',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    ''],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Total'],
#   ['1',
#    '2',
#    '1070',
#    '1071',
#    '1072',
#    '1073',
#    '1074',
#    '1075',
#    '1076',
#    '1077',
#    '1077']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Large Agrl. Land Holder More than 10 Ha. Sc'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1110', '1111', '1112', '1113', '1114', '1115', '1116', '1117']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl.No',
#    'District',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Small Agril. Land Holder 2 Ha. Others'],
#   ['Sl.No',
#    'District',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area',
#    ''],
#   ['Sl.No',
#    'District',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    ''],
#   ['1',
#    '2',
#    '1030',
#    '1031',
#    '1032',
#    '1033',
#    '1034',
#    '1035',
#    '1036',
#    '1037',
#    '']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['Sl. No.',
#    'Districts',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Small Agril. Land Holder 2 Ha. St'],
#   ['Sl. No.',
#    'Districts',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['Sl. No.',
#    'Districts',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1022', '1023', '1024', '1025', '1026', '1027', '1028', '1029']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '18.1 Agricultural Land Holdings And Area per 2010-11 Census'],
#   ['',
#    '',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total',
#    'Total Agrl. Land Holder Total'],
#   ['',
#    '',
#    'Number',
#    'Number',
#    'Number',
#    'Number',
#    'Area',
#    'Area',
#    'Area',
#    'Area'],
#   ['',
#    '',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total',
#    'Male',
#    'Female',
#    'Institutions',
#    'Total'],
#   ['1', '2', '1166', '1167', '1168', '1169', '1170', '1171', '1172', '1173']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Male',
#    '1118'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Female',
#    '1119'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Institutions',
#    '1120'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Number',
#    'Total',
#    '1121'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Male',
#    '1122'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Female',
#    '1123'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Institutions',
#    '1124'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. St',
#    'Area',
#    'Total',
#    '1125']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Male',
#    '1094'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Female',
#    '1095'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Institutions',
#    '1096'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Number',
#    'Total',
#    '1097'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Male',
#    '1098'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Female',
#    '1099'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Institutions',
#    '1100'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Others',
#    'Area',
#    'Total',
#    '1101']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Male',
#    '1054'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Female',
#    '1055'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Institutions',
#    '1056'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Number',
#    'Total',
#    '1057'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Male',
#    '1058'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Female',
#    '1059'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Institutions',
#    '1060'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. St',
#    'Area',
#    'Total',
#    '1061']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Male',
#    '1102'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Female',
#    '1103'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Institutions',
#    '1104'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Number',
#    'Total',
#    '1105'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Male',
#    '1106'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Female',
#    '1107'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Institutions',
#    '1108'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. Total',
#    'Area',
#    'Total',
#    '1109']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    'Male',
#    '982'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    'Female',
#    '983'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    'Institutions',
#    '984'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Number',
#    'Total',
#    '985'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    'Male',
#    '986'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    'Female',
#    '987'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    'Institutions',
#    '988'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Sc',
#    'Area',
#    'Total',
#    '989']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Male',
#    '990'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Female',
#    '991'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Institutions',
#    '992'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Number',
#    'Total',
#    '993'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Male',
#    '994'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Female',
#    '995'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Institutions',
#    '996'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. St',
#    'Area',
#    'Total',
#    '997'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Male',
#    '1014'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Female',
#    '1015'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Institutions',
#    '1016'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Number',
#    'Total',
#    '1017'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'Male',
#    '1018'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'Female',
#    '1019'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'Institutions',
#    '1020'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Sc',
#    'Area',
#    'Total',
#    '1021']],
#  [['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Male',
#    '1062'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Female',
#    '1063'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Institutions',
#    '1064'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Number',
#    'Total',
#    '1065'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Male',
#    '1066'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Female',
#    '1067'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Institutions',
#    '1068'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Others',
#    'Area',
#    'Total',
#    '1069']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Male',
#    '1038'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Female',
#    '1039'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Institutions',
#    '1040'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Number',
#    'Total',
#    '1041'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Male',
#    '1042'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Female',
#    '1043'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Institutions',
#    '1044'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 1-2 Ha. Total',
#    'Area',
#    'Total',
#    '1045']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Male',
#    '1142'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Female',
#    '1143'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Institutions',
#    '1144'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Number',
#    'Total',
#    '1145'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Male',
#    '1146'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Female',
#    '1147'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Institutions',
#    '1148'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Sc',
#    'Area',
#    'Total',
#    '1149'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Male',
#    '1126'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Female',
#    '1127'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Institutions',
#    '1128'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Total',
#    '1129'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Male',
#    '1130'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Female',
#    '1131'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Institutions',
#    '1132'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Total',
#    '1133']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Male',
#    '998'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Female',
#    '999'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Institutions',
#    '1000'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Number',
#    'Total',
#    '1001'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Male',
#    '1002'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Female',
#    '1003'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Institutions',
#    '1004'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Others',
#    'Area',
#    'Total',
#    '1005']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Number',
#    'Male',
#    '1078'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Number',
#    'Female',
#    '1079'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Number',
#    'Institutions',
#    '1080'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Number',
#    'Total',
#    '1081'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Area',
#    'Male',
#    '1082'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Area',
#    'Female',
#    '1083'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Area',
#    'Institutions',
#    '1084'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha.',
#    'Area',
#    'Total',
#    '1085']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Male',
#    '1134'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Female',
#    '1135'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Institutions',
#    '1136'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Number',
#    'Total',
#    '1137'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Male',
#    '1138'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Female',
#    '1139'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Institutions',
#    '1140'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha.',
#    'Area',
#    'Total',
#    '1141']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Male',
#    '1006'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Female',
#    '1007'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Institutions',
#    '1008'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Number',
#    'Total',
#    '1009'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Male',
#    '1010'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Female',
#    '1011'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Institutions',
#    '1012'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Marginal Agril. Land Holder Below 1 Ha. Total',
#    'Area',
#    'Total',
#    '1013']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Male',
#    '1150'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Female',
#    '1151'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Institutions',
#    '1152'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Number',
#    'Total',
#    '1153'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Male',
#    '1154'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Female',
#    '1155'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Institutions',
#    '1156'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder St',
#    'Area',
#    'Total',
#    '1157']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Male',
#    '1158'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Female',
#    '1159'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Institutions',
#    '1160'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Number',
#    'Total',
#    '1161'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Male',
#    '1162'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Female',
#    '1163'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Institutions',
#    '1164'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Agri.Census',
#    'Total Agrl. Land Holder Others',
#    'Area',
#    'Total',
#    '1165']],
#  [['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Male',
#    '1086'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Female',
#    '1087'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Institutions',
#    '1088'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Number',
#    'Total',
#    '1089'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Male',
#    '1090'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Female',
#    '1091'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Institutions',
#    '1092'],
#   ['18.1 Agricultural Land holdings and Area per 2010-11 Census',
#    'Medium Agril. Land Holder 4-10 Ha. St',
#    'Area',
#    'Total',
#    '1093']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Male',
#    '1046'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Female',
#    '1047'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Institutions',
#    '1048'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Number',
#    'Total',
#    '1049'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Male',
#    '1050'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Female',
#    '1051'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Institutions',
#    '1052'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Sc',
#    'Area',
#    'Total',
#    '1053']],
#  [['18.1 Agricultural Land Holdings And Area 2010-11', '', '', '', '1'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11', '', '', '', '2'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Male',
#    '1070'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Female',
#    '1071'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Institutions',
#    '1072'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Number',
#    'Total',
#    '1073'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Male',
#    '1074'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Female',
#    '1075'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Institutions',
#    '1076'],
#   ['18.1 Agricultural Land Holdings And Area 2010-11',
#    'Semi Medium Agril. Land Holder 2-4 Ha. Total',
#    'Area',
#    'Total',
#    '1077'],
#   ['', '', '', 'Total', '1077']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Male',
#    '1110'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Female',
#    '1111'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Institutions',
#    '1112'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Number',
#    'Total',
#    '1113'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Male',
#    '1114'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Female',
#    '1115'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Institutions',
#    '1116'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Large Agrl. Land Holder More than 10 Ha. Sc',
#    'Area',
#    'Total',
#    '1117']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Male',
#    '1030'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Female',
#    '1031'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Institutions',
#    '1032'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Number',
#    'Total',
#    '1033'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Male',
#    '1034'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Female',
#    '1035'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Institutions',
#    '1036'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    'Area',
#    'Total',
#    '1037'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. Others',
#    '',
#    '',
#    '']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Sl. No.',
#    'Sl. No.',
#    'Sl. No.',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Districts',
#    'Districts',
#    'Districts',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Male',
#    '1022'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Female',
#    '1023'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Institutions',
#    '1024'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Number',
#    'Total',
#    '1025'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Male',
#    '1026'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Female',
#    '1027'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Institutions',
#    '1028'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Small Agril. Land Holder 2 Ha. St',
#    'Area',
#    'Total',
#    '1029']],
#  [['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '1'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    '',
#    '',
#    '',
#    '2'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Male',
#    '1166'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Female',
#    '1167'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Institutions',
#    '1168'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Number',
#    'Total',
#    '1169'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Male',
#    '1170'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Female',
#    '1171'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Institutions',
#    '1172'],
#   ['18.1 Agricultural Land Holdings And Area per 2010-11 Census',
#    'Total Agrl. Land Holder Total',
#    'Area',
#    'Total',
#    '1173']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 18
chapter_name = "Additional information"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id, table_name = find_table_details(inner_list[0][0])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list):
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT/Output_html_Chapter18/Chapter18_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT/Dictionary/Chapter18_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)

# %%
#Not used
def remove_before_second_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) >= 2:
        second_occurrence_index = matches[1].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()
