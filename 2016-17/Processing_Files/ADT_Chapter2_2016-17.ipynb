# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
path = "/home/riya/Downloads/ADT/2016-17/HTML/Output_html_Chapter2/kaggle/working/output/"

# %%
os.chdir(path)

# %%
os.listdir()
# Out:
# ['output_page_10.html',
#  'output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_11.html',
#  'output_page_8.html',
#  'output_page_3.html',
#  'output_page_13.html',
#  'output_page_4.html',
#  'output_page_9.html',
#  'output_page_12.html',
#  'output_page_7.html',
#  'output_page_6.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = f"{path}{file}"
  
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            replace_td_content(table_tag)

            process_table_cells(table_tag)
            
            extractor1 = Extractor(table_tag)
            extractor1.parse()
            output_list.append(extractor1.return_list())

# %%
output_list
# Out:
# [[['2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
#    '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
#    '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
#    '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
#    '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers'],
#   ['Age group', '', '', '', '% to totalPopulation'],
#   ['Age group', 'Total', 'Rural', 'Urban', '% to totalPopulation'],
#   ['115', '116', '117', '118', '119'],
#   ['0-4 5-910-14 15-1920-24 25-2930-34 35-3940-44 45-4950-54 55-5960-64 65-6970-74 75-7980-84 85-8990-94 95-99100 Age not stated',
#    '5046719 5241509 5736646 5827277 6052558 5771606 4698380 4695451 3826712 3519782 2699270 2142504 2060052 1520119 1061125 524426 362024 133738 74534 32257 2275745851',
#    '3179495 3309619 3662475 3658264 3549425 3283508 2657749 2770958 2320355 2165676 1665456 1323457 1352255 1039482 736309 350060 249880 83752 49698 21558 14075 25829',
#    '1867224 1931890 2074171 2169013 2503133 2488098 2040631 1924493 1506357 1354106 1033814 819047 707797 480637 324816 174366 112144 49986 24836 106998682 20022',
#    '8.26 8.58 9.39 9.54 9.91 9.45 7.69 7.69 6.26 5.76 4.42 3.51 3.37 2.49 1.74 0.86 0.59 0.220.12 0.05 0.04 0.08'],
#   ['ALL AGES', '61095297', '37469335', '23625962', '100.00'],
#   ['Source per Census 2011.',
#    'Source per Census 2011.',
#    'Source per Census 2011.',
#    'Source per Census 2011.',
#    'Source per Census 2011.']],
#  [['AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011'],
#   ['',
#    'ffl',
#    'Geographical Area Sq.Kms',
#    'Population',
#    'Population',
#    'Population',
#    '% Share to total Population',
#    '%Rank'],
#   ['',
#    'ffl',
#    'Geographical Area Sq.Kms',
#    'Total',
#    'ale',
#    'Females',
#    '% Share to total Population',
#    '%Rank'],
#   ['1', '2', '58', '59', '60', '61', '62', '63']],
#  [['2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011'],
#   ['Sl.No',
#    'District',
#    'Population2011',
#    'Population2011',
#    'Population2011',
#    '% Decadal Change 2001-2011',
#    '% Decadal Change 2001-2011',
#    '% Decadal Change 2001-2011'],
#   ['Sl.No', 'District', '', '', '', '', '', ''],
#   ['Sl.No', 'District', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '64', '65', '66', '67', '68', '69']],
#  [['2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011'],
#   ['',
#    'A.ffl',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child SexRatio 0-6 Years 2011',
#    'Child SexRatio 0-6 Years 2011',
#    'Child SexRatio 0-6 Years 2011'],
#   ['', 'A.ffl', '', '', '', '', '', ''],
#   ['', 'A.ffl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '85', '86', '87', '88', '89', '90']],
#  [['2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears'],
#   ['Sl.No.',
#    'District',
#    '0-14',
#    '0-14',
#    '0-14',
#    '15-59',
#    '15-59',
#    '15-59',
#    '60',
#    '60',
#    '60'],
#   ['Sl.No.', 'District', '', '', '', '', '', 'gMl', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total'],
#   ['1', '2', '120', '121', '122', '123', '124', '125', '126', '127', '128']],
#  [['2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons'],
#   ['Sl. No',
#    'District',
#    'Scheduled Tribe Population2011',
#    'Scheduled Tribe Population2011',
#    'Scheduled Tribe Population2011',
#    'Decadal change 2001-2011',
#    'Decadal change 2001-2011',
#    'Decadal change 2001-2011'],
#   ['Sl. No', 'District', '', '', '', '', '', ''],
#   ['Sl. No', 'District', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '103', '104', '105', '106', '107', '108']],
#  [['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011'],
#   ['',
#    'ffl',
#    'SexRatio 2001',
#    'SexRatio 2001',
#    'SexRatio 2001',
#    'SexRatio 2011',
#    'SexRatio 2011',
#    'SexRatio 2011'],
#   ['', 'ffl', '', '', '', '', '', ''],
#   ['', 'ffl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '70', '71', '72', '73', '74', '75']],
#  [['2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers'],
#   ['Sl.No', 'District', '2017', '2018', '2019', '2020', '2021'],
#   ['1', '2', '135', '136', '137', '138', '139']],
#  [['2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons'],
#   ['Sl. No',
#    'District',
#    'Child Population 0-6 Years 2011',
#    'Child Population 0-6 Years 2011',
#    'Child Population 0-6 Years 2011',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population'],
#   ['Sl. No', 'District', '', '', '', '', '', '', '', '', ''],
#   ['Sl. No',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    '2001',
#    '2001',
#    '2001',
#    '2011',
#    '2011',
#    '2011'],
#   ['Sl. No',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban'],
#   ['1', '2', '76', '77', '78', '79', '80', '81', '82', '83', '84']],
#  [['2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011'],
#   ['',
#    'ffl',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2011Ml',
#    '% Scheduled Tribes 2011Ml',
#    '% Scheduled Tribes 2011Ml'],
#   ['', 'ffl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '109', '110', '111', '112', '113', '114']],
#  [['2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers'],
#   ['', '.ffl', '2011', '2012', '2013', '2014', '2015', '2016', ''],
#   ['1', '2', '129', '130', '131', '132', '133', '134', '']],
#  [['2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011'],
#   ['',
#    'Affl',
#    '% Scheduled Castes 2001',
#    '% Scheduled Castes 2001',
#    '% Scheduled Castes 2001',
#    '%Scheduled Castes 2011',
#    '%Scheduled Castes 2011',
#    '%Scheduled Castes 2011'],
#   ['', 'Affl', '', '', '', '', '', ''],
#   ['', 'Affl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '97', '98', '99', '100', '101', '102']],
#  [['2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011'],
#   ['Sl. No.',
#    'District',
#    'Scheduled Caste Population2011',
#    'Scheduled Caste Population2011',
#    'Scheduled Caste Population2011',
#    'Decadal Change2001-2011',
#    'Decadal Change2001-2011',
#    'Decadal Change2001-2011'],
#   ['Sl. No.', 'District', '', '', '', '', '', ''],
#   ['Sl. No.',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban'],
#   ['1', '2', '91', '92', '93', '94', '95', '96']]]

# %%
list_to_remove = [[['2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
  '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
  '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
  '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers',
  '2.10 2.10 DISTRIBUTION OF POPULATION BY AGEGROUPS RURAL URBAN 2011 Numbers'],
 ['Age group', '', '', '', '% to totalPopulation'],
 ['Age group', 'Total', 'Rural', 'Urban', '% to totalPopulation'],
 ['115', '116', '117', '118', '119'],
 ['0-4 5-910-14 15-1920-24 25-2930-34 35-3940-44 45-4950-54 55-5960-64 65-6970-74 75-7980-84 85-8990-94 95-99100 Age not stated',
  '5046719 5241509 5736646 5827277 6052558 5771606 4698380 4695451 3826712 3519782 2699270 2142504 2060052 1520119 1061125 524426 362024 133738 74534 32257 2275745851',
  '3179495 3309619 3662475 3658264 3549425 3283508 2657749 2770958 2320355 2165676 1665456 1323457 1352255 1039482 736309 350060 249880 83752 49698 21558 14075 25829',
  '1867224 1931890 2074171 2169013 2503133 2488098 2040631 1924493 1506357 1354106 1033814 819047 707797 480637 324816 174366 112144 49986 24836 106998682 20022',
  '8.26 8.58 9.39 9.54 9.91 9.45 7.69 7.69 6.26 5.76 4.42 3.51 3.37 2.49 1.74 0.86 0.59 0.220.12 0.05 0.04 0.08'],
 ['ALL AGES', '61095297', '37469335', '23625962', '100.00'],
 ['Source per Census 2011.',
  'Source per Census 2011.',
  'Source per Census 2011.',
  'Source per Census 2011.',
  'Source per Census 2011.']]]

# %%
for list_set in output_list:
    for item in list_to_remove: 
        if(list_set == item):
            output_list.remove(list_set)

# %%
output_list
# Out:
# [[['AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011',
#    'AREA AND POPULATION ffl 2.1 Population and percentage share to total Population 2011'],
#   ['',
#    'ffl',
#    'Geographical Area Sq.Kms',
#    'Population',
#    'Population',
#    'Population',
#    '% Share to total Population',
#    '%Rank'],
#   ['',
#    'ffl',
#    'Geographical Area Sq.Kms',
#    'Total',
#    'ale',
#    'Females',
#    '% Share to total Population',
#    '%Rank'],
#   ['1', '2', '58', '59', '60', '61', '62', '63']],
#  [['2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 20112.2 Rural and Urban Population and Decadal change by residence 2011'],
#   ['Sl.No',
#    'District',
#    'Population2011',
#    'Population2011',
#    'Population2011',
#    '% Decadal Change 2001-2011',
#    '% Decadal Change 2001-2011',
#    '% Decadal Change 2001-2011'],
#   ['Sl.No', 'District', '', '', '', '', '', ''],
#   ['Sl.No', 'District', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '64', '65', '66', '67', '68', '69']],
#  [['2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 0-6 2.5 Child Sex Ratio 0-6 Years by residence 2001-2011'],
#   ['',
#    'A.ffl',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child SexRatio 0-6 Years 2011',
#    'Child SexRatio 0-6 Years 2011',
#    'Child SexRatio 0-6 Years 2011'],
#   ['', 'A.ffl', '', '', '', '', '', ''],
#   ['', 'A.ffl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '85', '86', '87', '88', '89', '90']],
#  [['2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears',
#    '2.11 ffl 2.11 DISTRICTWISE POPULATION BY AGE GROUPS AND SEX 2011Age groups inyears'],
#   ['Sl.No.',
#    'District',
#    '0-14',
#    '0-14',
#    '0-14',
#    '15-59',
#    '15-59',
#    '15-59',
#    '60',
#    '60',
#    '60'],
#   ['Sl.No.', 'District', '', '', '', '', '', 'gMl', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total'],
#   ['1', '2', '120', '121', '122', '123', '124', '125', '126', '127', '128']],
#  [['2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons'],
#   ['Sl. No',
#    'District',
#    'Scheduled Tribe Population2011',
#    'Scheduled Tribe Population2011',
#    'Scheduled Tribe Population2011',
#    'Decadal change 2001-2011',
#    'Decadal change 2001-2011',
#    'Decadal change 2001-2011'],
#   ['Sl. No', 'District', '', '', '', '', '', ''],
#   ['Sl. No', 'District', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '103', '104', '105', '106', '107', '108']],
#  [['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011'],
#   ['',
#    'ffl',
#    'SexRatio 2001',
#    'SexRatio 2001',
#    'SexRatio 2001',
#    'SexRatio 2011',
#    'SexRatio 2011',
#    'SexRatio 2011'],
#   ['', 'ffl', '', '', '', '', '', ''],
#   ['', 'ffl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '70', '71', '72', '73', '74', '75']],
#  [['2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers'],
#   ['Sl.No', 'District', '2017', '2018', '2019', '2020', '2021'],
#   ['1', '2', '135', '136', '137', '138', '139']],
#  [['2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 0-6 Child Population 0-6 and proportion by residence 2011 Persons'],
#   ['Sl. No',
#    'District',
#    'Child Population 0-6 Years 2011',
#    'Child Population 0-6 Years 2011',
#    'Child Population 0-6 Years 2011',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population',
#    'ProporationofChild Population'],
#   ['Sl. No', 'District', '', '', '', '', '', '', '', '', ''],
#   ['Sl. No',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    '2001',
#    '2001',
#    '2001',
#    '2011',
#    '2011',
#    '2011'],
#   ['Sl. No',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban'],
#   ['1', '2', '76', '77', '78', '79', '80', '81', '82', '83', '84']],
#  [['2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 2.9 Percentage of Scheduled Tribes to total Population 2011'],
#   ['',
#    'ffl',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2011Ml',
#    '% Scheduled Tribes 2011Ml',
#    '% Scheduled Tribes 2011Ml'],
#   ['', 'ffl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '109', '110', '111', '112', '113', '114']],
#  [['2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers',
#    '2.12 CAz Projected Population Numbers'],
#   ['', '.ffl', '2011', '2012', '2013', '2014', '2015', '2016', ''],
#   ['1', '2', '129', '130', '131', '132', '133', '134', '']],
#  [['2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 2.7 Percentage of Scheduled Castes to total Population 2001-2011'],
#   ['',
#    'Affl',
#    '% Scheduled Castes 2001',
#    '% Scheduled Castes 2001',
#    '% Scheduled Castes 2001',
#    '%Scheduled Castes 2011',
#    '%Scheduled Castes 2011',
#    '%Scheduled Castes 2011'],
#   ['', 'Affl', '', '', '', '', '', ''],
#   ['', 'Affl', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '97', '98', '99', '100', '101', '102']],
#  [['2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 20112.6 Scheduled Caste Population and Decadal change by residence 2011'],
#   ['Sl. No.',
#    'District',
#    'Scheduled Caste Population2011',
#    'Scheduled Caste Population2011',
#    'Scheduled Caste Population2011',
#    'Decadal Change2001-2011',
#    'Decadal Change2001-2011',
#    'Decadal Change2001-2011'],
#   ['Sl. No.', 'District', '', '', '', '', '', ''],
#   ['Sl. No.',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban'],
#   ['1', '2', '91', '92', '93', '94', '95', '96']]]

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2017', '31.3.201', '31.3.2017', '31.3.2017.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'tP', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')

    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = {"ale": "Male", "0-6 Child": "Child", "ProporationofChild": "Proportion of Child", "2011Ml": "2011", "2011Age" : "2011 Age", "inyears" : "in years", "DISTRICTWISE" : "DISTRICT WISE"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(output_list)
output_list
# Out:
# [[['2.1 Population and percentage share to total Population 2011',
#    '2.1 Population and percentage share to total Population 2011',
#    '2.1 Population and percentage share to total Population 2011',
#    '2.1 Population and percentage share to total Population 2011',
#    '2.1 Population and percentage share to total Population 2011',
#    '2.1 Population and percentage share to total Population 2011',
#    '2.1 Population and percentage share to total Population 2011',
#    '2.1 Population and percentage share to total Population 2011'],
#   ['',
#    '',
#    'Geographical Area Sq.Kms',
#    'Population',
#    'Population',
#    'Population',
#    '% Share to total Population',
#    '% Rank'],
#   ['',
#    '',
#    'Geographical Area Sq.Kms',
#    'Total',
#    'Male',
#    'Females',
#    '% Share to total Population',
#    '% Rank'],
#   ['1', '2', '58', '59', '60', '61', '62', '63']],
#  [['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '2.2 Rural and Urban Population and Decadal change by residence 2011'],
#   ['Sl.No',
#    'District',
#    'Population 2011',
#    'Population 2011',
#    'Population 2011',
#    '% Decadal Change 2001-2011',
#    '% Decadal Change 2001-2011',
#    '% Decadal Change 2001-2011'],
#   ['Sl.No', 'District', '', '', '', '', '', ''],
#   ['Sl.No', 'District', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '64', '65', '66', '67', '68', '69']],
#  [['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    '2.5 Child Sex Ratio 0-6 Years by residence 2001-2011'],
#   ['',
#    '',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child Sex Ratio 0-6 Years 2001',
#    'Child Sex Ratio 0-6 Years 2011',
#    'Child Sex Ratio 0-6 Years 2011',
#    'Child Sex Ratio 0-6 Years 2011'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '85', '86', '87', '88', '89', '90']],
#  [['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years'],
#   ['Sl.No.',
#    'District',
#    '0-14',
#    '0-14',
#    '0-14',
#    '15-59',
#    '15-59',
#    '15-59',
#    '60',
#    '60',
#    '60'],
#   ['Sl.No.', 'District', '', '', '', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total',
#    'Male',
#    'Female',
#    'Total'],
#   ['1', '2', '120', '121', '122', '123', '124', '125', '126', '127', '128']],
#  [['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    '2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons'],
#   ['Sl. No',
#    'District',
#    'Scheduled Tribe Population 2011',
#    'Scheduled Tribe Population 2011',
#    'Scheduled Tribe Population 2011',
#    'Decadal change 2001-2011',
#    'Decadal change 2001-2011',
#    'Decadal change 2001-2011'],
#   ['Sl. No', 'District', '', '', '', '', '', ''],
#   ['Sl. No', 'District', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '103', '104', '105', '106', '107', '108']],
#  [['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    '2.3 Ratio No.of Females per 1000 Males 2001- 2011'],
#   ['',
#    '',
#    'Sex Ratio 2001',
#    'Sex Ratio 2001',
#    'Sex Ratio 2001',
#    'Sex Ratio 2011',
#    'Sex Ratio 2011',
#    'Sex Ratio 2011'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '70', '71', '72', '73', '74', '75']],
#  [['2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers'],
#   ['Sl.No', 'District', '2017', '2018', '2019', '2020', '2021'],
#   ['1', '2', '135', '136', '137', '138', '139']],
#  [['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    '2.4 Child Population 0-6 and proportion by residence 2011 Persons'],
#   ['Sl. No',
#    'District',
#    'Child Population 0-6 Years 2011',
#    'Child Population 0-6 Years 2011',
#    'Child Population 0-6 Years 2011',
#    'Proportion of Child Population',
#    'Proportion of Child Population',
#    'Proportion of Child Population',
#    'Proportion of Child Population',
#    'Proportion of Child Population',
#    'Proportion of Child Population'],
#   ['Sl. No', 'District', '', '', '', '', '', '', '', '', ''],
#   ['Sl. No',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    '2001',
#    '2001',
#    '2001',
#    '2011',
#    '2011',
#    '2011'],
#   ['Sl. No',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban'],
#   ['1', '2', '76', '77', '78', '79', '80', '81', '82', '83', '84']],
#  [['2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '2.9 Percentage of Scheduled Tribes to total Population 2011'],
#   ['',
#    '',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2001',
#    '% Scheduled Tribes 2011',
#    '% Scheduled Tribes 2011',
#    '% Scheduled Tribes 2011'],
#   ['', '', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '109', '110', '111', '112', '113', '114']],
#  [['2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers',
#    '2.12 Projected Population Numbers'],
#   ['', '', '2011', '2012', '2013', '2014', '2015', '2016', ''],
#   ['1', '2', '129', '130', '131', '132', '133', '134', '']],
#  [['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '2.7 Percentage of Scheduled Castes to total Population 2001-2011'],
#   ['',
#    '',
#    '% Scheduled Castes 2001',
#    '% Scheduled Castes 2001',
#    '% Scheduled Castes 2001',
#    '% Scheduled Castes 2011',
#    '% Scheduled Castes 2011',
#    '% Scheduled Castes 2011'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Total', 'Rural', 'Urban', 'Total', 'Rural', 'Urban'],
#   ['1', '2', '97', '98', '99', '100', '101', '102']],
#  [['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    '2.6 Scheduled Caste Population and Decadal change by residence 2011'],
#   ['Sl. No.',
#    'District',
#    'Scheduled Caste Population 2011',
#    'Scheduled Caste Population 2011',
#    'Scheduled Caste Population 2011',
#    'Decadal Change 2001-2011',
#    'Decadal Change 2001-2011',
#    'Decadal Change 2001-2011'],
#   ['Sl. No.', 'District', '', '', '', '', '', ''],
#   ['Sl. No.',
#    'District',
#    'Total',
#    'Rural',
#    'Urban',
#    'Total',
#    'Rural',
#    'Urban'],
#   ['1', '2', '91', '92', '93', '94', '95', '96']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['2.1 Population and percentage share to total Population 2011',
#    '',
#    '',
#    '1'],
#   ['2.1 Population and percentage share to total Population 2011',
#    '',
#    '',
#    '2'],
#   ['2.1 Population and percentage share to total Population 2011',
#    'Geographical Area Sq.Kms',
#    'Geographical Area Sq.Kms',
#    '58'],
#   ['2.1 Population and percentage share to total Population 2011',
#    'Population',
#    'Total',
#    '59'],
#   ['2.1 Population and percentage share to total Population 2011',
#    'Population',
#    'Male',
#    '60'],
#   ['2.1 Population and percentage share to total Population 2011',
#    'Population',
#    'Females',
#    '61'],
#   ['2.1 Population and percentage share to total Population 2011',
#    '% Share to total Population',
#    '% Share to total Population',
#    '62'],
#   ['2.1 Population and percentage share to total Population 2011',
#    '% Rank',
#    '% Rank',
#    '63']],
#  [['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    'Population 2011',
#    '',
#    'Total',
#    '64'],
#   ['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    'Population 2011',
#    '',
#    'Rural',
#    '65'],
#   ['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    'Population 2011',
#    '',
#    'Urban',
#    '66'],
#   ['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '% Decadal Change 2001-2011',
#    '',
#    'Total',
#    '67'],
#   ['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '% Decadal Change 2001-2011',
#    '',
#    'Rural',
#    '68'],
#   ['2.2 Rural and Urban Population and Decadal change by residence 2011',
#    '% Decadal Change 2001-2011',
#    '',
#    'Urban',
#    '69']],
#  [['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011', '', '', '', '1'],
#   ['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011', '', '', '', '2'],
#   ['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    'Child Sex Ratio 0-6 Years 2001',
#    '',
#    'Total',
#    '85'],
#   ['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    'Child Sex Ratio 0-6 Years 2001',
#    '',
#    'Rural',
#    '86'],
#   ['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    'Child Sex Ratio 0-6 Years 2001',
#    '',
#    'Urban',
#    '87'],
#   ['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    'Child Sex Ratio 0-6 Years 2011',
#    '',
#    'Total',
#    '88'],
#   ['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    'Child Sex Ratio 0-6 Years 2011',
#    '',
#    'Rural',
#    '89'],
#   ['2.5 Child Sex Ratio 0-6 Years by residence 2001-2011',
#    'Child Sex Ratio 0-6 Years 2011',
#    '',
#    'Urban',
#    '90']],
#  [['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '0-14',
#    '',
#    'Male',
#    '120'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '0-14',
#    '',
#    'Female',
#    '121'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '0-14',
#    '',
#    'Total',
#    '122'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '15-59',
#    '',
#    'Male',
#    '123'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '15-59',
#    '',
#    'Female',
#    '124'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '15-59',
#    '',
#    'Total',
#    '125'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '60',
#    '',
#    'Male',
#    '126'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '60',
#    '',
#    'Female',
#    '127'],
#   ['2.11 District Wise Population By Age Groups And Sex 2011 Age groups in years',
#    '60',
#    '',
#    'Total',
#    '128']],
#  [['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'Sl. No',
#    'Sl. No',
#    'Sl. No',
#    '1'],
#   ['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'Scheduled Tribe Population 2011',
#    '',
#    'Total',
#    '103'],
#   ['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'Scheduled Tribe Population 2011',
#    '',
#    'Rural',
#    '104'],
#   ['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'Scheduled Tribe Population 2011',
#    '',
#    'Urban',
#    '105'],
#   ['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'Decadal change 2001-2011',
#    '',
#    'Total',
#    '106'],
#   ['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'Decadal change 2001-2011',
#    '',
#    'Rural',
#    '107'],
#   ['2.8 Scheduled Tribe Population and Decadal change by residence 2011 Persons',
#    'Decadal change 2001-2011',
#    '',
#    'Urban',
#    '108']],
#  [['2.3 Ratio No.of Females per 1000 Males 2001- 2011', '', '', '', '1'],
#   ['2.3 Ratio No.of Females per 1000 Males 2001- 2011', '', '', '', '2'],
#   ['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    'Sex Ratio 2001',
#    '',
#    'Total',
#    '70'],
#   ['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    'Sex Ratio 2001',
#    '',
#    'Rural',
#    '71'],
#   ['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    'Sex Ratio 2001',
#    '',
#    'Urban',
#    '72'],
#   ['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    'Sex Ratio 2011',
#    '',
#    'Total',
#    '73'],
#   ['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    'Sex Ratio 2011',
#    '',
#    'Rural',
#    '74'],
#   ['2.3 Ratio No.of Females per 1000 Males 2001- 2011',
#    'Sex Ratio 2011',
#    '',
#    'Urban',
#    '75']],
#  [['2.12 Projected Population Numbers', 'Sl.No', '1'],
#   ['2.12 Projected Population Numbers', 'District', '2'],
#   ['2.12 Projected Population Numbers', '2017', '135'],
#   ['2.12 Projected Population Numbers', '2018', '136'],
#   ['2.12 Projected Population Numbers', '2019', '137'],
#   ['2.12 Projected Population Numbers', '2020', '138'],
#   ['2.12 Projected Population Numbers', '2021', '139']],
#  [['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Sl. No',
#    'Sl. No',
#    'Sl. No',
#    'Sl. No',
#    '1'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Child Population 0-6 Years 2011',
#    '',
#    'Total',
#    'Total',
#    '76'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Child Population 0-6 Years 2011',
#    '',
#    'Rural',
#    'Rural',
#    '77'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Child Population 0-6 Years 2011',
#    '',
#    'Urban',
#    'Urban',
#    '78'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Proportion of Child Population',
#    '',
#    '2001',
#    'Total',
#    '79'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Proportion of Child Population',
#    '',
#    '2001',
#    'Rural',
#    '80'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Proportion of Child Population',
#    '',
#    '2001',
#    'Urban',
#    '81'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Proportion of Child Population',
#    '',
#    '2011',
#    'Total',
#    '82'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Proportion of Child Population',
#    '',
#    '2011',
#    'Rural',
#    '83'],
#   ['2.4 Child Population 0-6 and proportion by residence 2011 Persons',
#    'Proportion of Child Population',
#    '',
#    '2011',
#    'Urban',
#    '84']],
#  [['2.9 Percentage of Scheduled Tribes to total Population 2011', '', '', '1'],
#   ['2.9 Percentage of Scheduled Tribes to total Population 2011', '', '', '2'],
#   ['2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '% Scheduled Tribes 2001',
#    'Total',
#    '109'],
#   ['2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '% Scheduled Tribes 2001',
#    'Rural',
#    '110'],
#   ['2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '% Scheduled Tribes 2001',
#    'Urban',
#    '111'],
#   ['2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '% Scheduled Tribes 2011',
#    'Total',
#    '112'],
#   ['2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '% Scheduled Tribes 2011',
#    'Rural',
#    '113'],
#   ['2.9 Percentage of Scheduled Tribes to total Population 2011',
#    '% Scheduled Tribes 2011',
#    'Urban',
#    '114']],
#  [['2.12 Projected Population Numbers', '', '1'],
#   ['2.12 Projected Population Numbers', '', '2'],
#   ['2.12 Projected Population Numbers', '2011', '129'],
#   ['2.12 Projected Population Numbers', '2012', '130'],
#   ['2.12 Projected Population Numbers', '2013', '131'],
#   ['2.12 Projected Population Numbers', '2014', '132'],
#   ['2.12 Projected Population Numbers', '2015', '133'],
#   ['2.12 Projected Population Numbers', '2016', '134'],
#   ['2.12 Projected Population Numbers', '', '']],
#  [['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '',
#    '',
#    '',
#    '1'],
#   ['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '',
#    '',
#    '',
#    '2'],
#   ['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '% Scheduled Castes 2001',
#    '',
#    'Total',
#    '97'],
#   ['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '% Scheduled Castes 2001',
#    '',
#    'Rural',
#    '98'],
#   ['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '% Scheduled Castes 2001',
#    '',
#    'Urban',
#    '99'],
#   ['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '% Scheduled Castes 2011',
#    '',
#    'Total',
#    '100'],
#   ['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '% Scheduled Castes 2011',
#    '',
#    'Rural',
#    '101'],
#   ['2.7 Percentage of Scheduled Castes to total Population 2001-2011',
#    '% Scheduled Castes 2011',
#    '',
#    'Urban',
#    '102']],
#  [['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'Sl. No.',
#    'Sl. No.',
#    'Sl. No.',
#    '1'],
#   ['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'Scheduled Caste Population 2011',
#    '',
#    'Total',
#    '91'],
#   ['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'Scheduled Caste Population 2011',
#    '',
#    'Rural',
#    '92'],
#   ['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'Scheduled Caste Population 2011',
#    '',
#    'Urban',
#    '93'],
#   ['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'Decadal Change 2001-2011',
#    '',
#    'Total',
#    '94'],
#   ['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'Decadal Change 2001-2011',
#    '',
#    'Rural',
#    '95'],
#   ['2.6 Scheduled Caste Population and Decadal change by residence 2011',
#    'Decadal Change 2001-2011',
#    '',
#    'Urban',
#    '96']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 2
chapter_name = "Area and Population"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id, table_name = find_table_details(inner_list[0][0])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list):
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT/2016-17/HTML/Output_html_Chapter2/Chapter2_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT/2016-17/Dictionary/Chapter2_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)

# %%
#Not used
def remove_before_second_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) >= 2:
        second_occurrence_index = matches[1].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()
