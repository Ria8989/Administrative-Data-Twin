# %% [markdown]
# # Extracting table header as list

# %%
import collections
collections.Callable = collections.abc.Callable

# %%
from bs4 import BeautifulSoup, NavigableString
from html_table_extractor.extractor import Extractor
import pandas as pd
import os
import re

# %%
path = "/home/riya/Downloads/ADT/Output_html_Chapter12/kaggle/working/output/"

# %%
os.chdir(path)

# %%
os.listdir()
# Out:
# ['output_page_18.html',
#  'output_page_15.html',
#  'output_page_10.html',
#  'output_page_16.html',
#  'output_page_1.html',
#  'output_page_2.html',
#  'output_page_5.html',
#  'output_page_11.html',
#  'output_page_8.html',
#  'output_page_19.html',
#  'output_page_3.html',
#  'output_page_13.html',
#  'output_page_20.html',
#  'output_page_4.html',
#  'output_page_14.html',
#  'output_page_9.html',
#  'output_page_12.html',
#  'output_page_17.html',
#  'output_page_7.html',
#  'output_page_6.html']

# %%
output_list = []

# %%
output_list
# Out:
# []

# %%
allowed_two_letter_words = {'sl','sc', 'st', 'cc', 'tp', 'tb', 'ts', 'tg', 'km', 'gm', 'an', 'at', 'by', 'do', 'go', 'if', 'in', 'is', 'it', 'me', 'my', 'no', 'of', 'on', 'or', 'so', 'to', 'up', 'us'}

def replace_td_content(tag):
    if isinstance(tag, NavigableString):
        return  # Skip strings, as they don't have 'contents'

    if tag.name == 'td':
        # Extract only meaningful English words and numbers
        valid_characters = set("abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789-.%")
        filtered_content = ''.join(char if char in valid_characters else ' ' for char in tag.get_text())
        
        # Remove extra spaces and words with less than 3 characters
        cleaned_content = ' '.join(word for word in filtered_content.split() if len(word) >= 3 or word.isdigit() or word.lower() in allowed_two_letter_words or word=='%')
        
        # Set the cleaned content as the tag's string
        tag.string = cleaned_content
    elif tag.contents:
        for child in tag.contents:
            replace_td_content(child)

# %%
def process_table_cells(target_table):
    if not target_table:
        print("Table not found in the HTML content.")
        return

    flag1 = 0
    flag2 = 0

    # Loop through each row in the table
    for row in target_table.find_all('tr'):
        # Loop through each cell in the row
        if(flag1 == 1 and flag2 == 1):
            row.decompose()
        else : 
            for cell in row.find_all(['td', 'th']):
                # Process the cell content (you can modify this part based on your requirements)
                cell_content = cell.get_text(strip=True)
                if(cell_content == '1'):
                    flag1 = 1
                if(cell_content == '2'):
                    flag2 = 1

# %%
# iterate through all file 
for file in os.listdir(): 
    # Check whether file is in text format or not 
    if file.endswith(".html"): 
        file_path = f"{path}{file}"
  
        with open(file_path) as fp:
            soup = BeautifulSoup(fp, "html.parser")
            
            for tag in soup.find_all(attrs={'style': True}):
                tag.attrs.pop('style')
            
            table_tag = soup.find('table')
            
            replace_td_content(table_tag)

            process_table_cells(table_tag)
            
            extractor1 = Extractor(table_tag)
            extractor1.parse()
            output_list.append(extractor1.return_list())

# %%
output_list
# Out:
# [[['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers'],
#   ['',
#    'ffl',
#    'cheduled Tribes',
#    'cheduled Tribes',
#    'cheduled Tribes',
#    'cheduled Tribes',
#    'cheduled Tribes',
#    'cheduled Tribes'],
#   ['',
#    'ffl',
#    'Pri marySchool 1-8thStandard',
#    'Pri marySchool 1-8thStandard',
#    'Pri marySchool 1-8thStandard',
#    'igh School9-10thStandard',
#    'igh School9-10thStandard',
#    'igh School9-10thStandard'],
#   ['',
#    'ffl',
#    'fiP Boys',
#    'fiQAi Girls',
#    'Total',
#    'fiP Boys',
#    'fiQAi Girls',
#    'Total'],
#   ['1', '2', '824', '825', '826', '827', '828', '829']],
#  [['12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017'],
#   ['l.No.',
#    'District',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric'],
#   ['l.No.',
#    'District',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['l.No.', 'District', 'Nos', '', 'Nos', '', 'ANos', ''],
#   ['l.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'ANos',
#    'Students'],
#   ['1', '2', '806', '807', '808', '809', '810', '811']],
#  [['12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017'],
#   ['Sl.No.',
#    'District',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric'],
#   ['Sl.No.',
#    'District',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '776', '777', '778', '779', '780', '781']],
#  [['12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017'],
#   ['',
#    'ffl',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    ''],
#   ['',
#    'ffl',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi irls',
#    'fiQAi irls',
#    'Total',
#    'Total',
#    ''],
#   ['', 'ffl', 'Nos', '', 'Nos', '', 'ANos', '', ''],
#   ['', 'ffl', 'Nos', 'Students', 'Nos', 'Students', 'ANos', 'Students', ''],
#   ['1', '2', '812', '813', '814', '815', '816', '817', '']],
#  [['12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.',
#    '12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.',
#    '12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.',
#    '12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.',
#    '12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.',
#    '12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.',
#    '12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.',
#    '12. SocialWelfare12.1 fiAi Scheduled Caste Student HostelsAs on 31.3.2017 in Nos.'],
#   ['',
#    '',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric'],
#   ['',
#    '',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '722', '723', '724', '725', '726', '727']],
#  [['12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.'],
#   ['Sl.No.',
#    'District',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric'],
#   ['Sl.No.',
#    'District',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '728', '729', '730', '731', '732', '733']],
#  [['12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos'],
#   ['',
#    'ffl',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric'],
#   ['',
#    'ffl',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['', 'ffl', '', '', '', '', '', ''],
#   ['', 'ffl', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'tudents'],
#   ['1', '2', '746', '747', '748', '749', '750', '751']],
#  [['12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017'],
#   ['',
#    'ffl',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric'],
#   ['',
#    'ffl',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['', 'ffl', '', '', '', '', '', ''],
#   ['', 'ffl', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '782', '783', '784', '785', '786', '787']],
#  [['12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribes Student Hostels on 31.3.2017 in Nos.'],
#   ['Sl.No',
#    'District',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric'],
#   ['Sl.No',
#    'District',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['Sl.No', 'District', '', '', '', '', '', ''],
#   ['Sl.No',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '764', '765', '766', '767', '768', '769']],
#  [['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers'],
#   ['Sl.No',
#    'District',
#    'ackward Castes',
#    'ackward Castes',
#    'ackward Castes',
#    'ackward Castes',
#    'ackward Castes',
#    'ackward Castes'],
#   ['Sl.No',
#    'District',
#    'marySchool1-8thStandard',
#    'marySchool1-8thStandard',
#    'marySchool1-8thStandard',
#    'igh School 9-10thStandard',
#    'igh School 9-10thStandard',
#    'igh School 9-10thStandard'],
#   ['Sl.No',
#    'District',
#    'fiP Boys',
#    'fiQAi Girls',
#    'Total',
#    'fiP Boys',
#    'fiQAi Girls',
#    'Total'],
#   ['1', '2', '830', '831', '832', '833', '834', '835']],
#  [['12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos.'],
#   ['',
#    'ffl',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric'],
#   ['',
#    'ffl',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['', 'ffl', '', '', '', '', '', ''],
#   ['', 'ffl', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '734', '735', '736', '737', '738', '739']],
#  [['12.4 fiAi Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 fiAi Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 fiAi Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 fiAi Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 fiAi Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 fiAi Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 fiAi Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 fiAi Ashrama Residential Students Hostels Year 2016-17'],
#   ['Sl.No',
#    'District',
#    'wAi fiAi Scheduled Caste Ashrama Residential Students Hostels',
#    'wAi fiAi Scheduled Caste Ashrama Residential Students Hostels',
#    'Scheduled Tribe Ashrama Residential StudentsHostels',
#    'Scheduled Tribe Ashrama Residential StudentsHostels',
#    'BackwardClassAshram Residential Students Hostels',
#    'BackwardClassAshram Residential Students Hostels'],
#   ['Sl.No',
#    'District',
#    'Numbers',
#    'students',
#    'Numbers',
#    'students',
#    'Numbers',
#    'students'],
#   ['1', '2', '794', '795', '796', '797', '798', '799']],
#  [['12.6 1-10 wAi Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 1-10 wAi Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 1-10 wAi Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 1-10 wAi Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 1-10 wAi Scholarship paid to 1-10th Standard Students 2016-17 In Numbers'],
#   ['Sl.No', 'District', 'Cfi inorities', 'Cfi inorities', 'Cfi inorities'],
#   ['Sl.No', 'District', '1-10thStandard', '1-10thStandard', '1-10thStandard'],
#   ['Sl.No', 'District', 'fiP Boys', 'fiQAi Girls', 'Total'],
#   ['1', '2', '836', '837', '838']],
#  [['12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos',
#    '12.1 fiAi Scheduled Caste Student Hostels on 31.3.2017 in Nos'],
#   ['Sl.No.',
#    'District',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric'],
#   ['Sl.No.',
#    'District',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi irls',
#    'fiQAi irls',
#    'Total',
#    'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '740', '741', '742', '743', '744', '745']],
#  [['12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017',
#    '12.5 Cfi fiAi Minorities Student Hostels on 31.3.2017'],
#   ['',
#    'ffl',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric'],
#   ['',
#    'ffl',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi irls',
#    'fiQAi irls',
#    'Total',
#    'Total'],
#   ['', 'ffl', 'Nos', '', 'Nos', '', 'ANos', ''],
#   ['', 'ffl', 'Nos', 'Students', 'Nos', 'Students', 'ANos', 'Students'],
#   ['1', '2', '800', '801', '802', '803', '804', '805']],
#  [['12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017 in Nos.'],
#   ['',
#    '',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric'],
#   ['',
#    '',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '770', '771', '772', '773', '774', '775']],
#  [['12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017',
#    '12.3 fiAi Backward Class Student Hostels on 31.3.2017'],
#   ['Sl. No',
#    'District',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric',
#    'ided Post-Matric'],
#   ['Sl. No',
#    'District',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['Sl. No', 'District', '', '', '', '', '', ''],
#   ['Sl. No',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '788', '789', '790', '791', '792', '793']],
#  [['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers'],
#   ['Sl.No.',
#    'District',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste'],
#   ['Sl.No.',
#    'District',
#    'Prim arySchool 1-8th Standard',
#    'Prim arySchool 1-8th Standard',
#    'Prim arySchool 1-8th Standard',
#    'igh School 9-10thStandard',
#    'igh School 9-10thStandard',
#    'igh School 9-10thStandard'],
#   ['Sl.No.',
#    'District',
#    'fiP Boys',
#    'fiQAi Girls',
#    'Total',
#    'fiP gBoys',
#    'fiQAi Girls',
#    'Total'],
#   ['1', '2', '818', '819', '820', '821', '822', '823']],
#  [['12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.'],
#   ['',
#    '',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric'],
#   ['',
#    '',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '758', '759', '760', '761', '762', '763']],
#  [['12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.',
#    '12.2 fiAi Scheduled Tribe Student Hostels on 31.3.2017 in Nos.'],
#   ['Sl.No.',
#    'District',
#    'overnment Post-Matric',
#    'overnment Post-Matric',
#    'overnment Post-Matric',
#    'overnment Post-Matric',
#    'overnment Post-Matric',
#    'overnment Post-Matric'],
#   ['Sl.No.',
#    'District',
#    'fiP Boys',
#    'fiP Boys',
#    'fiQAi Girls',
#    'fiQAi Girls',
#    'Total',
#    'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '752', '753', '754', '755', '756', '757']]]

# %%
#list_to_remove = [[['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'aQv fiAi Indian System of Medicine HospitalsIndian System of MedicineDispensaries',
   'aQv fiAi Indian System of Medicine HospitalsIndian System of MedicineDispensaries',
   'aQv fiAi Indian System of Medicine HospitalsIndian System of MedicineDispensaries',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds',
   'Nos',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds'],
  ['1',
   '2',
   '667',
   '668',
   '669',
   '670',
   '670',
   '671',
   '672',
   '673',
   '674',
   '675']]]
# Out:
#   File "/tmp/ipykernel_16719/2863250876.py", line 2
#     '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#     ^
# IndentationError: unexpected indent

# %%
#for list_set in output_list:
    for item in list_to_remove: 
        if(list_set == item):
            output_list.remove(list_set)
# Out:
#   File "/tmp/ipykernel_16719/2081342099.py", line 2
#     for item in list_to_remove:
#     ^
# IndentationError: unexpected indent

# %%
#list_to_add = [[['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
   '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.'],
  ['Sl.No',
   'Districts',
   'Dfl Allopathy Hospitals',
   'Dfl Allopathy Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of Medicine Hospitals',
   'Indian System of MedicineDispensaries',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Primary Health Centres',
   'Primary Health Centres',
   'Community Health Centres',
   'Community Health Centres'],
  ['Sl.No',
   'Districts',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds',
   'Nos',
   'No.of Pvt. Hospitals Including Nursing Homes Clinics',
   'Nos.',
   'Beds',
   'Nos.',
   'Beds'],
  ['1',
   '2',
   '667',
   '668',
   '669',
   '670',
   '670.1',
   '671',
   '672',
   '673',
   '674',
   '675']]]

for item in list_to_add:
    output_list.append(item)

# %%
#output_list
# Out:
# [[['11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.',
#    '11. ealth Family welfare Services 11.1v ffl Taluk District Autonomous Teaching Other Hospitals on 31.3.2017 In Nos.'],
#   ['Sl. No.',
#    'Districts',
#    'lukaHq Hospitals',
#    'lukaHq Hospitals',
#    'ffl District Hospitals',
#    'ffl District Hospitals',
#    'Other Hos pitals under HFW',
#    'Other Hos pitals under HFW',
#    'tP Autonomous Teaching Hospitals',
#    'tP Autonomous Teaching Hospitals',
#    'Others CHCs',
#    'Others CHCs',
#    'Total',
#    'Total'],
#   ['Sl. No.',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'UNos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '648',
#    '649',
#    '650',
#    '651',
#    '652',
#    '653',
#    '654',
#    '655',
#    '656',
#    '657',
#    '658',
#    '659']],
#  [['11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.',
#    '11.2 UNo pitals Doctors BedsAs on 31.3.2017 In Nos.'],
#   ['',
#    'ffl',
#    'No.Hospitals',
#    'No.Hospitals',
#    'No.Hospitals',
#    'ofD No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Private',
#    'Total',
#    'ofD No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['',
#    'ffl',
#    'Govt.',
#    'Nursing Home Hospitals',
#    'Total',
#    'ofD No.Govt. Doctors',
#    'No.of beds in Govt. Hospitals',
#    'Medical Shops',
#    'BloodBanks'],
#   ['1', '2', '660', '661', '662', '663', '664', '665', '666']],
#  [['11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos',
#    '11.5 Family Planning Measures Year 2016-17 In Nos'],
#   ['',
#    'ffl',
#    'Sterlisation',
#    'Sterlisation',
#    'Family Planning Measures in users',
#    'Family Planning Measures in users',
#    'Family Planning Measures in users'],
#   ['', 'ffl', 'Vasectomy', 'Tubectomy', 'I.U.D user', 'C.C. user', 'O.P user'],
#   ['1', '2', '682', '683', '684', '685', '686']],
#  [['11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.',
#    '11.5 TB ControlProgrammes on 31.3.2017 inNos.'],
#   ['Sl.No.',
#    'Districts',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme',
#    'T.B.ControlProgramme'],
#   ['Sl.No.',
#    'Districts',
#    'No ofIdentified T.B.patient',
#    'No ofIdentified T.B.patient',
#    'No ofIdentified T.B.patient',
#    'Patients Cured',
#    'Patients Cured',
#    'Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred'],
#   ['Sl.No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total',
#    'Afi Male',
#    'Female',
#    'Total'],
#   ['1', '2', '705', '706', '707', '708', '709', '710', '711', '712', '713']],
#  [['11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.',
#    '11.4 Immunisation given to Children Year 2016-17 In Nos.'],
#   ['Sl.No.',
#    'Districts',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation',
#    'Immunisation'],
#   ['Sl.No.',
#    'Districts',
#    'fl. D.P.T.',
#    'Polio',
#    'BCG',
#    'Measles',
#    'T.T',
#    '.Pentavalent includes Hepatities D.P.T'],
#   ['1', '2', '676', '677', '678', '679', '680', '681']],
#  [['11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in',
#    '11.6 DifferentHealthFacilities Ason31.3.2017 in'],
#   ['',
#    'ffl',
#    'FRU Units First Referal Units',
#    '108 Ambulance',
#    '108 Ambulance',
#    '24 7 24 hoursand 7days workingHospitals',
#    '24 7 24 hoursand 7days workingHospitals',
#    'No.of enificiariesinJananni Suraksha Yojanas',
#    'No.of benificiaries medical kit',
#    'Maternal Mortalit Death'],
#   ['',
#    'ffl',
#    'FRU Units First Referal Units',
#    'No.of Vehical',
#    'SNo.of sbenefitted patients',
#    'Nos.',
#    'No.of delivariesinthisHospital',
#    'No.of enificiariesinJananni Suraksha Yojanas',
#    'No.of benificiaries medical kit',
#    'Maternal Mortalit Death'],
#   ['1', '2', '714', '715', '716', '717', '718', '719', '720', '721']],
#  [['11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017',
#    '11.5 Famil Plannin Measures and AIDS prosy TB Control Pro grammesAs on 31.3.2017'],
#   ['',
#    'ffl',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme',
#    'LeprosyControl Programme'],
#   ['',
#    'ffl',
#    'of Identified Leprosy Patients',
#    'of Identified Leprosy Patients',
#    'of Identified Leprosy Patients',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'No. Patients Cured'],
#   ['', 'ffl', 'Afi Male', 'Female', 'Total', 'Afi Male', 'Female', 'Total'],
#   ['1', '2', '699', '700', '701', '702', '703', '704']],
#  [['11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.',
#    '11.5 AIDS Leprosy TB ControlProgrammes Year 2016-17 in Nos.'],
#   ['Sl. No.',
#    'Districts',
#    '',
#    '',
#    '',
#    '',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme',
#    'Aids Control Programme'],
#   ['Sl. No.',
#    'Districts',
#    'of identifiedAidspatients',
#    'of identifiedAidspatients',
#    'of identifiedAidspatients',
#    'of identifiedAidspatients',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'No. Patients Cured',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred',
#    'Death Occurred'],
#   ['Sl. No.',
#    'Districts',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG',
#    'Afi Male',
#    'Female',
#    'TS',
#    'TotalG'],
#   ['1',
#    '2',
#    '687',
#    '688',
#    '689',
#    '690',
#    '691',
#    '692',
#    '693',
#    '694',
#    '695',
#    '696',
#    '697',
#    '698']],
#  [['11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.',
#    '11.3 Dfl Allopathy Hospitals Indian System of Medicine Hospitals Pvt. Hospitals Including Nursing Homes Clinics Primary Health Centres Community Health Centres on 31.3.2017 In Nos.'],
#   ['Sl.No',
#    'Districts',
#    'Dfl Allopathy Hospitals',
#    'Dfl Allopathy Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of Medicine Hospitals',
#    'Indian System of MedicineDispensaries',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Primary Health Centres',
#    'Primary Health Centres',
#    'Community Health Centres',
#    'Community Health Centres'],
#   ['Sl.No',
#    'Districts',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds',
#    'Nos',
#    'No.of Pvt. Hospitals Including Nursing Homes Clinics',
#    'Nos.',
#    'Beds',
#    'Nos.',
#    'Beds'],
#   ['1',
#    '2',
#    '667',
#    '668',
#    '669',
#    '670',
#    '670.1',
#    '671',
#    '672',
#    '673',
#    '674',
#    '675']]]

# %%
def add_space_before_year(input_string):
    # Regular expression to find a year in 'yyyy' format with an optional alphabet character before it
    pattern = re.compile(r'([a-zA-Z])?(\d{4})')
    
    # Function to add space between alphabet character and year
    def replace(match):
        alphabet_part, year_part = match.groups()
        if alphabet_part:
            return f'{alphabet_part} {year_part}'
        else:
            return year_part

    # Using re.sub() to apply the replacement function to the input string
    result = pattern.sub(replace, input_string)

    return result

# %%
def remove_before_all_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    for i in range(len(matches)):
        second_occurrence_index = matches[i].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()

# %%
def convert_uppercase_to_camel_case(input_string):
    words = input_string.split()
    result_words = [word.capitalize() if word.isupper() else word for word in words]
    result_string = ' '.join(result_words)
    return result_string

# %%
def add_space_before_camelcase(input_string):
    # Use regular expression to find camel case words
    camelcase_pattern = re.compile(r'(?<=[a-z])(?=[A-Z])')
    result_string = camelcase_pattern.sub(' ', input_string)
    return result_string

# %%
def remove_extra_spaces(input_string):
    # Use regular expression to replace consecutive white spaces with a single space
    cleaned_string = re.sub(r'\s+', ' ', input_string)
    return cleaned_string.strip()

# %%
def add_space_before_word_with_condition(input_string):
    # Use regular expression to find words preceded by a number or special character
    pattern = re.compile(r'(?<=[%])\b(\w+)\b', flags=re.IGNORECASE)

    # Using re.sub() to add space before matched words
    result_string = pattern.sub(lambda x: ' ' + x.group(1), input_string)

    return result_string

# %%
def replace_words_with_blank(input_string, words_to_replace):
    # Constructing a regular expression pattern to match any of the words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')\b', flags=re.IGNORECASE)
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in words_to_replace) + r')(?!\S)', flags=re.IGNORECASE)

    # Using re.sub() to replace matched words with blank
    result = pattern.sub('', input_string)

    return result.strip()

# %%
words_to_replace = ['.CA', '.Dg', '.G.S', '.Jfl', '.Q.', '.ffl', '1 2', '1-10', '2 01', '2006 jAz 2016', '2011 twAi rAi AaP fiU', '2011 twAi zsj wAi EAzs %', '20112.2', '20112.6', '2011g', '24 7', '31.03.2017', '31.3.201', '31.3.2017', '31.3.2017.', '33 jAz 6', '6 jAz 1', '6 jAz 14', '6 wAU', 'A.ffl', 'A.g', 'AdP', 'Adg', 'Affl', 'Afi', 'Afli', 'Aid', 'Arg', 'Azs', 'CAU', 'CAZ', 'CAv', 'CAw', 'CAz', 'Cfi', 'CrP', 'Dfi', 'Dfl', 'E.J .n. .Dg .Jfl .JA.', 'EAf', 'Efi', 'Efl', 'JfiP', 'Jfl', 'KfiQ', 'MlM', 'Pfi', 'QAi', 'Raing', 'Rfl', 'SQA', 'Three', 'VAi', 'dfl', 'eng cy.U', 'ffl', 'fiAi', 'fiP', 'fiQ', 'fiQAi', 'fiU', 'fig', 'fl.', 'gLi', 'gMl', 'jAU', 'jAi', 'lion nit', 'ofD', 'rAi', 'tAwAi', 'tP', 'twAi', 'tzx', 'wAi', 'tzs']

# %%
def replace_words(input_string, word_replacements):
    # Constructing a regular expression pattern to match whole words in the set
    # pattern = re.compile(r'\b(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')\b')
    pattern = re.compile(r'(?<!\S)(?:' + '|'.join(re.escape(word) for word in word_replacements.keys()) + r')(?!\S)')

    
    # Using re.sub() to replace matched words with their corresponding replacements
    result = pattern.sub(lambda x: word_replacements.get(x.group(), x.group()), input_string)

    return result

# %%
word_replacements = { "cheduled" : "Scheduled", "Pri marySchool" : "Primary School", "School9-10thStandard" : "School 9-10th Standard", "on" : "on 31-3-2017", "irls" : "Girls", "ANos" : "Nos", "SocialWelfare12.1" : "SocialWelfare 12.1", "tudents" : "Students", "ackward" : "Backward", "igh" : "High", "9-10thStandard" : "9-10th Standard", "marySchool1-8thStandard" : "Primary School 1-8th Standard", "inorities" : "Minorities", "1-10thStandard" : "1-10th Standard", "ided" : "Aided", "overnment" : "Government"}

# %%
def process_data(input_data):
    for k in range(len(input_data)):
        for i in range(len(input_data[k])):
            for j in range(len(input_data[k][i])):
                #print(k,i,j,input_data[k][i][j])

                input_data[k][i][j] = add_space_before_year(input_data[k][i][j])
                input_data[k][i][j] = replace_words_with_blank(input_data[k][i][j], words_to_replace)
                input_data[k][i][j] = replace_words(input_data[k][i][j], word_replacements)
                input_data[k][i][j] = remove_before_all_occurrence(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_camelcase(input_data[k][i][j])
                input_data[k][i][j] = convert_uppercase_to_camel_case(input_data[k][i][j])
                input_data[k][i][j] = remove_extra_spaces(input_data[k][i][j])
                input_data[k][i][j] = add_space_before_word_with_condition(input_data[k][i][j])

# %%
process_data(output_list)
output_list
# Out:
# [[['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers'],
#   ['',
#    '',
#    'Scheduled Tribes',
#    'Scheduled Tribes',
#    'Scheduled Tribes',
#    'Scheduled Tribes',
#    'Scheduled Tribes',
#    'Scheduled Tribes'],
#   ['',
#    '',
#    'Primary School 1-8th Standard',
#    'Primary School 1-8th Standard',
#    'Primary School 1-8th Standard',
#    'High School 9-10th Standard',
#    'High School 9-10th Standard',
#    'High School 9-10th Standard'],
#   ['', '', 'Boys', 'Girls', 'Total', 'Boys', 'Girls', 'Total'],
#   ['1', '2', '824', '825', '826', '827', '828', '829']],
#  [['12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017'],
#   ['l.No.',
#    'District',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric'],
#   ['l.No.', 'District', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['l.No.', 'District', 'Nos', '', 'Nos', '', 'Nos', ''],
#   ['l.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '806', '807', '808', '809', '810', '811']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017'],
#   ['Sl.No.',
#    'District',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric'],
#   ['Sl.No.', 'District', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '776', '777', '778', '779', '780', '781']],
#  [['12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017'],
#   ['',
#    '',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    ''],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total', ''],
#   ['', '', 'Nos', '', 'Nos', '', 'Nos', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students', ''],
#   ['1', '2', '812', '813', '814', '815', '816', '817', '']],
#  [['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.'],
#   ['',
#    '',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric',
#    'Government- Pre-Matric'],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '722', '723', '724', '725', '726', '727']],
#  [['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.'],
#   ['Sl.No.',
#    'District',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric'],
#   ['Sl.No.', 'District', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '728', '729', '730', '731', '732', '733']],
#  [['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos'],
#   ['',
#    '',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric'],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '746', '747', '748', '749', '750', '751']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017'],
#   ['',
#    '',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric'],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '782', '783', '784', '785', '786', '787']],
#  [['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.'],
#   ['Sl.No',
#    'District',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric'],
#   ['Sl.No', 'District', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['Sl.No', 'District', '', '', '', '', '', ''],
#   ['Sl.No',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '764', '765', '766', '767', '768', '769']],
#  [['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers'],
#   ['Sl.No',
#    'District',
#    'Backward Castes',
#    'Backward Castes',
#    'Backward Castes',
#    'Backward Castes',
#    'Backward Castes',
#    'Backward Castes'],
#   ['Sl.No',
#    'District',
#    'Primary School 1-8th Standard',
#    'Primary School 1-8th Standard',
#    'Primary School 1-8th Standard',
#    'High School 9-10th Standard',
#    'High School 9-10th Standard',
#    'High School 9-10th Standard'],
#   ['Sl.No', 'District', 'Boys', 'Girls', 'Total', 'Boys', 'Girls', 'Total'],
#   ['1', '2', '830', '831', '832', '833', '834', '835']],
#  [['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.'],
#   ['',
#    '',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric'],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '734', '735', '736', '737', '738', '739']],
#  [['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 Ashrama Residential Students Hostels Year 2016-17',
#    '12.4 Ashrama Residential Students Hostels Year 2016-17'],
#   ['Sl.No',
#    'District',
#    'Scheduled Caste Ashrama Residential Students Hostels',
#    'Scheduled Caste Ashrama Residential Students Hostels',
#    'Scheduled Tribe Ashrama Residential Students Hostels',
#    'Scheduled Tribe Ashrama Residential Students Hostels',
#    'Backward Class Ashram Residential Students Hostels',
#    'Backward Class Ashram Residential Students Hostels'],
#   ['Sl.No',
#    'District',
#    'Numbers',
#    'students',
#    'Numbers',
#    'students',
#    'Numbers',
#    'students'],
#   ['1', '2', '794', '795', '796', '797', '798', '799']],
#  [['12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers'],
#   ['Sl.No', 'District', 'Minorities', 'Minorities', 'Minorities'],
#   ['Sl.No',
#    'District',
#    '1-10th Standard',
#    '1-10th Standard',
#    '1-10th Standard'],
#   ['Sl.No', 'District', 'Boys', 'Girls', 'Total'],
#   ['1', '2', '836', '837', '838']],
#  [['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    '12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos'],
#   ['Sl.No.',
#    'District',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric'],
#   ['Sl.No.', 'District', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '740', '741', '742', '743', '744', '745']],
#  [['12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017',
#    '12.5 Minorities Student Hostels on 31-3-2017'],
#   ['',
#    '',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric'],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['', '', 'Nos', '', 'Nos', '', 'Nos', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '800', '801', '802', '803', '804', '805']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '12.3 Backward Class Student Hostels on 31-3-2017 in Nos.'],
#   ['',
#    '',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric',
#    'Government Pre-Matric'],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '770', '771', '772', '773', '774', '775']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017',
#    '12.3 Backward Class Student Hostels on 31-3-2017'],
#   ['Sl. No',
#    'District',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric',
#    'Aided Post-Matric'],
#   ['Sl. No', 'District', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['Sl. No', 'District', '', '', '', '', '', ''],
#   ['Sl. No',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '788', '789', '790', '791', '792', '793']],
#  [['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers'],
#   ['Sl.No.',
#    'District',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste',
#    'Scheduled Caste'],
#   ['Sl.No.',
#    'District',
#    'Prim ary School 1-8th Standard',
#    'Prim ary School 1-8th Standard',
#    'Prim ary School 1-8th Standard',
#    'High School 9-10th Standard',
#    'High School 9-10th Standard',
#    'High School 9-10th Standard'],
#   ['Sl.No.', 'District', 'Boys', 'Girls', 'Total', 'g Boys', 'Girls', 'Total'],
#   ['1', '2', '818', '819', '820', '821', '822', '823']],
#  [['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.'],
#   ['',
#    '',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric',
#    'Aided Pre-Matric'],
#   ['', '', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['', '', '', '', '', '', '', ''],
#   ['', '', 'Nos', 'Students', 'Nos', 'Students', 'Nos', 'Students'],
#   ['1', '2', '758', '759', '760', '761', '762', '763']],
#  [['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.'],
#   ['Sl.No.',
#    'District',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric',
#    'Government Post-Matric'],
#   ['Sl.No.', 'District', 'Boys', 'Boys', 'Girls', 'Girls', 'Total', 'Total'],
#   ['Sl.No.', 'District', '', '', '', '', '', ''],
#   ['Sl.No.',
#    'District',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students',
#    'Nos',
#    'Students'],
#   ['1', '2', '752', '753', '754', '755', '756', '757']]]

# %%
#transpose the inner list
transp_list = [[list(pair) for pair in zip(*sublist)] for sublist in output_list]
transp_list
# Out:
# [[['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '',
#    '',
#    '',
#    '1'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    '',
#    '',
#    '',
#    '2'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Tribes',
#    'Primary School 1-8th Standard',
#    'Boys',
#    '824'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Tribes',
#    'Primary School 1-8th Standard',
#    'Girls',
#    '825'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Tribes',
#    'Primary School 1-8th Standard',
#    'Total',
#    '826'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Tribes',
#    'High School 9-10th Standard',
#    'Boys',
#    '827'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Tribes',
#    'High School 9-10th Standard',
#    'Girls',
#    '828'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Tribes',
#    'High School 9-10th Standard',
#    'Total',
#    '829']],
#  [['12.5 Minorities Student Hostels on 31-3-2017',
#    'l.No.',
#    'l.No.',
#    'l.No.',
#    'l.No.',
#    '1'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Boys',
#    'Nos',
#    'Nos',
#    '806'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Boys',
#    '',
#    'Students',
#    '807'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Girls',
#    'Nos',
#    'Nos',
#    '808'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Girls',
#    '',
#    'Students',
#    '809'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Total',
#    'Nos',
#    'Nos',
#    '810'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Total',
#    '',
#    'Students',
#    '811']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '776'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Boys',
#    '',
#    'Students',
#    '777'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '778'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Girls',
#    '',
#    'Students',
#    '779'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Total',
#    '',
#    'Nos',
#    '780'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Government Post-Matric',
#    'Total',
#    '',
#    'Students',
#    '781']],
#  [['12.5 Minorities Student Hostels on 31-3-2017', '', '', '', '', '1'],
#   ['12.5 Minorities Student Hostels on 31-3-2017', '', '', '', '', '2'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Boys',
#    'Nos',
#    'Nos',
#    '812'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Boys',
#    '',
#    'Students',
#    '813'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Girls',
#    'Nos',
#    'Nos',
#    '814'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Girls',
#    '',
#    'Students',
#    '815'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Total',
#    'Nos',
#    'Nos',
#    '816'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Total',
#    '',
#    'Students',
#    '817'],
#   ['12.5 Minorities Student Hostels on 31-3-2017', '', '', '', '', '']],
#  [['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '1'],
#   ['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '2'],
#   ['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    'Government- Pre-Matric',
#    'Boys',
#    'Nos',
#    '722'],
#   ['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    'Government- Pre-Matric',
#    'Boys',
#    'Students',
#    '723'],
#   ['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    'Government- Pre-Matric',
#    'Girls',
#    'Nos',
#    '724'],
#   ['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    'Government- Pre-Matric',
#    'Girls',
#    'Students',
#    '725'],
#   ['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    'Government- Pre-Matric',
#    'Total',
#    'Nos',
#    '726'],
#   ['12.1 Scheduled Caste Student Hostels As on 31-3-2017 in Nos.',
#    'Government- Pre-Matric',
#    'Total',
#    'Students',
#    '727']],
#  [['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '728'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Boys',
#    '',
#    'Students',
#    '729'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '730'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Girls',
#    '',
#    'Students',
#    '731'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Total',
#    '',
#    'Nos',
#    '732'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Total',
#    '',
#    'Students',
#    '733']],
#  [['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '',
#    '',
#    '',
#    '',
#    '1'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    '',
#    '',
#    '',
#    '',
#    '2'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    'Government Pre-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '746'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    'Government Pre-Matric',
#    'Boys',
#    '',
#    'Students',
#    '747'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    'Government Pre-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '748'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    'Government Pre-Matric',
#    'Girls',
#    '',
#    'Students',
#    '749'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    'Government Pre-Matric',
#    'Total',
#    '',
#    'Nos',
#    '750'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos',
#    'Government Pre-Matric',
#    'Total',
#    '',
#    'Students',
#    '751']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017', '', '', '', '', '1'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017', '', '', '', '', '2'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '782'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Boys',
#    '',
#    'Students',
#    '783'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '784'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Girls',
#    '',
#    'Students',
#    '785'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Total',
#    '',
#    'Nos',
#    '786'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Pre-Matric',
#    'Total',
#    '',
#    'Students',
#    '787']],
#  [['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'Aided Post-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '764'],
#   ['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'Aided Post-Matric',
#    'Boys',
#    '',
#    'Students',
#    '765'],
#   ['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'Aided Post-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '766'],
#   ['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'Aided Post-Matric',
#    'Girls',
#    '',
#    'Students',
#    '767'],
#   ['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'Aided Post-Matric',
#    'Total',
#    '',
#    'Nos',
#    '768'],
#   ['12.2 Scheduled Tribes Student Hostels on 31-3-2017 in Nos.',
#    'Aided Post-Matric',
#    'Total',
#    '',
#    'Students',
#    '769']],
#  [['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Backward Castes',
#    'Primary School 1-8th Standard',
#    'Boys',
#    '830'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Backward Castes',
#    'Primary School 1-8th Standard',
#    'Girls',
#    '831'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Backward Castes',
#    'Primary School 1-8th Standard',
#    'Total',
#    '832'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Backward Castes',
#    'High School 9-10th Standard',
#    'Boys',
#    '833'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Backward Castes',
#    'High School 9-10th Standard',
#    'Girls',
#    '834'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Backward Castes',
#    'High School 9-10th Standard',
#    'Total',
#    '835']],
#  [['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '',
#    '1'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '',
#    '2'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '734'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Boys',
#    '',
#    'Students',
#    '735'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '736'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Girls',
#    '',
#    'Students',
#    '737'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Total',
#    '',
#    'Nos',
#    '738'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Total',
#    '',
#    'Students',
#    '739']],
#  [['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'District',
#    'District',
#    '2'],
#   ['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'Scheduled Caste Ashrama Residential Students Hostels',
#    'Numbers',
#    '794'],
#   ['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'Scheduled Caste Ashrama Residential Students Hostels',
#    'students',
#    '795'],
#   ['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'Scheduled Tribe Ashrama Residential Students Hostels',
#    'Numbers',
#    '796'],
#   ['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'Scheduled Tribe Ashrama Residential Students Hostels',
#    'students',
#    '797'],
#   ['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'Backward Class Ashram Residential Students Hostels',
#    'Numbers',
#    '798'],
#   ['12.4 Ashrama Residential Students Hostels Year 2016-17',
#    'Backward Class Ashram Residential Students Hostels',
#    'students',
#    '799']],
#  [['12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    'Sl.No',
#    'Sl.No',
#    'Sl.No',
#    '1'],
#   ['12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    'Minorities',
#    '1-10th Standard',
#    'Boys',
#    '836'],
#   ['12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    'Minorities',
#    '1-10th Standard',
#    'Girls',
#    '837'],
#   ['12.6 Scholarship paid to 1-10th Standard Students 2016-17 In Numbers',
#    'Minorities',
#    '1-10th Standard',
#    'Total',
#    '838']],
#  [['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'Aided Post-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '740'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'Aided Post-Matric',
#    'Boys',
#    '',
#    'Students',
#    '741'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'Aided Post-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '742'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'Aided Post-Matric',
#    'Girls',
#    '',
#    'Students',
#    '743'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'Aided Post-Matric',
#    'Total',
#    '',
#    'Nos',
#    '744'],
#   ['12.1 Scheduled Caste Student Hostels on 31-3-2017 in Nos',
#    'Aided Post-Matric',
#    'Total',
#    '',
#    'Students',
#    '745']],
#  [['12.5 Minorities Student Hostels on 31-3-2017', '', '', '', '', '1'],
#   ['12.5 Minorities Student Hostels on 31-3-2017', '', '', '', '', '2'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Pre-Matric',
#    'Boys',
#    'Nos',
#    'Nos',
#    '800'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Pre-Matric',
#    'Boys',
#    '',
#    'Students',
#    '801'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Pre-Matric',
#    'Girls',
#    'Nos',
#    'Nos',
#    '802'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Pre-Matric',
#    'Girls',
#    '',
#    'Students',
#    '803'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Pre-Matric',
#    'Total',
#    'Nos',
#    'Nos',
#    '804'],
#   ['12.5 Minorities Student Hostels on 31-3-2017',
#    'Government Pre-Matric',
#    'Total',
#    '',
#    'Students',
#    '805']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '',
#    '1'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '',
#    '2'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    'Government Pre-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '770'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    'Government Pre-Matric',
#    'Boys',
#    '',
#    'Students',
#    '771'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    'Government Pre-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '772'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    'Government Pre-Matric',
#    'Girls',
#    '',
#    'Students',
#    '773'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    'Government Pre-Matric',
#    'Total',
#    '',
#    'Nos',
#    '774'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017 in Nos.',
#    'Government Pre-Matric',
#    'Total',
#    '',
#    'Students',
#    '775']],
#  [['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Sl. No',
#    'Sl. No',
#    'Sl. No',
#    'Sl. No',
#    '1'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Post-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '788'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Post-Matric',
#    'Boys',
#    '',
#    'Students',
#    '789'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Post-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '790'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Post-Matric',
#    'Girls',
#    '',
#    'Students',
#    '791'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Post-Matric',
#    'Total',
#    '',
#    'Nos',
#    '792'],
#   ['12.3 Backward Class Student Hostels on 31-3-2017',
#    'Aided Post-Matric',
#    'Total',
#    '',
#    'Students',
#    '793']],
#  [['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Caste',
#    'Prim ary School 1-8th Standard',
#    'Boys',
#    '818'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Caste',
#    'Prim ary School 1-8th Standard',
#    'Girls',
#    '819'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Caste',
#    'Prim ary School 1-8th Standard',
#    'Total',
#    '820'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Caste',
#    'High School 9-10th Standard',
#    'g Boys',
#    '821'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Caste',
#    'High School 9-10th Standard',
#    'Girls',
#    '822'],
#   ['12.6 Scholarship paid to Primary and High Schools Students 2016-17 In Numbers',
#    'Scheduled Caste',
#    'High School 9-10th Standard',
#    'Total',
#    '823']],
#  [['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '',
#    '1'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    '',
#    '',
#    '',
#    '',
#    '2'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '758'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Boys',
#    '',
#    'Students',
#    '759'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '760'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Girls',
#    '',
#    'Students',
#    '761'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Total',
#    '',
#    'Nos',
#    '762'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Aided Pre-Matric',
#    'Total',
#    '',
#    'Students',
#    '763']],
#  [['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    'Sl.No.',
#    '1'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'District',
#    'District',
#    'District',
#    'District',
#    '2'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Boys',
#    '',
#    'Nos',
#    '752'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Boys',
#    '',
#    'Students',
#    '753'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Girls',
#    '',
#    'Nos',
#    '754'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Girls',
#    '',
#    'Students',
#    '755'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Total',
#    '',
#    'Nos',
#    '756'],
#   ['12.2 Scheduled Tribe Student Hostels on 31-3-2017 in Nos.',
#    'Government Post-Matric',
#    'Total',
#    '',
#    'Students',
#    '757']]]

# %%
def find_table_details(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = pattern.finditer(input_string)

    # Initialize variables to store the matches
    match_positions = []

    # Store the positions of the matches
    for match in matches:
        match_positions.append(match.start())

    # If there is at least one occurrence of the pattern
    if match_positions:
        table_id_index = match_positions[0]
        input_string = input_string[table_id_index:]  
        space_index = input_string.find(' ') 
        table_id = input_string[table_id_index:space_index].strip()
        table_name = input_string[space_index:].strip()
        return table_id, table_name    
    else:
        return None, None

# %%
def convert_to_number(string):
    try:
        number = int(string)
    except ValueError:
        try:
            number = float(string)
        except ValueError:
            raise ValueError("Input string is not a valid number")
    return number

# %%
chapter_id = 12
chapter_name = "Social Welfare"
#processing each column
def process_dictionary(input_data):
    df = pd.DataFrame(columns = ['Attr_id', 'Chapter_id', 'Chapter_name', 'Table_id', 'Table_name', 'Description'])
    for inner_list in input_data:
        table_id, table_name = find_table_details(inner_list[0][0])
        previd=0
        for data_list in inner_list:
            i=0
            attr_id=0
            description = ''
            prev = ''
            for data in reversed(data_list):
                if data == '1' or data == '2':
                    break
                i = i+1;
                if i == 1 and data!='' and (previd==0 or convert_to_number(data)!=previd):
                    attr_id = convert_to_number(data)
                    previd = convert_to_number(data)
                if i > 1 and i < len(data_list):
                    if description == '':
                        description = data
                        prev = data
                    else : 
                        if prev != data and data!='':
                            description = ','.join([description, data]) #description + ' ' + data
                            prev = data
            if attr_id != 0 and description != "" :
                row = {'Attr_id' : attr_id, 'Chapter_id' : chapter_id, 'Chapter_name' : chapter_name, 'Table_id' : table_id, 'Table_name' : table_name, 'Description' : remove_extra_spaces(description)}
                df.loc[len(df)] = row
    df = df.sort_values(by=['Attr_id'])
    df.to_csv('/home/riya/Downloads/ADT/Output_html_Chapter12/Chapter12_Attributes.csv', sep=';', index=False)
    df.to_csv('/home/riya/Downloads/ADT/Dictionary/Chapter12_Attributes.csv', sep=';', index=False)

# %%
process_dictionary(transp_list)

# %%
#Not used
def remove_before_second_occurrence(input_string):
    # Regular expression to match numbers with dot similar to dd.dd, d.d, d.dd, or dd.d
    pattern = re.compile(r'\b(\d\.\d|\d{2}\.\d|\d\.\d{2}|\d{2}\.\d{2})\b')

    # Find all occurrences of the pattern in the input string
    matches = list(pattern.finditer(input_string))

    # If there are at least two occurrences of the pattern, remove everything before the second occurrence
    if len(matches) >= 2:
        second_occurrence_index = matches[1].start()
        input_string = input_string[second_occurrence_index:]

    return input_string.strip()
